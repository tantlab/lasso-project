# %%
# SETTINGS

number_topics = 15

# %% [markdown]
# # Filter
#
# Here we assume that the source file already contains the text, as it's a subcorpus.

# %%
# Filter the input file
import pandas as pd

df = pd.read_csv('00 source data (urls).csv')
df.fillna('', inplace=True)

# /!\ FILTERING
df = df[df['area'] == 'Iceland']

df.to_csv("01 data filtered.csv", index = False, encoding='utf-8')

df
# Out:
#       result # search engine       discourse     area              domain  \
# 1058      2118          bing         UN SDGs  Iceland                unep
# 1066      2007          bing     environment  Iceland       icelandreview
# 1071      2117          bing         UN SDGs  Iceland                 fao
# 1073      2098          bing     environment  Iceland  scientificamerican
# 1074      2021          bing     environment  Iceland         theguardian
# ...        ...           ...             ...      ...                 ...
# 1205      2323          bing    green growth  Iceland                  un
# 1206      2403          bing  sustainability  Iceland                  un
# 1212      2405          bing  sustainability  Iceland                  un
# 1751      2051          bing     environment  Iceland                oecd
# 1771      2097          bing     environment  Iceland                oecd
#
#      actor name                                      article title  \
# 1058             Iceland, a world leader in clean energy ... - ...
# 1066             Environmental Issues Among Iceland"s Top Five ...
# 1071             FAO Country Profiles: Iceland | Food and Agric...
# 1073             One Hot Island: Iceland"s Renewable Geothermal...
# 1074             Iceland"s innovations to reach net-zero – in p...
# ...         ...                                                ...
# 1205             Iceland .:. Sustainable Development Knowledge ...
# 1206             Iceland"s Sustainable Energy Story: A Model fo...
# 1212             Iceland .:. Sustainable Development Knowledge ...
# 1751                                                Iceland - OECD
# 1771             Environmental performance review: Iceland 2014...
#
#                                             article url  \
# 1058  https://www.unep.org/news-and-stories/story/ic...
# 1066  https://www.icelandreview.com/news/environment...
# 1071  http://www.fao.org/countryprofiles/index/en/?i...
# 1073  https://www.scientificamerican.com/article/ice...
# 1074  https://www.theguardian.com/environment/galler...
# ...                                                 ...
# 1205  https://sustainabledevelopment.un.org/memberst...
# 1206  https://www.un.org/en/chronicle/article/icelan...
# 1212  https://sustainabledevelopment.un.org/memberst...
# 1751  http://www.oecd.org/environment/country-review...
# 1771    http://www.oecd.org/environment/iceland2014.htm
#
#                                     article description  \
# 1058  6/24/2020 · Iceland is also home to the Geothe...
# 1066  1/12/2018 · Icelanders have become increasingl...
# 1071  About us Director-General Leadership Organizat...
# 1073  10/20/2008 · Environment. One Hot Island: Icel...
# 1074  12/30/2020 · Geothermal wells and pipes in Kra...
# ...                                                 ...
# 1205  Iceland is fully committed to implementing Age...
# 1206  Iceland"s conversion is a meaningful success s...
# 1212  Iceland is fully committed to implementing Age...
# 1751  Iceland has a very small, open economy, built ...
# 1771  Iceland has a very small, open economy, built ...
#
#       total nr of results (best guess)  ...  \
# 1058                          46000000  ...
# 1066                          83500000  ...
# 1071                          46000000  ...
# 1073                          83500000  ...
# 1074                          83500000  ...
# ...                                ...  ...
# 1205                          91000000  ...
# 1206                          67300000  ...
# 1212                          67300000  ...
# 1751                          83500000  ...
# 1771                          83500000  ...
#
#                                           canonical_url  \
# 1058
# 1066  https://www.icelandreview.com/news/environment...
# 1071  http://www.fao.org/countryprofiles/index/en/?i...
# 1073  https://www.scientificamerican.com/article/ice...
# 1074  http://www.theguardian.com/environment/gallery...
# ...                                                 ...
# 1205
# 1206  https://www.un.org/en/chronicle/article/icelan...
# 1212
# 1751
# 1771
#
#                                                   title  \
# 1058
# 1066  Environmental Issues Among Iceland's Top Five ...
# 1071                                    general profile
# 1073  One Hot Island: Iceland's Renewable Geothermal...
# 1074  Iceland's innovations to reach net-zero – in p...
# ...                                                 ...
# 1205  Iceland .:. Sustainable Development Knowledge ...
# 1206  Iceland's Sustainable Energy Story: A Model fo...
# 1212  Iceland .:. Sustainable Development Knowledge ...
# 1751
# 1771  Environmental performance review: Iceland 2014...
#
#                                             description  \
# 1058
# 1066  Icelanders have become increasingly aware of a...
# 1071
# 1073  Iceland goes green by tapping the power of the...
# 1074  Isolated and challenged by a harsh climate and...
# ...                                                 ...
# 1205
# 1206  Iceland's conversion is a meaningful success s...
# 1212
# 1751
# 1771  Data, research, outlooks and country reviews o...
#
#                                             raw_content comments  \
# 1058
# 1066  Icelanders have become increasingly aware of a...
# 1071  SEE ALL PUBLICATIONS chevron_right\nThematic p...
# 1073  REYKJAVIK, ICELAND—Snorri Sturlusson is the fi...
# 1074  Iceland's innovations to reach net-zero – in p...
# ...                                                 ...      ...
# 1205  Iceland is fully committed to implementing Age...
# 1206  In an era when climate change is making it nec...
# 1212  Iceland is fully committed to implementing Age...
# 1751
# 1771  Iceland has one of the world’s most pristine n...
#
#                 author   categories  \
# 1058
# 1066    Iceland Review       x News
# 1071
# 1073  Christopher Mims
# 1074                    Environment
# ...                ...          ...
# 1205
# 1206    United Nations
# 1212
# 1751
# 1771
#
#                                                    tags        date  \
# 1058
# 1066                                                     2018-01-12
# 1071
# 1073                                                     2008-10-20
# 1074  Environment|Iceland|Climate change|Greenhouse ...  2020-12-30
# ...                                                 ...         ...
# 1205                              Ocean Conference 2017  2017-06-09
# 1206
# 1212                              Ocean Conference 2017  2017-06-09
# 1751
# 1771  environment|biodiversity|water|resource and wa...
#
#                                                sitename
# 1058
# 1066                                     Iceland Review
# 1071  Food and Agriculture Organization of the Unite...
# 1073                                Scientific American
# 1074                                       The Guardian
# ...                                                 ...
# 1205
# 1206                                     United Nations
# 1212
# 1751
# 1771                                               OECD
#
# [65 rows x 29 columns]

# %% [markdown]
# # Group content by actor

# %%
actor_dict = {}
for index, row in df.iterrows():
    if row['actor name']:
        actor_id = row['actor name']
    else:
        actor_id = row['domain']
    if actor_id in actor_dict:
        actor_obj = actor_dict[actor_id]
    else:
        actor_obj = {}
        actor_obj['Id'] = actor_id
        actor_obj['urls'] = ''
        actor_obj['text'] = ''
        actor_obj['discourse: Climate change'] = 'False'
        actor_obj['discourse: Environment'] = 'False'
        actor_obj['discourse: Green growth'] = 'False'
        actor_obj['discourse: Sustainability'] = 'False'
        actor_obj['discourse: UN SDGs'] = 'False'
        actor_obj['area: Arctic'] = 'False'
        actor_obj['area: Arctic Norway'] = 'False'
        actor_obj['area: Extended Arctic'] = 'False'
        actor_obj['area: Faroed Islands'] = 'False'
        actor_obj['area: Greenland'] = 'False'
        actor_obj['area: Iceland'] = 'False'
        actor_obj['area: Nunavut'] = 'False'
        actor_obj['area: Sami'] = 'False'
    
    actor_obj['urls'] = actor_obj['urls'] + str(row['article url']) + ' '
    actor_obj['text'] = actor_obj['text'] + str(row['raw_content']) + ' . '

    if row['discourse'] == 'Climate change':
        actor_obj['discourse: Climate change'] = 'True'
    if row['discourse'] == 'environment':
        actor_obj['discourse: Environment'] = 'True'
    if row['discourse'] == 'green growth':
        actor_obj['discourse: Green growth'] = 'True'
    if row['discourse'] == 'sustainability':
        actor_obj['discourse: Sustainability'] = 'True'
    if row['discourse'] == 'UN SDGs':
        actor_obj['discourse: UN SDGs'] = 'True'
    if row['area'] == 'arctic':
        actor_obj['area: Arctic'] = 'True'
    if row['area'] == 'arctic norway':
        actor_obj['area: Arctic Norway'] = 'True'
    if row['area'] == 'extended arctic':
        actor_obj['area: Extended Arctic'] = 'True'
    if row['area'] == 'faroe islands':
        actor_obj['area: Faroed Islands'] = 'True'
    if row['area'] == 'greenland':
        actor_obj['area: Greenland'] = 'True'
    if row['area'] == 'Iceland':
        actor_obj['area: Iceland'] = 'True'
    if row['area'] == 'Nunavut':
        actor_obj['area: Nunavut'] = 'True'
    if row['area'] == 'Sami':
        actor_obj['area: Sami'] = 'True'
    
    actor_dict[actor_id] = actor_obj
print("Actor index built.")
# Out:
# Actor index built.

# %%
# DOWNLOAD ACTORS
actors_df = pd.DataFrame.from_dict(actor_dict, orient='index')
actors_df.to_csv("02 Actors with text.csv", index = False, encoding='utf-8')
actors_df
# Out:
#                                                           Id  \
# unep                                                    unep
# icelandreview                                  icelandreview
# fao                                                      fao
# scientificamerican                        scientificamerican
# theguardian                                      theguardian
# unicef                                                unicef
# newsweek                                            newsweek
# weforum                                              weforum
# government                                        government
# iceland                                              iceland
# guidetoiceland                                guidetoiceland
# thewire                                              thewire
# wipo                                                    wipo
# who                                                      who
# ruv                                                      ruv
# euobserver                                        euobserver
# worldbank                                          worldbank
# nytimes                                              nytimes
# prospects                                          prospects
# aljazeera                                          aljazeera
# sjavarklasinn                                  sjavarklasinn
# nationalgeographic                        nationalgeographic
# arctic-council                                arctic-council
# cia                                                      cia
# thegreenprogram                              thegreenprogram
# europa                                                europa
# hi                                                        hi
# matadornetwork                                matadornetwork
# salmon-from-the-faroe-islands  salmon-from-the-faroe-islands
# ru                                                        ru
# circularsolutions                          circularsolutions
# hihostels                                          hihostels
# blueandgreentomorrow                    blueandgreentomorrow
# bluelagoon                                        bluelagoon
# eco-business                                    eco-business
# hiddeniceland                                  hiddeniceland
# un                                                        un
# huffpost                                            huffpost
# siceland                                            siceland
# matorka                                              matorka
# reykjavikforum                                reykjavikforum
# oecd                                                    oecd
#
#                                                                             urls  \
# unep                           https://www.unep.org/news-and-stories/story/ic...
# icelandreview                  https://www.icelandreview.com/news/environment...
# euobserver                     Iceland says final EU goodbye\nBy Eric Maurice...
# worldbank                      International migration to fall in 2020 for th...
# nytimes                        What Worries Iceland? A World Without Ice. It ...
# prospects                      Work in Iceland\nNot the most obvious place fo...
# aljazeera                      Popular glaciers are melting so fast that guid...
# sjavarklasinn                  150% growth in startups\nNew analysis by the I...
# nationalgeographic             Is Iceland Really Green and Greenland Really I...
# arctic-council                                                                .
# cia                            Introduction\nBackground\nSettled by Norwegian...
# thegreenprogram                Why Iceland\nAs one of the greenest countries ...
# europa                         Iceland on the road to sustainable transport\n...
# hi                             Sustainability and Environment\nThe University...
# matadornetwork                 After economic collapse, here’s how Iceland re...
# salmon-from-the-faroe-islands  Sustainability has become the hallmark of Faro...
# ru                             Our Programmes:\nNews and Events\nMSc Thesis: ...
# circularsolutions              CIRCULAR Solutions is a sustainability & ESG\n...
# hihostels                      Welcome to our hostel\nSelfoss is a lovely tow...
# blueandgreentomorrow           No list of inspirational sustainable cities wo...
# bluelagoon                     About us\nSustainability\nThe genetic cornerst...
# eco-business                   Since the 1970s, economic development has help...
# hiddeniceland                  Sustainable tourism in Iceland is a hot topic ...
# un                             Iceland is fully committed to implementing Age...
# huffpost                       Last week I had the pleasure of speaking at th...
# siceland                       Know More\nSustainability\nSUSTAINABILITY\nOur...
# matorka                        Sustainability\nRampant over-fishing and a wor...
# reykjavikforum                 The Forum is now Live\nTo access the Forum ple...
# oecd                            . Iceland has one of the world’s most pristin...
#
#                               discourse: Climate change  \
# unep                                              False
# icelandreview                                      True
# fao                                               False
# scientificamerican                                False
# theguardian                                       False
# unicef                                             True
# newsweek                                          False
# weforum                                           False
# government                                        False
# iceland                                           False
# guidetoiceland                                    False
# thewire                                           False
# wipo                                              False
# who                                                True
# ruv                                                True
# euobserver                                         True
# worldbank                                          True
# nytimes                                            True
# prospects                                          True
# aljazeera                                          True
# sjavarklasinn                                     False
# nationalgeographic                                 True
# arctic-council                                    False
# cia                                                True
# thegreenprogram                                   False
# europa                                            False
# hi                                                False
# matadornetwork                                    False
# salmon-from-the-faroe-islands                     False
# ru                                                False
# circularsolutions                                 False
# hihostels                                         False
# blueandgreentomorrow                              False
# bluelagoon                                        False
# eco-business                                      False
# hiddeniceland                                     False
# un                                                 True
# huffpost                                          False
# siceland                                          False
# matorka                                           False
# reykjavikforum                                    False
# oecd                                              False
#
#                               discourse: Environment discourse: Green growth  \
# unep                                           False                   False
# icelandreview                                   True                   False
# fao                                            False                   False
# scientificamerican                              True                   False
# theguardian                                     True                   False
# unicef                                         False                   False
# newsweek                                        True                   False
# weforum                                        False                   False
# government                                     False                    True
# iceland                                         True                    True
# guidetoiceland                                 False                    True
# thewire                                         True                   False
# wipo                                           False                   False
# who                                            False                   False
# ruv                                            False                   False
# euobserver                                     False                   False
# worldbank                                      False                   False
# nytimes                                        False                   False
# prospects                                      False                   False
# aljazeera                                      False                   False
# sjavarklasinn                                  False                   False
# nationalgeographic                             False                   False
# arctic-council                                 False                   False
# cia                                            False                   False
# thegreenprogram                                False                    True
# europa                                         False                    True
# hi                                             False                   False
# matadornetwork                                 False                    True
# salmon-from-the-faroe-islands                  False                   False
# ru                                             False                   False
# circularsolutions                              False                    True
# hihostels                                      False                   False
# blueandgreentomorrow                           False                    True
# bluelagoon                                     False                   False
# eco-business                                   False                    True
# hiddeniceland                                  False                   False
# un                                             False                    True
# huffpost                                       False                   False
# siceland                                       False                   False
# matorka                                        False                   False
# reykjavikforum                                 False                   False
# oecd                                            True                   False
#
#                               discourse: Sustainability discourse: UN SDGs  \
# unep                                              False               True
# icelandreview                                     False              False
# fao                                               False               True
# scientificamerican                                False              False
# theguardian                                       False              False
# unicef                                            False               True
# newsweek                                          False              False
# weforum                                           False               True
# government                                        False               True
# iceland                                           False              False
# guidetoiceland                                     True               True
# thewire                                           False              False
# wipo                                              False               True
# who                                               False               True
# ruv                                               False              False
# euobserver                                        False              False
# worldbank                                         False              False
# nytimes                                           False              False
# prospects                                         False              False
# aljazeera                                         False              False
# sjavarklasinn                                     False               True
# nationalgeographic                                False              False
# arctic-council                                    False               True
# cia                                               False              False
# thegreenprogram                                    True               True
# europa                                            False              False
# hi                                                 True              False
# matadornetwork                                    False              False
# salmon-from-the-faroe-islands                      True              False
# ru                                                 True              False
# circularsolutions                                 False              False
# hihostels                                         False               True
# blueandgreentomorrow                               True              False
# bluelagoon                                         True              False
# eco-business                                      False              False
# hiddeniceland                                      True              False
# un                                                 True               True
# huffpost                                           True              False
# siceland                                           True              False
# matorka                                            True              False
# reykjavikforum                                    False               True
# oecd                                              False              False
#
#                               area: Arctic area: Arctic Norway  \
# unep                                 False               False
# icelandreview                        False               False
# fao                                  False               False
# scientificamerican                   False               False
# theguardian                          False               False
# unicef                               False               False
# newsweek                             False               False
# weforum                              False               False
# government                           False               False
# iceland                              False               False
# guidetoiceland                       False               False
# thewire                              False               False
# wipo                                 False               False
# who                                  False               False
# ruv                                  False               False
# euobserver                           False               False
# worldbank                            False               False
# nytimes                              False               False
# prospects                            False               False
# aljazeera                            False               False
# sjavarklasinn                        False               False
# nationalgeographic                   False               False
# arctic-council                       False               False
# cia                                  False               False
# thegreenprogram                      False               False
# europa                               False               False
# hi                                   False               False
# matadornetwork                       False               False
# salmon-from-the-faroe-islands        False               False
# ru                                   False               False
# circularsolutions                    False               False
# hihostels                            False               False
# blueandgreentomorrow                 False               False
# bluelagoon                           False               False
# eco-business                         False               False
# hiddeniceland                        False               False
# un                                   False               False
# huffpost                             False               False
# siceland                             False               False
# matorka                              False               False
# reykjavikforum                       False               False
# oecd                                 False               False
#
#                               area: Extended Arctic area: Faroed Islands  \
# unep                                          False                False
# icelandreview                                 False                False
# fao                                           False                False
# scientificamerican                            False                False
# theguardian                                   False                False
# unicef                                        False                False
# newsweek                                      False                False
# weforum                                       False                False
# government                                    False                False
# iceland                                       False                False
# guidetoiceland                                False                False
# thewire                                       False                False
# wipo                                          False                False
# who                                           False                False
# ruv                                           False                False
# euobserver                                    False                False
# worldbank                                     False                False
# nytimes                                       False                False
# prospects                                     False                False
# aljazeera                                     False                False
# sjavarklasinn                                 False                False
# nationalgeographic                            False                False
# arctic-council                                False                False
# cia                                           False                False
# thegreenprogram                               False                False
# europa                                        False                False
# hi                                            False                False
# matadornetwork                                False                False
# salmon-from-the-faroe-islands                 False                False
# ru                                            False                False
# circularsolutions                             False                False
# hihostels                                     False                False
# blueandgreentomorrow                          False                False
# bluelagoon                                    False                False
# eco-business                                  False                False
# hiddeniceland                                 False                False
# un                                            False                False
# huffpost                                      False                False
# siceland                                      False                False
# matorka                                       False                False
# reykjavikforum                                False                False
# oecd                                          False                False
#
#                               area: Greenland area: Iceland area: Nunavut  \
# unep                                    False          True         False
# icelandreview                           False          True         False
# fao                                     False          True         False
# scientificamerican                      False          True         False
# theguardian                             False          True         False
# unicef                                  False          True         False
# newsweek                                False          True         False
# weforum                                 False          True         False
# government                              False          True         False
# iceland                                 False          True         False
# guidetoiceland                          False          True         False
# thewire                                 False          True         False
# wipo                                    False          True         False
# who                                     False          True         False
# ruv                                     False          True         False
# euobserver                              False          True         False
# worldbank                               False          True         False
# nytimes                                 False          True         False
# prospects                               False          True         False
# aljazeera                               False          True         False
# sjavarklasinn                           False          True         False
# nationalgeographic                      False          True         False
# arctic-council                          False          True         False
# cia                                     False          True         False
# thegreenprogram                         False          True         False
# europa                                  False          True         False
# hi                                      False          True         False
# matadornetwork                          False          True         False
# salmon-from-the-faroe-islands           False          True         False
# ru                                      False          True         False
# circularsolutions                       False          True         False
# hihostels                               False          True         False
# blueandgreentomorrow                    False          True         False
# bluelagoon                              False          True         False
# eco-business                            False          True         False
# hiddeniceland                           False          True         False
# un                                      False          True         False
# huffpost                                False          True         False
# siceland                                False          True         False
# matorka                                 False          True         False
# reykjavikforum                          False          True         False
# oecd                                    False          True         False
#
#                               area: Sami
# unep                               False
# icelandreview                      False
# fao                                False
# scientificamerican                 False
# theguardian                        False
# unicef                             False
# newsweek                           False
# weforum                            False
# government                         False
# iceland                            False
# guidetoiceland                     False
# thewire                            False
# wipo                               False
# who                                False
# ruv                                False
# euobserver                         False
# worldbank                          False
# nytimes                            False
# prospects                          False
# aljazeera                          False
# sjavarklasinn                      False
# nationalgeographic                 False
# arctic-council                     False
# cia                                False
# thegreenprogram                    False
# europa                             False
# hi                                 False
# matadornetwork                     False
# salmon-from-the-faroe-islands      False
# ru                                 False
# circularsolutions                  False
# hihostels                          False
# blueandgreentomorrow               False
# bluelagoon                         False
# eco-business                       False
# hiddeniceland                      False
# un                                 False
# huffpost                           False
# siceland                           False
# matorka                            False
# reykjavikforum                     False
# oecd                               False

# %% [markdown]
# # LDA: extract topics

# %%
import pandas as pd
# This is for text mining
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# Source file (CSV)
source_file = "02 Actors with text.csv"
text_col_name = "text"

# More features is more dimensions for each document. You should probably keep it at 1000.
no_features = 1000

# %%
# LOAD DATA
documents_dictionary = {}
df = pd.read_csv(source_file)

for index, row in df.iterrows():
    key = row['Id']
    text = str(row[text_col_name])
    if len(text)>10:
        documents_dictionary[key] = text

# %%
# COMPUTE LDA TOPICS
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents_dictionary.values())
tf_feature_names = tf_vectorizer.get_feature_names()
lda = LatentDirichletAllocation(n_components=number_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)
print("LDA topics computed.")
# Out:
# LDA topics computed.

# %%
# DISPLAY RESULTS (for monitoring)
no_top_words = 25 # How many words to keep for each topic (there may be many)

# Create a data frame for convenience (for download, actually)
topics_df = pd.DataFrame(columns=['topic','word','weight'])

# Display topics to check it works. For each topic, we only display the top words.
i = 0
for topic_idx, topic in enumerate(lda.components_):
    print("# TOPIC_%d:" % (topic_idx))
    for j in topic.argsort()[:-no_top_words - 1:-1]:
        print(str(topic[j]) + "   " + tf_feature_names[j])
        topics_df.loc[i] = ["TOPIC_"+str(topic_idx), tf_feature_names[j], topic[j]]
        i = i+1
    print(" ")

topics_df
# Out:
# # TOPIC_0:
# 4.401948217156163   iceland
# 2.452821261624727   energy
# 2.3497216111211614   development
# 2.344797705008305   government
# 1.917480395923594   icelandic
# 1.6559905121322647   country
# 1.6110401290399305   sustainable
# 1.6017553141477372   challenges
# 1.4373322533612791   geothermal
# 1.369211313118054   sdgs
# 1.3629873551719571   report
# 1.3447101966431427   states
# 1.3276321998878535   success
# 1.3146367273960702   transition
# 1.3052431394929775   work
# 1.2915422640916494   source
# 1.2908581687845815   countries
# 1.2860380200609487   climate
# 1.2847728145807387   waste
# 1.2657814573172343   change
# 1.2395811569405657   regard
# 1.2276773853904785   resources
# 1.2140252969619687   factors
# 1.2063105050097196   national
# 1.2016760956408774   action
#
# # TOPIC_1:
# 1.6283148171936737   program
# 1.4907753450067858   china
# 1.3754068878331773   president
# 1.3284217119528436   greenland
# 1.3000209777512   sustainability
# 1.253344587999512   blue
# 1.2056239071137926   energy
# 1.1933825197749512   development
# 1.1823641769980364   rare
# 1.1778999897070672   world
# 1.15196371040881   aquaculture
# 1.1487587805516626   plan
# 1.142699309962958   salmon
# 1.1409686375686927   respect
# 1.1342869514273672   lagoon
# 1.112228415087884   used
# 1.106588252646354   iceland
# 1.088244892170722   quotas
# 1.0743976675607438   global
# 1.0696865125473165   geothermal
# 1.0618121675191312   time
# 1.05454468446804   students
# 1.051086709607748   sustainable
# 1.047085268821172   industry
# 1.0464163906351924   day
#
# # TOPIC_2:
# 5.361203807009664   health
# 3.640065607267969   iceland
# 2.3819560492613117   countries
# 2.0354262548340816   president
# 1.8837413973909731   global
# 1.733077936659858   member
# 1.681959552601747   general
# 1.648868777936597   tourism
# 1.636525340129752   director
# 1.5988421370250312   world
# 1.560032579227049   women
# 1.549353441901702   country
# 1.5368625208837263   small
# 1.5169925420620174   ministry
# 1.4698777745440736   development
# 1.4211363385944384   2020
# 1.3923262086364525   354
# 1.3918991735704194   minister
# 1.369928383888974   initiative
# 1.3625212787416332   2013
# 1.3562525445246714   international
# 1.3549821943444678   founder
# 1.3511600854120187   data
# 1.3480272487812788   want
# 1.3467436697545658   town
# 1.3059555884163518   time
# 1.2661042310052306   make
# 1.2537220278031909   nature
# 1.248278251871847   government
# 1.2301326467697762   country
# 1.2206130298386106   renewable
# 1.1991638602014723   icelandic
# 1.1876579981261561   landscape
# 1.1579489106001475   easy
# 1.155005155921848   sustainability
# 1.1522857840518532   new
#
# # TOPIC_12:
# 180.7207261469917   iceland
# 56.924147554607316   sustainable
# 52.768174731028544   country
# 48.25111854799111   energy
# 45.8382977528517   icelandic
# 43.42451319431256   geothermal
# 42.824298696757076   development
# 38.11846811156301   tourism
# 36.48802147615678   government
# 31.329918663186312   world
# 25.247893833718067   environment
# 23.140368743243965   climate
# 21.352381418806246   countries
# 21.179660318579884   years
# 20.84878866499177   resources
# 20.69550581543919   land
# 20.160598162150837   new
# 19.924016158108586   international
# 19.915739876548063   year
# 19.693083415062457   people
# 19.691907332594138   national
# 19.573194776824042   change
# 18.800955695475466   use
# 18.62370067716951   marine
# 18.372785069730163   power
#
# # TOPIC_13:
# 19.93386851727166   program
# 19.87344091719343   day
# 17.61792503715032   iceland
# 16.08018393554716   students
# 14.885239590976653   energy
# 8.431556239281024   spot
# 8.25029823202932   make
# 7.771520778755013   pay
# 7.152050432991318   programs
# 7.053837817477542   green
# 6.942595571903556   geothermal
# 6.7161187428698845   breakfast
# 6.426470112934867   time
# 6.4140630164233094   sustainability
# 6.36297400938255   renewable
# 6.342690703599642   lunch
# 6.105736661761484   development
# 6.0046941102963665   course
# 5.996521059373963   power
# 5.782834356682082   learn
# 5.762935415096791   easy
# 5.528702265150422   reykjavik
# 5.2478719162015395   community
# 5.081027283101916   university
# 5.07685125629429   seen
#
# # TOPIC_14:
# 3.411370390048105   iceland
# 2.2258268543061184   students
# 1.9770163102436007   energy
# 1.826439933414986   geothermal
# 1.7758811910857   reykjavik
# 1.7220838609100295   year
# 1.5464528476206645   development
# 1.499918460425782   sustainable
# 1.4567649302977157   new
# 1.4385296884624603   program
# 1.4140237683845942   world
# 1.402198332010306   greenland
# 1.381649727200328   school
# 1.3567165882932768   university
# 1.3369368178436205   read
# 1.3135677583058858   msc
# 1.2562496906061382   industry
# 1.2263251337940702   arctic
# 1.2247478762088895   government
# 1.2143563947261775   summer
# 1.167045414842354   day
# 1.1599461485895686   second
# 1.1512717978400575   research
# 1.1415078587549388   work
# 1.133001303311424   current
#         topic         word    weight
# 0     TOPIC_0      iceland  4.401948
# 1     TOPIC_0       energy  2.452821
# 2     TOPIC_0  development  2.349722
# 3     TOPIC_0   government  2.344798
# 4     TOPIC_0    icelandic  1.917480
# ..        ...          ...       ...
# 370  TOPIC_14          day  1.167045
# 371  TOPIC_14       second  1.159946
# 372  TOPIC_14     research  1.151272
# 373  TOPIC_14         work  1.141508
# 374  TOPIC_14      current  1.133001
#
# [375 rows x 3 columns]

# %%
# COMPUTE DOC x TOPIC RELATIONS (network)
# We create a data frame to store the content. It looks like a matrix.
df_matrix_style = pd.DataFrame(columns=['doc']+[("TOPIC_"+str(i)) for i in range(0,number_topics)])

# We create a second data frame with the same data. It looks like a list.
# Depending on what you want to do, one or the other are most convenient.
df_list_style = pd.DataFrame(columns=['doc', 'topic', 'weight'])

doc_topic = lda.transform(tf)
docs = list(documents_dictionary.keys())
topic_index = {}
i1 = 0
i2 = 0
for j in range(len(docs)):
    key = docs[j]
    topic_weights = list(doc_topic[j])
    
    # Index
    topic_index[key] = topic_weights
    
    # Matrix style
    df_matrix_style.loc[i1] = [key]+topic_weights
    i1 = i1+1
    
    # List style
    for k, w in enumerate(topic_weights):
        df_list_style.loc[i2] = [key, "TOPIC_"+str(k), w]
        i2 = i2+1

print("Done.")
# Out:
# Done.

# %%
# Output articles & topics, matrix style, to check that it works:
df_matrix_style
# Out:
#                               doc   TOPIC_0   TOPIC_1   TOPIC_2   TOPIC_3  \
# 0                   icelandreview  0.000148  0.000148  0.000148  0.000148
# 1                             fao  0.033333  0.033333  0.033333  0.033333
# 2              scientificamerican  0.000141  0.000141  0.000141  0.000141
# 3                     theguardian  0.002469  0.002469  0.002469  0.002469
# 4                          unicef  0.001361  0.001361  0.001361  0.001361
# 5                        newsweek  0.000163  0.000163  0.000163  0.000163
# 6                         weforum  0.000117  0.000117  0.000117  0.000117
# 7                      government  0.000071  0.000071  0.000071  0.000071
# 8                         iceland  0.000172  0.000172  0.000172  0.000172
# 9                  guidetoiceland  0.000026  0.000026  0.000026  0.000026
# 10                        thewire  0.000098  0.000098  0.000098  0.000098
# 11                           wipo  0.016667  0.016667  0.016667  0.016667
# 12                            who  0.000328  0.000328  0.353740  0.000328
# 13                            ruv  0.000612  0.000612  0.000612  0.000612
# 14                     euobserver  0.000463  0.000463  0.000463  0.000463
# 15                      worldbank  0.003509  0.003509  0.003509  0.003509
# 16                        nytimes  0.000131  0.000131  0.000131  0.000131
# 17                      prospects  0.000153  0.000153  0.000153  0.000153
# 18                      aljazeera  0.000327  0.000327  0.000327  0.000327
# 19                  sjavarklasinn  0.002020  0.002020  0.002020  0.002020
# 20             nationalgeographic  0.000335  0.000335  0.000335  0.000335
# 21                            cia  0.000044  0.000044  0.000044  0.000044
# 22                thegreenprogram  0.000026  0.000026  0.000026  0.000026
# 23                         europa  0.000417  0.000417  0.000417  0.000417
# 24                             hi  0.002564  0.002564  0.002564  0.002564
# 25                 matadornetwork  0.000163  0.000163  0.000163  0.000163
# 26  salmon-from-the-faroe-islands  0.000419  0.000419  0.000419  0.000419
# 27                             ru  0.000304  0.000304  0.000304  0.000304
# 28              circularsolutions  0.000647  0.000647  0.000647  0.506898
# 29                      hihostels  0.002778  0.002778  0.472423  0.002778
# 30           blueandgreentomorrow  0.000201  0.000201  0.000201  0.000201
# 31                     bluelagoon  0.000312  0.000312  0.000312  0.000312
# 32                   eco-business  0.000144  0.000144  0.000144  0.000144
# 33                  hiddeniceland  0.000110  0.000110  0.000110  0.000110
# 34                             un  0.000009  0.000009  0.000009  0.000009
# 35                       huffpost  0.000123  0.000123  0.000123  0.000123
0.000009  0.000009  0.000009  0.000009  0.000009  0.000009  0.000009
# 35  0.000123  0.000123  0.000123  0.000123  0.000123  0.000123  0.000123
# 36  0.001626  0.001626  0.001626  0.001626  0.001626  0.001626  0.001626
# 37  0.001802  0.001802  0.001802  0.001802  0.001802  0.001802  0.001802
# 38  0.000054  0.000054  0.000054  0.000054  0.000054  0.000054  0.000054
# 39  0.000422  0.000422  0.000422  0.000422  0.000422  0.000422  0.000422
#
#     TOPIC_11  TOPIC_12  TOPIC_13  TOPIC_14
# 0   0.000148  0.997921  0.000148  0.000148
# 1   0.033333  0.533332  0.033333  0.033333
# 2   0.000141  0.998023  0.000141  0.000141
# 3   0.002469  0.965432  0.002469  0.002469
# 4   0.001361  0.730233  0.001361  0.001361
# 5   0.000163  0.000163  0.000163  0.000163
# 6   0.000117  0.047288  0.000117  0.000117
# 7   0.000071  0.999010  0.000071  0.000071
# 8   0.000172  0.997588  0.000172  0.000172
# 9   0.000026  0.999630  0.000026  0.000026
# 10  0.000098  0.998623  0.000098  0.000098
# 11  0.016667  0.766666  0.016667  0.016667
# 12  0.000328  0.641990  0.000328  0.000328
# 13  0.000612  0.000612  0.000612  0.000612
# 14  0.000463  0.993519  0.000463  0.000463
# 15  0.003509  0.950877  0.003509  0.003509
# 16  0.000131  0.998163  0.000131  0.000131
# 17  0.000153  0.976365  0.021642  0.000153
# 18  0.000327  0.154772  0.000327  0.000327
# 19  0.002020  0.971717  0.002020  0.002020
# 20  0.000335  0.995310  0.000335  0.000335
# 21  0.000044  0.324794  0.000044  0.000044
# 22  0.000026  0.000026  0.999633  0.000026
# 23  0.000417  0.994167  0.000417  0.000417
# 24  0.002564  0.485225  0.481442  0.002564
# 25  0.000163  0.997724  0.000163  0.000163
# 26  0.000419  0.994130  0.000419  0.000419
# 27  0.000304  0.741275  0.254767  0.000304
# 28  0.000647  0.484688  0.000647  0.000647
# 29  0.002778  0.002778  0.491465  0.002778
# 30  0.000201  0.997180  0.000201  0.000201
# 31  0.000312  0.995639  0.000312  0.000312
# 32  0.000144  0.997980  0.000144  0.000144
# 33  0.000110  0.998462  0.000110  0.000110
# 34  0.000009  0.999870  0.000009  0.000009
# 35  0.000123  0.998275  0.000123  0.000123
# 36  0.001626  0.648241  0.266304  0.001626
# 37  0.001802  0.974775  0.001802  0.001802
# 38  0.000054  0.000054  0.000054  0.000054
# 39  0.000422  0.994093  0.000422  0.000422

# %%
# Output articles & topics, list style, to check that it works:
df_list_style
# Out:
#                doc     topic    weight
# 0    icelandreview   TOPIC_0  0.000148
# 1    icelandreview   TOPIC_1  0.000148
# 2    icelandreview   TOPIC_2  0.000148
# 3    icelandreview   TOPIC_3  0.000148
# 4    icelandreview   TOPIC_4  0.000148
# ..             ...       ...       ...
# 595           oecd  TOPIC_10  0.000422
# 596           oecd  TOPIC_11  0.000422
# 597           oecd  TOPIC_12  0.994093
# 598           oecd  TOPIC_13  0.000422
# 599           oecd  TOPIC_14  0.000422
#
# [600 rows x 3 columns]

# %%
# DOWNLOAD LDA results
# Note: these files can be used in Tableau or Table2Net to build various visualizations.

topics_df.to_csv("03-a LDA topics and their words.csv", index = False, encoding='utf-8')
# df_matrix_style.to_csv("03-? LDA actors and topics matrix.csv", index = False, encoding='utf-8')
df_list_style.to_csv("03-b LDA actors and topics list style.csv", index = False, encoding='utf-8')

# %%
# ENRICH FILE (and monitor new version)
for topic_id, topic in enumerate(lda.components_):
    colname = "topic_"+str(topic_id)
    values = []
    for index, row in df.iterrows():
        key = row['Id']
        if key in topic_index:
            val = topic_index[key][topic_id]
        else:
            val = 0
        values.append(val)
    df.insert(len(df.columns), colname, values)
df
# Out:
#                                Id  \
# 0                            unep
# 1                   icelandreview
# 2                             fao
# 3              scientificamerican
# 4                     theguardian
# 5                          unicef
# 6                        newsweek
# 7                         weforum
# 8                      government
# 9                         iceland
# 10                 guidetoiceland
# 11                        thewire
# 12                           wipo
# 13                            who
# 14                            ruv
# 15                     euobserver
# 16                      worldbank
# 17                        nytimes
# 18                      prospects
# 19                      aljazeera
# 20                  sjavarklasinn
# 21             nationalgeographic
# 22                 arctic-council
# 23                            cia
# 24                thegreenprogram
# 25                         europa
# 26                             hi
# 27                 matadornetwork
# 28  salmon-from-the-faroe-islands
# 29                             ru
# 30              circularsolutions
# 31                      hihostels
# 32           blueandgreentomorrow
# 33                     bluelagoon
# 34                   eco-business
# 35                  hiddeniceland
# 36                             un
# 37                       huffpost
# 38                       siceland
# 39                        matorka
# 40                 reykjavikforum
# 41                           oecd
#
#                                                  urls  \
# 0   https://www.unep.org/news-and-stories/story/ic...
# 1   https://www.icelandreview.com/news/environment...
# 2   http://www.fao.org/countryprofiles/index/en/?i...
# 3   https://www.scientificamerican.com/article/ice...
# 4   https://www.theguardian.com/environment/galler...
# 5   https://www.unicef.org/infobycountry/iceland.h...
# 6   https://www.newsweek.com/environmental-effects...
# 7   https://www.weforum.org/agenda/2017/11/why-ice...
# 8   https://www.government.is/topics/foreign-affai...
# 9   https://www.iceland.is/the-big-picture/nature-...
# 10  https://guidetoiceland.is/history-culture/heal...
# 11  https://science.thewire.in/environment/an-arct...
# 12  https://www.wipo.int/directory/en/details.jsp?...
# 13  https://www.euro.who.int/en/countries/iceland ...
# 14                               https://www.ruv.is/
# 15     https://euobserver.com/beyond-brussels/127983
# 16      https://www.worldbank.org/en/country/iceland
# 17  https://www.nytimes.com/2019/08/09/business/ic...
# 18  https://www.prospects.ac.uk/jobs-and-work-expe...
# 19  https://www.aljazeera.com/news/2021/3/20/icela...
# 20                   http://www.sjavarklasinn.is/en/
# 21  https://www.nationalgeographic.com/science/art...
# 22                    https://arctic-council.org/en/
# 23  https://www.cia.gov/the-world-factbook/countri...
# 24  https://thegreenprogram.com/programs/iceland h...
# 25  https://www.fch.europa.eu/news/iceland-road-su...
# 26  https://english.hi.is/sustainability_and_envir...
# 27  https://matadornetwork.com/change/iceland-gree...
# 28  http://salmon-from-the-faroe-islands.com/susta...
# 29                              https://en.ru.is/ise
# 30                 https://www.circularsolutions.is/
# 31         https://www.hihostels.com/hostels/selfoss
# 32  https://blueandgreentomorrow.com/features/sust...
# 33   https://www.bluelagoon.com/about/sustainability
# 34  https://www.eco-business.com/opinion/the-four-...
# 35  https://hiddeniceland.is/sustainable-tourism-i...
# 36  https://sustainabledevelopment.un.org/memberst...
# 37  https://www.huffpost.com/entry/sustainable-tou...
# 38              https://siceland.com/sustainability/
# 39                https://matorka.is/sustainability/
# 40                    https://reykjavikforum.global/
# 41  http://www.oecd.org/environment/country-review...
#
#                                                  text  \
# 0                                                  .
# 1   Icelanders have become increasingly aware of a...
# 2   SEE ALL PUBLICATIONS chevron_right\nThematic p...
# 3   REYKJAVIK, ICELAND—Snorri Sturlusson is the fi...
# 4   Iceland's innovations to reach net-zero – in p...
# 5   We’re building a new UNICEF.org.\nAs we swap o...
# 6   The Environmental Effects of Iceland's Volcano...
# 7   For Icelanders, it is a source of pride to be ...
# 8   International Development Cooperation\nInterna...
# 9   Ministry for the Environment and Natural Resou...
# 10  Top things to do in Iceland\nBook your complet...
# 11  Aerial view of the Kringlerne rare Earth depos...
# 12               Use of WIPO Services and Products .
# 13  Iceland\nIn Iceland, the Minister of Health an...
# 14  Í loftinu\nNýjast\nESB í mál við AstraZeneca\n...
# 15  Iceland says final EU goodbye\nBy Eric Maurice...
# 16  International migration to fall in 2020 for th...
# 17  What Worries Iceland? A World Without Ice. It ...
# 18  Work in Iceland\nNot the most obvious place fo...
# 19  Popular glaciers are melting so fast that guid...
# 20  150% growth in startups\nNew analysis by the I...
# 21  Is Iceland Really Green and Greenland Really I...
# 22                                                 .
# 23  Introduction\nBackground\nSettled by Norwegian...
# 24  Why Iceland\nAs one of the greenest countries ...
# 25  Iceland on the road to sustainable transport\n...
# 26  Sustainability and Environment\nThe University...
# 27  After economic collapse, here’s how Iceland re...
# 28  Sustainability has become the hallmark of Faro...
# 29  Our Programmes:\nNews and Events\nMSc Thesis: ...
# 30  CIRCULAR Solutions is a sustainability & ESG\n...
# 31  Welcome to our hostel\nSelfoss is a lovely tow...
# 32  No list of inspirational sustainable cities wo...
# 33  About us\nSustainability\nThe genetic cornerst...
# 34  Since the 1970s, economic development has help...
# 35  Sustainable tourism in Iceland is a hot topic ...
# 36  Iceland is fully committed to implementing Age...
# 37  Last week I had the pleasure of speaking at th...
# 38  Know More\nSustainability\nSUSTAINABILITY\nOur...
# 39  Sustainability\nRampant over-fishing and a wor...
# 40  The Forum is now Live\nTo access the Forum ple...
# 41   . Iceland has one of the world’s most pristin...
#
#     discourse: Climate change  discourse: Environment  \
# 0                       False                   False
# 1                        True                    True
# 2                       False                   False
# 3                       False                    True
# 4                       False                    True
# 5                        True                   False
# 6                       False                    True
# 7                       False                   False
# 8                       False                   False
# 9                       False                    True
# 10                      False                   False
# 11                      False                    True
# 12                      False                   False
# 13                       True                   False
# 14                       True                   False
# 15                       True                   False
# 16                       True                   False
# 17                       True                   False
# 18                       True                   False
# 19                       True                   False
# 20                      False                   False
# 21                       True                   False
# 22                      False                   False
# 23                       True                   False
# 24                      False                   False
# 25                      False                   False
# 26                      False                   False
# 27                      False                   False
# 28                      False                   False
# 29                      False                   False
# 30                      False                   False
# 31                      False                   False
# 32                      False                   False
# 33                      False                   False
# 34                      False                   False
# 35                      False                   False
# 36                       True                   False
# 37                      False                   False
# 38                      False                   False
# 39                      False                   False
# 40                      False                   False
# 41                      False                    True
#
#     discourse: Green growth  discourse: Sustainability  discourse: UN SDGs  \
# 0                     False                      False                True
# 1                     False                      False               False
# 2                     False                      False                True
# 3                     False                      False               False
# 4                     False                      False               False
# 5                     False                      False                True
# 6                     False                      False               False
# 7                     False                      False                True
# 8                      True                      False                True
# 9                      True                      False               False
# 10                     True                       True                True
# 11                    False                      False               False
# 12                    False                      False                True
# 13                    False                      False                True
# 14                    False                      False               False
# 15                    False                      False               False
# 16                    False                      False               False
# 17                    False                      False               False
# 18                    False                      False               False
# 19                    False                      False               False
# 20                    False                      False                True
# 21                    False                      False               False
# 22                    False                      False                True
# 23                    False                      False               False
# 24                     True                       True                True
# 25                     True                      False               False
# 26                    False                       True               False
# 27                     True                      False               False
# 28                    False                       True               False
# 29                    False                       True               False
# 30                     True                      False               False
# 31                    False                      False                True
# 32                     True                       True               False
# 33                    False                       True               False
# 34                     True                      False               False
# 35                    False                       True               False
# 36                     True                       True                True
# 37                    False                       True               False
# 38                    False                       True               False
# 39                    False                       True               False
# 40                    False                      False                True
# 41                    False                      False               False
#
#     area: Arctic  area: Arctic Norway  ...   topic_5   topic_6   topic_7  \
# 0          False                False  ...  0.000000  0.000000  0.000000
# 1          False                False  ...  0.000148  0.000148  0.000148
# 2          False                False  ...  0.033333  0.033333  0.033333
# 3          False                False  ...  0.000141  0.000141  0.000141
# 4          False                False  ...  0.002469  0.002469  0.002469
# 5          False                False  ...  0.252080  0.001361  0.001361
# 6          False                False  ...  0.997718  0.000163  0.000163
# 7          False                False  ...  0.000117  0.951194  0.000117
# 8          False                False  ...  0.000071  0.000071  0.000071
# 9          False                False  ...  0.000172  0.000172  0.000172
# 10         False                False  ...  0.000026  0.000026  0.000026
# 11         False                False  ...  0.000098  0.000098  0.000098
# 12         False                False  ...  0.016667  0.016667  0.016667
# 13         False                False  ...  0.000328  0.000328  0.000328
# 14         False                False  ...  0.000612  0.000612  0.991437
# 15         False                False  ...  0.000463  0.000463  0.000463
# 16         False                False  ...  0.003509  0.003509  0.003509
# 17         False                False  ...  0.000131  0.000131  0.000131
# 18         False                False  ...  0.000153  0.000153  0.000153
# 19         False                False  ...  0.000327  0.840979  0.000327
# 20         False                False  ...  0.002020  0.002020  0.002020
# 21         False                False  ...  0.000335  0.000335  0.000335
# 22         False                False  ...  0.000000  0.000000  0.000000
# 23         False                False  ...  0.000044  0.000044  0.000044
# 24         False                False  ...  0.000026  0.000026  0.000026
# 25         False                False  ...  0.000417  0.000417  0.000417
# 26         False                False  ...  0.002564  0.002564  0.002564
# 27         False                False  ...  0.000163  0.000163  0.000163
# 28         False                False  ...  0.000419  0.000419  0.000419
# 29         False                False  ...  0.000304  0.000304  0.000304
# 30         False                False  ...  0.000647  0.000647  0.000647
# 31         False                False  ...  0.002778  0.002778  0.002778
# 32         False                False  ...  0.000201  0.000201  0.000201
# 33         False                False  ...  0.000312  0.000312  0.000312
# 35  0.000110  0.000110  0.000110  0.000110  0.998462  0.000110  0.000110
# 36  0.000009  0.000009  0.000009  0.000009  0.999870  0.000009  0.000009
# 37  0.000123  0.000123  0.000123  0.000123  0.998275  0.000123  0.000123
# 38  0.001626  0.001626  0.001626  0.001626  0.648241  0.266304  0.001626
# 39  0.001802  0.001802  0.001802  0.001802  0.974775  0.001802  0.001802
# 40  0.000054  0.000054  0.000054  0.000054  0.000054  0.000054  0.000054
# 41  0.000422  0.000422  0.000422  0.000422  0.994093  0.000422  0.000422
#
# [42 rows x 31 columns]

# %%
# DOWNLOAD ENRICHED FILE
df.drop(columns=[text_col_name]).to_csv("04 Actors and their topics.csv", index=False)

# %% [markdown]
# # Export LDA networks

# %%
# Export network of words and topics
import networkx as nx
G = nx.Graph()
for index, row in topics_df.iterrows():
    topic = 'T_'+str(row['topic'])
    word = 'W_'+str(row['word'])
    w = row['weight']
    
    G.add_edge(topic, word)
    G[topic][word]['weight'] = w
    
    G.nodes[topic]['label'] = str(row['topic'])
    G.nodes[topic]['type'] = 'topic'
    G.nodes[word]['label'] = str(row['word'])
    G.nodes[word]['type'] = 'word'
    
nx.write_gexf(G, "05 Words and topics.gexf")

# %%
# Export network of actors and topics
import networkx as nx
threshold = 0.001
G = nx.Graph()
for index, row in df_list_style.iterrows():
    topic = 'T_'+str(row['topic'])
    actor = 'A_'+str(row['doc'])
    w = row['weight']
    
    if w > threshold:
        G.add_edge(topic, actor)
        G[topic][actor]['weight'] = w

        G.nodes[topic]['label'] = str(row['topic'])
        G.nodes[topic]['type'] = 'topic'
        G.nodes[actor]['label'] = str(row['doc'])
        G.nodes[actor]['type'] = 'actor'
    
nx.write_gexf(G, "06 Actors and topics.gexf")

# %% [markdown]
# # UMAP after the topics

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import umap

# %%
# Load data
df = pd.read_csv("04 Actors and their topics.csv")
df = df.dropna()

# %%
# Prepare data
reducer = umap.UMAP()
umap_data = df[
    [
        "topic_0",
        "topic_1",
        "topic_2",
        "topic_3",
        "topic_4",
        "topic_5",
        "topic_6",
        "topic_7",
        "topic_8",
        "topic_9",
        "topic_10",
        "topic_11",
        "topic_12",
        "topic_13",
        "topic_14"
    ]
].values
scaled_umap_data = StandardScaler().fit_transform(umap_data)

# %%
# Compute embedding
embedding = reducer.fit_transform(scaled_umap_data)
embedding.shape
# Out:
# (42, 2)

# %%
# Monitor embedding
plt.scatter(
    embedding[:, 0],
    embedding[:, 1]
)
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection of the dataset', fontsize=24)
# Out:
# Text(0.5, 1.0, 'UMAP projection of the dataset')

# %%
# Enrich source and download
xvalues = []
yvalues = []
for index, row in df.iterrows():
    coord = embedding[index]
    xvalues.append(coord[0])
    yvalues.append(coord[1])
df.insert(len(df.columns), 'X-UMAP', xvalues)
df.insert(len(df.columns), 'Y-UMAP', yvalues)

df.to_csv("07 Actors with topics + UMAP layout.csv", index = False, encoding='utf-8')
