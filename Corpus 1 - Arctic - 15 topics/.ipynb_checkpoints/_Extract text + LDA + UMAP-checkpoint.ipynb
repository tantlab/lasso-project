# %%
# SETTINGS

number_topics = 15

# %% [markdown]
# # Filter
#
# Here we assume that the source file already contains the text, as it's a subcorpus.

# %%
# Filter the input file
import pandas as pd

df = pd.read_csv('00 source data (urls).csv')
df.fillna('', inplace=True)

# /!\ FILTERING
df = df[df['area'] == 'arctic']

df.to_csv("01 data filtered.csv", index = False, encoding='utf-8')

df
# Out:
#      result # search engine       discourse    area         domain actor name  \
# 0          48          bing     environment  arctic            fas
# 1          55          bing     environment  arctic            fas
# 2          47          bing     environment  arctic  foreignpolicy
# 3          22          bing     environment  arctic         europa
# 4           7          bing     environment  arctic        weforum
# ..        ...           ...             ...     ...            ...        ...
# 396       481          bing  sustainability  arctic          wiley
# 401       476          bing  sustainability  arctic  arctickingdom
# 407       495          bing  sustainability  arctic            awi
# 415       448          bing  sustainability  arctic        booking
# 476       499          bing  sustainability  arctic        booking
#
#                                          article title  \
# 0    Changes in the Arctic: Background and Issues f...
# 1    Changes in the Arctic: Background and Issues f...
# 2    Forget Greenland, the Faroe Islands Are the Ne...
# 3    Arctic - International Issues - Environment - ...
# 4    What the melting Arctic means for the world | ...
# ..                                                 ...
# 396  Arctic Sea Ice in CMIP6 - Notz - 2020 - Geophy...
# 401  10 Fun Facts About The Arctic Fox | Arctic Kin...
# 407                                 Arctic Ocean - AWI
# 415      Hotel Arctic, Ilulissat – Updated 2021 Prices
# 476  Arctic TreeHouse Hotel, Rovaniemi – Updated 20...
#
#                                            article url  \
# 0              https://fas.org/sgp/crs/misc/R41153.pdf
# 1              https://fas.org/sgp/crs/misc/R41153.pdf
# 2    https://foreignpolicy.com/2020/12/07/forget-gr...
# 3    https://ec.europa.eu/environment/international...
# 4    https://www.weforum.org/agenda/2020/01/arctic-...
# ..                                                 ...
# 396  https://agupubs.onlinelibrary.wiley.com/doi/fu...
# 401  https://arctickingdom.com/10-fun-facts-about-a...
# 407      https://www.awi.de/en/focus/arctic-ocean.html
# 415       https://www.booking.com/hotel/gl/arctic.html
# 476  https://www.booking.com/hotel/fi/arctic-treeho...
#
#                                    article description  \
# 0    The geopolitical environment for the Arctic ha...
# 1    The geopolitical environment for the Arctic ha...
# 2    12/7/2020 · With the Arctic ice melting, and t...
# 3    The Arctic is a key driver of the world ocean ...
# 4    3/23/2021 · The Arctic is an incredibly import...
# ..                                                 ...
# 396  4/17/2020 · To address this issue when analyzi...
# 401  2. The Arctic fox has the warmest pelt of any ...
# 407  The Arctic sea-ice extent is the lowest it’s e...
# 415  Modern furnishings and décor are featured in e...
# 476  Santa Claus Village - Main Post Office is 1.2 ...
#
#      total nr of results (best guess)  ...  \
# 0                            30600000  ...
# 1                            30600000  ...
# 2                            30600000  ...
# 3                            30600000  ...
# 4                            30600000  ...
# ..                                ...  ...
# 396                           6560000  ...
# 401                           6560000  ...
# 407                           6560000  ...
# 415                           6560000  ...
# 476                           6560000  ...
#
#                                          canonical_url  \
# 0
# 1
# 2    https://foreignpolicy.com/2020/12/07/forget-gr...
# 3
# 4    https://www.weforum.org/agenda/2020/01/arctic-...
# ..                                                 ...
# 396
# 401  https://arctickingdom.com/10-fun-facts-about-a...
# 407      https://www.awi.de/en/focus/arctic-ocean.html
# 415  https://www.booking.com/hotel/gl/arctic.en-gb....
# 476  https://www.booking.com/hotel/fi/arctic-treeho...
#
#                                                  title  \
# 0
# 1
# 2    Forget Greenland, There’s a New Strategic Gate...
# 3                                               Arctic
# 4          What the melting Arctic means for the world
# ..                                                 ...
# 396
# 401  10 Fun Facts About The Arctic Fox | Arctic Kin...
# 407                                       Arctic Ocean
# 415            ★★★★ Hotel Arctic, Ilulissat, Greenland
# 476   ★★★★★ Arctic TreeHouse Hotel, Rovaniemi, Finland
#
#                                            description  \
# 0
# 1
# 2    The Faroe Islands have a history of trading wi...
# 3    The EU participates in international efforts t...
# 4    The Arctic is turning from white to blue, abso...
# ..                                                 ...
# 396
# 401  While polar bears are the most popular animals...
# 407  The Arctic Ocean is one of the early warning s...
# 415  Located on the UNESCO-listed Ilulissat Icefjor...
# 476  Located near SantaPark, Arctic TreeHouse Hotel...
#
#                                            raw_content comments  \
# 0
# 1
# 2    Jenis av Rana, foreign minister of the Faroe I...
# 3    Accessibility tools\nService tools\nLanguage s...
# 4    - Since the 1970s, we have lost 75% of the vol...
# ..                                                 ...      ...
# 396
# 401  By: Liz Carino\nWhile polar bears are the most...
# 407  Due to construction work in the sea, shipping,...
# 415  Hotel Hotel Arctic\nMittarfimmut Aqq. B1128, 3...
# 476  Hotel Arctic TreeHouse Hotel\nTarvantie 3 Arct...
#
#                     author                                         categories  \
# 0
# 1
# 2    Regin Winther Poulsen  Morning Brief|Argument|Argument|Report|Report|...
# 3
# 4            Robin Pomeroy                                             Arctic
# ..                     ...                                                ...
# 396
# 401            Paul Brunet                                         arctic fox
# 407
# 415
# 476
#
#                                                   tags        date  \
# 0
# 1
# 2                                                       2020-12-07
# 3    environment|international|cooperation|arctic|f...
# 4    World Economic Forum|WEF|Davos|Klaus Schwab|gl...  2020-01-23
# ..                                                 ...         ...
# 396
# 401                                                     2018-05-06
# 407                        Arctic Ocean|Polar research
# 415      Hotel Arctic|Ilulissat|Greenland|hotel|Hotels  2020-04-06
# 476  Arctic TreeHouse Hotel|Rovaniemi|Finland|R:Lap...  2020-04-06
#
#                                               sitename
# 0
# 1
# 2                                       Foreign Policy
# 3    International Issues - Environment - European ...
# 4                                 World Economic Forum
# ..                                                 ...
# 396
# 401                                     Arctic Kingdom
# 407                                                AWI
# 415                                        Booking.com
# 476                                        Booking.com
#
# [381 rows x 29 columns]

# %% [markdown]
# # Group content by actor

# %%
actor_dict = {}
for index, row in df.iterrows():
    if row['actor name']:
        actor_id = row['actor name']
    else:
        actor_id = row['domain']
    if actor_id in actor_dict:
        actor_obj = actor_dict[actor_id]
    else:
        actor_obj = {}
        actor_obj['Id'] = actor_id
        actor_obj['urls'] = ''
        actor_obj['text'] = ''
        actor_obj['discourse: Climate change'] = 'False'
        actor_obj['discourse: Environment'] = 'False'
        actor_obj['discourse: Green growth'] = 'False'
        actor_obj['discourse: Sustainability'] = 'False'
        actor_obj['discourse: UN SDGs'] = 'False'
        actor_obj['area: Arctic'] = 'False'
        actor_obj['area: Arctic Norway'] = 'False'
        actor_obj['area: Extended Arctic'] = 'False'
        actor_obj['area: Faroed Islands'] = 'False'
        actor_obj['area: Greenland'] = 'False'
        actor_obj['area: Iceland'] = 'False'
        actor_obj['area: Nunavut'] = 'False'
        actor_obj['area: Sami'] = 'False'
    
    actor_obj['urls'] = actor_obj['urls'] + str(row['article url']) + ' '
    actor_obj['text'] = actor_obj['text'] + str(row['raw_content']) + ' . '

    if row['discourse'] == 'Climate change':
        actor_obj['discourse: Climate change'] = 'True'
    if row['discourse'] == 'environment':
        actor_obj['discourse: Environment'] = 'True'
    if row['discourse'] == 'green growth':
        actor_obj['discourse: Green growth'] = 'True'
    if row['discourse'] == 'sustainability':
        actor_obj['discourse: Sustainability'] = 'True'
    if row['discourse'] == 'UN SDGs':
        actor_obj['discourse: UN SDGs'] = 'True'
    if row['area'] == 'arctic':
        actor_obj['area: Arctic'] = 'True'
    if row['area'] == 'arctic norway':
        actor_obj['area: Arctic Norway'] = 'True'
    if row['area'] == 'extended arctic':
        actor_obj['area: Extended Arctic'] = 'True'
    if row['area'] == 'faroe islands':
        actor_obj['area: Faroed Islands'] = 'True'
    if row['area'] == 'greenland':
        actor_obj['area: Greenland'] = 'True'
    if row['area'] == 'Iceland':
        actor_obj['area: Iceland'] = 'True'
    if row['area'] == 'Nunavut':
        actor_obj['area: Nunavut'] = 'True'
    if row['area'] == 'Sami':
        actor_obj['area: Sami'] = 'True'
    
    actor_dict[actor_id] = actor_obj
print("Actor index built.")
# Out:
# Actor index built.

# %%
# DOWNLOAD ACTORS
actors_df = pd.DataFrame.from_dict(actor_dict, orient='index')
actors_df.to_csv("02 Actors with text.csv", index = False, encoding='utf-8')
actors_df
# Out:
#                           Id  \
# fas                      fas
# foreignpolicy  foreignpolicy
# europa                europa
# weforum              weforum
# harvard              harvard
# ...                      ...
# acces-arctic    acces-arctic
# eu-interact      eu-interact
# wiley                  wiley
# arctickingdom  arctickingdom
# awi                      awi
#
#                                                             urls  \
# fas            https://fas.org/sgp/crs/misc/R41153.pdf https:...
# foreignpolicy  https://foreignpolicy.com/2020/12/07/forget-gr...
# europa         https://ec.europa.eu/environment/international...
# weforum        https://www.weforum.org/agenda/2020/01/arctic-...
# harvard        https://www.hsph.harvard.edu/news/press-releas...
# ...                                                          ...
# acces-arctic                      https://www.acces-arctic.com/
# eu-interact             https://eu-interact.org/glossary/artic/
# wiley          https://agupubs.onlinelibrary.wiley.com/doi/fu...
# arctickingdom  https://arctickingdom.com/10-fun-facts-about-a...
# awi               https://www.awi.de/en/focus/arctic-ocean.html
#
#                                                             text  \
# fas                                               .  .  .  .  .
# foreignpolicy  Jenis av Rana, foreign minister of the Faroe I...
# europa         Accessibility tools\nService tools\nLanguage s...
# weforum        - Since the 1970s, we have lost 75% of the vol...
# harvard        Harvard study finds circumpolar rivers most re...
# ...                                                          ...
# acces-arctic   De-icing of the Arctic coast:new challenges an...
# eu-interact    Definitions of the ArcticDefinitions of the Ar...
# wiley                                                         .
# arctickingdom  By: Liz Carino\nWhile polar bears are the most...
# awi            Due to construction work in the sea, shipping,...
#
#               discourse: Climate change discourse: Environment  \
# fas                                True                   True
# foreignpolicy                      True                   True
# europa                             True                   True
# weforum                            True                   True
# harvard                            True                   True
# ...                                 ...                    ...
# acces-arctic                      False                  False
# eu-interact                       False                  False
# wiley                             False                  False
# arctickingdom                     False                  False
# awi                               False                  False
#
#               discourse: Green growth discourse: Sustainability  \
# fas                              True                      True
# foreignpolicy                   False                     False
# europa                           True                      True
# weforum                          True                      True
# harvard                          True                     False
# ...                               ...                       ...
# acces-arctic                    False                      True
# eu-interact                     False                      True
# wiley                           False                      True
# arctickingdom                   False                      True
# awi                             False                      True
#
#               discourse: UN SDGs area: Arctic area: Arctic Norway  \
# fas                        False         True               False
# foreignpolicy              False         True               False
# europa                      True         True               False
# weforum                     True         True               False
# harvard                    False         True               False
# ...                          ...          ...                 ...
# acces-arctic               False         True               False
# eu-interact                False         True               False
# wiley                      False         True               False
# arctickingdom              False         True               False
# awi                        False         True               False
#
#               area: Extended Arctic area: Faroed Islands area: Greenland  \
# fas                           False                False           False
# foreignpolicy                 False                False           False
# europa                        False                False           False
# weforum                       False                False           False
# harvard                       False                False           False
# ...                             ...                  ...             ...
# acces-arctic                  False                False           False
# eu-interact                   False                False           False
# wiley                         False                False           False
# arctickingdom                 False                False           False
# awi                           False                False           False
#
#               area: Iceland area: Nunavut area: Sami
# fas                   False         False      False
# foreignpolicy         False         False      False
# europa                False         False      False
# weforum               False         False      False
# harvard               False         False      False
# ...                     ...           ...        ...
# acces-arctic          False         False      False
# eu-interact           False         False      False
# wiley                 False         False      False
# arctickingdom         False         False      False
# awi                   False         False      False
#
# [159 rows x 16 columns]

# %% [markdown]
# # LDA: extract topics

# %%
import pandas as pd
# This is for text mining
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# Source file (CSV)
source_file = "02 Actors with text.csv"
text_col_name = "text"

# More features is more dimensions for each document. You should probably keep it at 1000.
no_features = 1000

# %%
# LOAD DATA
documents_dictionary = {}
df = pd.read_csv(source_file)

for index, row in df.iterrows():
    key = row['Id']
    text = str(row[text_col_name])
    if len(text)>10:
        documents_dictionary[key] = text

# %%
# COMPUTE LDA TOPICS
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents_dictionary.values())
tf_feature_names = tf_vectorizer.get_feature_names()
lda = LatentDirichletAllocation(n_components=number_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)
print("LDA topics computed.")
# Out:
# LDA topics computed.

# %%
# DISPLAY RESULTS (for monitoring)
no_top_words = 25 # How many words to keep for each topic (there may be many)

# Create a data frame for convenience (for download, actually)
topics_df = pd.DataFrame(columns=['topic','word','weight'])

# Display topics to check it works. For each topic, we only display the top words.
i = 0
for topic_idx, topic in enumerate(lda.components_):
    print("# TOPIC_%d:" % (topic_idx))
    for j in topic.argsort()[:-no_top_words - 1:-1]:
        print(str(topic[j]) + "   " + tf_feature_names[j])
        topics_df.loc[i] = ["TOPIC_"+str(topic_idx), tf_feature_names[j], topic[j]]
        i = i+1
    print(" ")

topics_df
# Out:
# # TOPIC_0:
# 1294.912474394897   line
# 1116.9773440199056   array
# 680.1745280457947   core
# 625.1965781065852   render
# 590.3210345585819   object
# 204.29920556748357   handle
# 187.7978040287149   html
# 123.74841846102193   arcticnet
# 123.32512898810964   theme
# 98.71881797409006   themes
# 98.48732452163756   195
# 98.10100782585634   437
# 85.49947345161063   view
# 76.613942697597   component
# 73.20304157394798   64
# 72.95714349493744   490
# 72.9022641475232   384
# 72.88053598129252   411
# 72.72913039444362   432
# 72.39489944026047   403
# 72.31496250573832   display
# 64.13806732676592   block
# 55.92039981849881   450
# 51.60498046149631   47
# 43.05295911243879   page
#
# # TOPIC_1:
# 22.245457144800998   room
# 20.90414038396674   arctic
# 18.582521265316462   read
# 15.574691860369402   geographical
# 15.080186608279197   vary
# 15.035690787401425   cool
# 15.012408057595653   perspectives
# 14.821888579388588   interact
# 12.443615096912755   according
# 11.934207660487063   define
# 11.72012071254362   session
# 10.396779169254659   political
# 10.082866378724459   00
# 9.94871248580734   report
# 9.779976545998467   summers
# 9.660235613218495   winters
# 9.28967682076922   latitude
# 8.354614037033906   having
# 8.13404105900742   cultural
# 7.9863850391090825   short
# 6.87111914251172   biodiversity
# 6.514125220847141   news
# 6.448361076294334   scientists
# 6.281091146479725   30
# 5.508318267580987   chair
#
# # TOPIC_2:
# 22.047623181486838   lng
# 9.285514056305512   project
# 7.10492941544458   construction
# 4.095256685997144   design
# 4.042171353824555   production
# 3.8808651838938553   arctic
# 3.644950568951864   center
# 3.3769503056673638   end
# 3.0577416595067213   capacity
# 2.8995130935633213   september
# 2.861105573182178   base
# 2.857970647462109   low
# 2.60814360922411   facilities
# 2.5755836686595392   using
# 2.55298625502044   field
# 2.5390680007459734   estimated
# 2.523677982883034   final
# 2.5078879228670905   russia
# 2.3967653572166028   2018
# 2.3676875664871124   2019
# 2.3516708622174836   diamonds
# 2.311083167395562   decision
# 2.131171902980435   investment
# 2.0125840298174427   sea
# 1.8851797275703035   october
#
# # TOPIC_3:
# 12.206743935378116   interact
# 11.935208409467716   geographical
# 11.254475589086725   vary
# 9.747867445337974   cool
# 8.835468729914163   ice
# 8.453266644922957   latitude
# 7.080168206485315   sea
# 6.801476179044756   according
# 6.688461416622974   summers
# 6.507602801120983   perspectives
# 6.4982170967291335   define
# 5.846546010292843   winters
# 5.769034792430772   having
# 5.637520753256248   arctic
# 5.159737901378363   short
# 4.871522097841583   scientists
# 4.690746341587319   news
# 3.6537226030356713   long
# 3.1957239410347076   areas
# 3.0837357231839606   scientific
# 3.03292475025579   cultural
# 2.8027782415809415   station
# 2.6834917145452573   owner
# 2.6439980198108985   political
# 2.5407233314865216   environmental
#
# # TOPIC_4:
# 759.908050911997   arctic
# 392.32833293993343   ice
# 278.3581350753097   sea
# 208.03448664251687   climate
# 180.05741535162213   ocean
# 123.9975809298726   change
# 104.1664831339326   polar
# 92.5613966074298   warming
# 82.26938677181863   global
# 75.12247642013129   research
# 74.04832312631181   year
# 71.83112144495786   data
# 71.54286023892196   marine
# 67.01119128062473   north
# 66.67075874316231   new
# 66.54736959314765   changes
# 65.47167991584722   summer
# 65.31807749663002   temperatures
# 64.90490117021334   snow
# 63.63181854299309   al
# 63.02924492683175   et
# 60.14916851178915   greenland
# 59.85105161322152   animals
# 59.73130694661145   world
# 58.939030907448576   2021
#
# # TOPIC_5:
# 13.54717222143414   arctic
# 3.649011913440649   climate
# 3.1856121076685944   world
# 3.122858086540937   products
# 2.8535315404277695   array
# 2.7804702431521955   development
# 2.627316611489516   north
# 2.499007692528325   based
# 2.4325760435340578   region
# 2.3837979799795534   line
# 2.317747328407288   norwegian
# 2.2519145575130444   canada
# 2.2264062368974287   new
# 2.222324297085595   sustainable
# 2.172908157625174   government
# 2.1178593137188235   northern
# 2.0793770295837954   change
# 2.079045770651919   marine
# 2.0730954735692104   permafrost
# 2.007096394240042   cooperation
# 2.004933520161736   norway
# 1.9933735606157237   council
# 1.9561079328466886   communities
# 1.9305357707699202   ice
# 1.8942463002393806   company
#
# # TOPIC_6:
# 51.09423610926223   diamonds
# 39.786387184949895   diamond
# 26.51771483194323   mining
# 23.702320910241106   pipes
# 22.088267983310708   ore
# 21.27281739555943   canada
# 17.27087869830531   pp
# 16.99274255237821   pipe
# 14.3196819716457   10
# 14.310981810373015   2015
# 14.064201103313213   http
# 12.908665128577724   surface
# 12.835386401882172   million
# 12.816320041550846   operations
# 12.717119127096007   production
# 12.232203334341877   rocks
# 11.50036908955741   figure
# 11.29561121717077   lake
# 11.048538108698756   area
# 11.014677270984508   year
# 11.000998142228449   rock
# 10.875733013913036   exploration
# 10.754334244563205   site
# 10.239392130804424   northwest
# 9.864496676723105   open
#
# # TOPIC_7:
# 2.208322832439591   arctic
# 1.701239478233837   north
# 1.6265869417351528   development
# 1.6086267837239145   canada
# 1.4067067705789433   climate
# 1.3978301488709655   indigenous
# 1.3824555949010635   change
# 1.3595744074631433   government
# 1.3393681138718523   northwest
# 1.3212809328553985   region
# 1.3195856648339024   territories
# 1.2544602330410275   diamonds
# 1.2059510342010629   inuit
# 1.1475971749620393   ice
# 1.1411903442606555   infrastructure
# 1.1339748934504095   people
# 1.0934606733465178   canadian
# 1.0875075656078481   territorial
# 1.0859359489929747   peoples
# 1.0839058902345389   economic
# 1.0776919775429616   international
# 1.0689921100437079   communities
# 1.064569211789279   diamond
# 1.062915276952178   greenland
# 1.0229017035993504   area
#
# # TOPIC_8:
# 21.98677453041603   clark
# 20.46563340443784   lex
# 15.670741048565562   arctic
# 11.858272870960965   season
# 8.32345595097126   permafrost
# 5.903718184646185   says
# 5.521141768260717   ice
# 4.908387900260361   climate
# 4.894712009956452   thawing
# 4.893528429973827   sea
# 4.846657977690876   world
# 4.4917359240208095   region
# 4.132593590478495   canada
# 3.706552812973064   tundra
# 3.583342628940449   time
# 3.2836085226934113   ground
# 3.223527484467407   warming
# 2.97988946790995   northern
# 2.856297220008062   indigenous
# 2.778924942219521   carbon
# 2.668697252364549   people
# 2.65008191488109   including
# 2.6003711548669863   security
# 2.5916092570246883   change
# 2.470183539203164   communities
#
# # TOPIC_9:
# 2.3846252492604587   arctic
# 2.039384694105804   ocean
# 2.001426445755592   ice
# 1.9528433256118958   climate
# 1.6069387606658367   sea
# 1.4934972505126636   eu
# 1.4142920572654358   temperature
# 1.410466313993272   acidification
# 1.4068679603677046   change
# 1.3980878001199875   model
# 1.3685587583365528   warming
# 1.258735878271738   et
# 1.2008347124188057   diamonds
# 1.183793436347254   dmi
# 1.1730470609130152   year
# 1.167155346235869   surface
# 1.16417824232068   effects
# 1.1436724348364624   data
# 1.1237324112351008   stock
# 1.1230104523612123   high
# 1.1193890921095802   economic
# 1.1107678759734676   north
# 1.1013913346644604   environmental
# 1.0951268243521473   2015
# 1.0945908745005937   al
#
# # TOPIC_10:
# 177.30413422909064   arctic
# 41.308499156918096   council
# 35.795856622846294   china
# 32.781782719316915   climate
# 28.358528936552528   region
# 25.804072535006025   policy
# 21.386269159060618   change
# 18.391604750233803   development
# 17.793457564220176   international
# 16.712463968632996   states
# 16.20289622997884   research
# 16.074836696599732   indigenous
# 15.880113469118847   security
# 15.217716842407592   work
# 14.600792315197763   meeting
# 14.444436751099738   sea
# 13.686287257928697   ocean
# 13.55952469680062   russia
# 13.385378592922445   united
# 13.026408520188633   said
# 12.95463502934255   adam
# 12.709076996722638   cooperation
# 12.528509564642889   marine
# 12.525096190361818   chairmanship
# 12.271925077441692   global
#
# # TOPIC_11:
# 1900.918792223363   arctic
# 321.6713302706341   region
# 237.49860310678704   north
# 233.75272090171913   oil
# 232.9012518157843   development
# 225.55979867710747   states
# 215.6301860061011   canada
# 211.7279672867605   russia
# 210.69815455916103   climate
# 209.5383879048393   northern
# 199.76555778431793   international
# 196.72473853191153   indigenous
# 193.57971978350287   policy
# 188.9940748432093   united
# 180.32944455335922   change
# 179.50131375739986   sea
# 174.15737089842247   research
# 172.72236978808317   security
# 165.94820393988232   council
# 158.30546529661638   new
# 153.29038978560598   china
# 150.28018485984038   economic
# 144.4913897428623   national
# 136.75667503551273   alaska
# 128.1575376395028   resources
#
# # TOPIC_12:
# 79.17466251230063   arctic
# 55.467529767470026   additional
# 52.89329579102524   research
# 47.84652227610057   nsf
# 37.77694536117819   km
# 32.29424704366603   information
# 29.732948718960248   program
# 26.804920524462414   proposals
# 25.324384455487984   gov
# 24.628875697835255   room
# 23.28372776842984   website
# 21.428585499842253   free
# 20.487982923522566   science
# 20.064422935817234   facilities
# 18.940477272086476   help
# 18.882977444519728   support
# 17.90155411106883   service
# 17.037116204313286   single
# 16.54416619811337   email
# 16.024596697408445   proposal
# 15.946310872807889   community
# 15.441448645176035   activities
# 15.322305375259521   services
# 15.20481602315386   safety
# 14.326460679652737   large
#
# # TOPIC_13:
# 1473.1785647171553   arctic
# 672.2404096834462   environmental
# 648.0872792163649   read
# 618.6274743247485   scientific
# 613.8379236339558   according
# 601.1848741266829   vary
# 592.1327153517342   political
# 586.5280312924266   scientists
# 584.9166809241424   cultural
# 574.4452246493191   geographical
# 552.0316416922458   perspectives
# 510.8904466656172   define
# 491.0462695765374   areas
# 447.11545671725224   high
# 445.32314322772055   having
# 439.3754692533477   long
# 430.03319636007814   interact
# 414.5382118510266   latitude
# 396.5969874436835   short
# 392.6988597351519   news
# 387.30301212746605   winters
# 386.0501518654404   summers
# 378.70807417230026   cool
# 277.3020182899105   station
# 255.6001167208059   research
#
# # TOPIC_14:
# 18.420813757862884   tundra
# 10.070720016200516   arctic
# 9.444133809263036   nordic
# 6.117049321013188   programme
# 5.959126885150173   ministers
# 5.3419036074366675   inuit
# 5.209559089306638   council
# 4.512767900029675   plants
# 4.257623687070948   line
# 3.921287722713096   array
# 3.235007128019686   climate
# 2.9743154805961773   development
# 2.911835449798212   region
# 2.9101868735110097   people
# 2.63267922102177   grow
# 2.6278616988179935   permafrost
# 2.4951428780535503   landscape
# 2.445011401686629   core
# 2.4364462000324916   operation
# 2.4305944663589556   ice
# 2.408235933525104   canada
# 2.368704828253111   north
# 2.3348775093278866   indigenous
# 2.1747950099128346   html
# 2.1371459095127205   www
#         topic        word       weight
# 0     TOPIC_0        line  1294.912474
# 1     TOPIC_0       array  1116.977344
# 2     TOPIC_0        core   680.174528
# 3     TOPIC_0      render   625.196578
# 4     TOPIC_0      object   590.321035
# ..        ...         ...          ...
# 370  TOPIC_14      canada     2.408236
# 371  TOPIC_14       north     2.368705
# 372  TOPIC_14  indigenous     2.334878
# 373  TOPIC_14        html     2.174795
# 374  TOPIC_14         www     2.137146
#
# [375 rows x 3 columns]

# %%
# COMPUTE DOC x TOPIC RELATIONS (network)
# We create a data frame to store the content. It looks like a matrix.
df_matrix_style = pd.DataFrame(columns=['doc']+[("TOPIC_"+str(i)) for i in range(0,number_topics)])

# We create a second data frame with the same data. It looks like a list.
# Depending on what you want to do, one or the other are most convenient.
df_list_style = pd.DataFrame(columns=['doc', 'topic', 'weight'])

doc_topic = lda.transform(tf)
docs = list(documents_dictionary.keys())
topic_index = {}
i1 = 0
i2 = 0
for j in range(len(docs)):
    key = docs[j]
    topic_weights = list(doc_topic[j])
    
    # Index
    topic_index[key] = topic_weights
    
    # Matrix style
    df_matrix_style.loc[i1] = [key]+topic_weights
    i1 = i1+1
    
    # List style
    for k, w in enumerate(topic_weights):
        df_list_style.loc[i2] = [key, "TOPIC_"+str(k), w]
        i2 = i2+1

print("Done.")
# Out:
# Done.

# %%
# Output articles & topics, matrix style, to check that it works:
df_matrix_style
# Out:
#                   doc   TOPIC_0   TOPIC_1   TOPIC_2   TOPIC_3   TOPIC_4  \
# 0                 fas  0.066667  0.066667  0.066667  0.066667  0.066667
# 1       foreignpolicy  0.000005  0.000005  0.000005  0.000005  0.000005
# 2              europa  0.000017  0.000017  0.000017  0.000017  0.164556
# 3             weforum  0.000046  0.000046  0.000046  0.000046  0.952473
# 4             harvard  0.000022  0.000022  0.000022  0.000022  0.108414
# ..                ...       ...       ...       ...       ...       ...
# 147  arctic-adventure  0.001449  0.001449  0.001449  0.001449  0.001449
# 148      acces-arctic  0.000926  0.000926  0.000926  0.000926  0.514492
# 149       eu-interact  0.000006  0.000006  0.000006  0.000006  0.000006
# 150     arctickingdom  0.000575  0.000575  0.000575  0.000575  0.991954
# 151               awi  0.000813  0.000813  0.000813  0.000813  0.988618
#
#       TOPIC_5   TOPIC_6   TOPIC_7   TOPIC_8   TOPIC_9  TOPIC_10  TOPIC_11  \
# 0    0.066667  0.066667  0.066667  0.066667  0.066667  0.066667  0.066667
# 1    0.000005  0.000005  0.000005  0.000005  0.000005  0.000005  0.999925
# 2    0.000017  0.000017  0.000017  0.000017  0.000017  0.000017  0.835217
# 3    0.000046  0.000046  0.000046  0.000046  0.000046  0.000046  0.046926
# 4    0.000022  0.000022  0.000022  0.000022  0.000022  0.000022  0.887257
# ..        ...       ...       ...       ...       ...       ...       ...
# 147  0.001449  0.001449  0.001449  0.001449  0.001449  0.001449  0.001449
# 148  0.000926  0.000926  0.000926  0.000926  0.000926  0.000926  0.436133
# 149  0.000006  0.000006  0.000006  0.000006  0.000006  0.000006  0.000006
# 150  0.000575  0.000575  0.000575  0.000575  0.000575  0.000575  0.000575
# 151  0.000813  0.000813  0.000813  0.000813  0.000813  0.000813  0.000813
#
#      TOPIC_12  TOPIC_13  TOPIC_14
# 0    0.066667  0.066667  0.066667
# 1    0.000005  0.000005  0.000005
# 2    0.000017  0.000028  0.000017
# 3    0.000046  0.000046  0.000046
# 4    0.000022  0.004064  0.000022
# ..        ...       ...       ...
# 147  0.979710  0.001449  0.001449
# 148  0.000926  0.038264  0.000926
# 149  0.000006  0.999918  0.000006
# 150  0.000575  0.000575  0.000575
# 151  0.000813  0.000813  0.000813
#
# [152 rows x 16 columns]

# %%
# Output articles & topics, list style, to check that it works:
df_list_style
# Out:
#       doc     topic    weight
# 0     fas   TOPIC_0  0.066667
# 1     fas   TOPIC_1  0.066667
# 2     fas   TOPIC_2  0.066667
# 3     fas   TOPIC_3  0.066667
# 4     fas   TOPIC_4  0.066667
# ...   ...       ...       ...
# 2275  awi  TOPIC_10  0.000813
# 2276  awi  TOPIC_11  0.000813
# 2277  awi  TOPIC_12  0.000813
# 2278  awi  TOPIC_13  0.000813
# 2279  awi  TOPIC_14  0.000813
#
# [2280 rows x 3 columns]

# %%
# DOWNLOAD LDA results
# Note: these files can be used in Tableau or Table2Net to build various visualizations.

topics_df.to_csv("03-a LDA topics and their words.csv", index = False, encoding='utf-8')
# df_matrix_style.to_csv("03-? LDA actors and topics matrix.csv", index = False, encoding='utf-8')
df_list_style.to_csv("03-b LDA actors and topics list style.csv", index = False, encoding='utf-8')

# %%
# ENRICH FILE (and monitor new version)
for topic_id, topic in enumerate(lda.components_):
    colname = "topic_"+str(topic_id)
    values = []
    for index, row in df.iterrows():
        key = row['Id']
        if key in topic_index:
            val = topic_index[key][topic_id]
        else:
            val = 0
        values.append(val)
    df.insert(len(df.columns), colname, values)
df
# Out:
#                 Id                                               urls  \
# 0              fas  https://fas.org/sgp/crs/misc/R41153.pdf https:...
# 1    foreignpolicy  https://foreignpolicy.com/2020/12/07/forget-gr...
# 2           europa  https://ec.europa.eu/environment/international...
# 3          weforum  https://www.weforum.org/agenda/2020/01/arctic-...
# 4          harvard  https://www.hsph.harvard.edu/news/press-releas...
# ..             ...                                                ...
# 154   acces-arctic                     https://www.acces-arctic.com/
# 155    eu-interact           https://eu-interact.org/glossary/artic/
# 156          wiley  https://agupubs.onlinelibrary.wiley.com/doi/fu...
# 157  arctickingdom  https://arctickingdom.com/10-fun-facts-about-a...
# 158            awi     https://www.awi.de/en/focus/arctic-ocean.html
#
#                                                   text  \
# 0                                       .  .  .  .  .
# 1    Jenis av Rana, foreign minister of the Faroe I...
# 2    Accessibility tools\nService tools\nLanguage s...
# 3    - Since the 1970s, we have lost 75% of the vol...
# 4    Harvard study finds circumpolar rivers most re...
# ..                                                 ...
# 154  De-icing of the Arctic coast:new challenges an...
# 155  Definitions of the ArcticDefinitions of the Ar...
# 156                                                 .
# 157  By: Liz Carino\nWhile polar bears are the most...
# 158  Due to construction work in the sea, shipping,...
#
#      discourse: Climate change  discourse: Environment  \
# 0                         True                    True
# 1                         True                    True
# 2                         True                    True
# 3                         True                    True
# 4                         True                    True
# ..                         ...                     ...
# 154                      False                   False
# 155                      False                   False
# 156                      False                   False
# 157                      False                   False
# 158                      False                   False
#
#      discourse: Green growth  discourse: Sustainability  discourse: UN SDGs  \
# 0                       True                       True               False
# 1                      False                      False               False
# 2                       True                       True                True
# 3                       True                       True                True
# 4                       True                      False               False
# ..                       ...                        ...                 ...
# 154                    False                       True               False
# 155                    False                       True               False
# 156                    False                       True               False
# 157                    False                       True               False
# 158                    False                       True               False
#
#      area: Arctic  area: Arctic Norway  ...   topic_5   topic_6   topic_7  \
# 0            True                False  ...  0.066667  0.066667  0.066667
# 1            True                False  ...  0.000005  0.000005  0.000005
# 2            True                False  ...  0.000017  0.000017  0.000017
# 3            True                False  ...  0.000046  0.000046  0.000046
# 4            True                False  ...  0.000022  0.000022  0.000022
# ..            ...                  ...  ...       ...       ...       ...
# 154          True                False  ...  0.000926  0.000926  0.000926
# 155          True                False  ...  0.000006  0.000006  0.000006
# 156          True                False  ...  0.000000  0.000000  0.000000
# 157          True                False  ...  0.000575  0.000575  0.000575
# 158          True                False  ...  0.000813  0.000813  0.000813
#
#       topic_8   topic_9  topic_10  topic_11  topic_12  topic_13  topic_14
# 0    0.066667  0.066667  0.066667  0.066667  0.066667  0.066667  0.066667
# 1    0.000005  0.000005  0.000005  0.999925  0.000005  0.000005  0.000005
# 2    0.000017  0.000017  0.000017  0.835217  0.000017  0.000028  0.000017
# 3    0.000046  0.000046  0.000046  0.046926  0.000046  0.000046  0.000046
# 4    0.000022  0.000022  0.000022  0.887257  0.000022  0.004064  0.000022
# ..        ...       ...       ...       ...       ...       ...       ...
# 154  0.000926  0.000926  0.000926  0.436133  0.000926  0.038264  0.000926
# 155  0.000006  0.000006  0.000006  0.000006  0.000006  0.999918  0.000006
# 156  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 157  0.000575  0.000575  0.000575  0.000575  0.000575  0.000575  0.000575
# 158  0.000813  0.000813  0.000813  0.000813  0.000813  0.000813  0.000813
#
# [159 rows x 31 columns]

# %%
# DOWNLOAD ENRICHED FILE
df.drop(columns=[text_col_name]).to_csv("04 Actors and their topics.csv", index=False)

# %% [markdown]
# # Export LDA networks

# %%
# Export network of words and topics
import networkx as nx
G = nx.Graph()
for index, row in topics_df.iterrows():
    topic = 'T_'+str(row['topic'])
    word = 'W_'+str(row['word'])
    w = row['weight']
    
    G.add_edge(topic, word)
    G[topic][word]['weight'] = w
    
    G.nodes[topic]['label'] = str(row['topic'])
    G.nodes[topic]['type'] = 'topic'
    G.nodes[word]['label'] = str(row['word'])
    G.nodes[word]['type'] = 'word'
    
nx.write_gexf(G, "05 Words and topics.gexf")

# %%
# Export network of actors and topics
import networkx as nx
threshold = 0.001
G = nx.Graph()
for index, row in df_list_style.iterrows():
    topic = 'T_'+str(row['topic'])
    actor = 'A_'+str(row['doc'])
    w = row['weight']
    
    if w > threshold:
        G.add_edge(topic, actor)
        G[topic][actor]['weight'] = w

        G.nodes[topic]['label'] = str(row['topic'])
        G.nodes[topic]['type'] = 'topic'
        G.nodes[actor]['label'] = str(row['doc'])
        G.nodes[actor]['type'] = 'actor'
    
nx.write_gexf(G, "06 Actors and topics.gexf")

# %% [markdown]
# # UMAP after the topics

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import umap

# %%
# Load data
df = pd.read_csv("04 Actors and their topics.csv")
df = df.dropna()

# %%
# Prepare data
reducer = umap.UMAP()
umap_data = df[
    [
        "topic_0",
        "topic_1",
        "topic_2",
        "topic_3",
        "topic_4",
        "topic_5",
        "topic_6",
        "topic_7",
        "topic_8",
        "topic_9",
        "topic_10",
        "topic_11",
        "topic_12",
        "topic_13",
        "topic_14"
    ]
].values
scaled_umap_data = StandardScaler().fit_transform(umap_data)

# %%
# Compute embedding
embedding = reducer.fit_transform(scaled_umap_data)
embedding.shape
# Out:
# (159, 2)

# %%
# Monitor embedding
plt.scatter(
    embedding[:, 0],
    embedding[:, 1]
)
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection of the dataset', fontsize=24)
# Out:
# Text(0.5, 1.0, 'UMAP projection of the dataset')

# %%
# Enrich source and download
xvalues = []
yvalues = []
for index, row in df.iterrows():
    coord = embedding[index]
    xvalues.append(coord[0])
    yvalues.append(coord[1])
df.insert(len(df.columns), 'X-UMAP', xvalues)
df.insert(len(df.columns), 'Y-UMAP', yvalues)

df.to_csv("07 Actors with topics + UMAP layout.csv", index = False, encoding='utf-8')
