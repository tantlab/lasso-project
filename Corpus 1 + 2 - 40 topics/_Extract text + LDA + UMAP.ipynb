# %%
# SETTINGS

number_topics = 40

# %% [markdown]
# # Load and join the source files

# %%
# Filter the input file
import pandas as pd

df1 = pd.read_csv('00-a source data corpus 1.csv')
df1.fillna('', inplace=True)

df1
# Out:
#       result # search engine       discourse           area  \
# 0           48          bing     environment         arctic
# 1           55          bing     environment         arctic
# 2           47          bing     environment         arctic
# 3           22          bing     environment         arctic
# 4            7          bing     environment         arctic
# ...        ...           ...             ...            ...
# 1772      1985          bing  sustainability  faroe islands
# 1773      3997          bing  sustainability  arctic norway
# 1774      2678          bing         UN SDGs           Sami
# 1775      3919          bing  sustainability  arctic norway
# 1776      3992          bing  sustainability  arctic norway
#
#                  domain actor name  \
# 0                   fas
# 1                   fas
# 2         foreignpolicy
# 3                europa
# 4               weforum
# ...                 ...        ...
# 1772           kingspan
# 1773        tripadvisor
# 1774               oecd
# 1775  secretatlastravel
# 1776            booking
#
#                                           article title  \
# 0     Changes in the Arctic: Background and Issues f...
# 1     Changes in the Arctic: Background and Issues f...
# 2     Forget Greenland, the Faroe Islands Are the Ne...
# 3     Arctic - International Issues - Environment - ...
# 4     What the melting Arctic means for the world | ...
# ...                                                 ...
# 1772  Sustainability and responsibility | Kingspan I...
# 1773  Sustainable luxury - Review of Funken Lodge, L...
# 1774  Linking Indigenous communities with regional d...
# 1775  Arctic Cruises, Private Expeditions ... - Secr...
# 1776  Svalbard Hotell | Polfareren, Longyearbyen – U...
#
#                                             article url  \
# 0               https://fas.org/sgp/crs/misc/R41153.pdf
# 1               https://fas.org/sgp/crs/misc/R41153.pdf
# 2     https://foreignpolicy.com/2020/12/07/forget-gr...
# 3     https://ec.europa.eu/environment/international...
# 4     https://www.weforum.org/agenda/2020/01/arctic-...
# ...                                                 ...
# 1772  https://www.kingspan.com/gb/en-gb/about-kingsp...
# 1773  https://www.tripadvisor.com/ShowUserReviews-g5...
# 1774  http://www.oecd.org/regional/regional-policy/i...
# 1775                     https://secretatlastravel.com/
# 1776     https://www.booking.com/hotel/no/svalbard.html
#
#                                     article description  \
# 0     The geopolitical environment for the Arctic ha...
# 1     The geopolitical environment for the Arctic ha...
# 2     12/7/2020 · With the Arctic ice melting, and t...
# 3     The Arctic is a key driver of the world ocean ...
# 4     3/23/2021 · The Arctic is an incredibly import...
# ...                                                 ...
# 1772  Sustainability issues, however, extend far bey...
# 1773  2/15/2020 · Funken Lodge: Sustainable luxury -...
# 1774  Indigenous peoples represent about 5% of the w...
# 1775  Svalbard Expedition Micro Cruises 2021 and 202...
# 1776  The hotel"s Polfareren Restaurant offers a men...
#
#       total nr of results (best guess)  ...  \
# 0                             30600000  ...
# 1                             30600000  ...
# 2                             30600000  ...
# 3                             30600000  ...
# 4                             30600000  ...
# ...                                ...  ...
# 1772                           1810000  ...
# 1773                           1820000  ...
# 1774                            930000  ...
# 1775                           1820000  ...
# 1776                           1820000  ...
#
#                                           canonical_url  \
# 0
# 1
# 2     https://foreignpolicy.com/2020/12/07/forget-gr...
# 3
# 4     https://www.weforum.org/agenda/2020/01/arctic-...
# ...                                                 ...
# 1772  https://www.kingspan.com/gb/en-gb/about-kingsp...
# 1773
# 1774
# 1775                 https://www.secretatlastravel.com/
# 1776  https://www.booking.com/hotel/no/svalbard.en-g...
#
#                                                   title  \
# 0
# 1
# 2     Forget Greenland, There’s a New Strategic Gate...
# 3                                                Arctic
# 4           What the melting Arctic means for the world
# ...                                                 ...
# 1772                                     Sustainability
# 1773  Sustainable luxury - Review of Funken Lodge, L...
# 1774  Linking Indigenous communities with regional d...
# 1775  Secret Atlas | Arctic Cruises & Photo Tours on...
# 1776  ★★★★ Svalbard Hotell | Polfareren, Longyearbye...
#
#                                             description  \
# 0
# 1
# 2     The Faroe Islands have a history of trading wi...
# 3     The EU participates in international efforts t...
# 4     The Arctic is turning from white to blue, abso...
# ...                                                 ...
# 1772  We have a long-term commitment to sustainabili...
# 1773  Funken Lodge: Sustainable luxury - See 206 tra...
# 1774  This project was launched on 19 September 2017...
# 1775  Cruises on Small Expedition Vessels to the Arc...
# 1776  Centrally located in Longyearbyen, Svalbard Ho...
#
#                                             raw_content comments  \
# 0
# 1
# 2     Jenis av Rana, foreign minister of the Faroe I...
# 3     Accessibility tools\nService tools\nLanguage s...
# 4     - Since the 1970s, we have lost 75% of the vol...
# ...                                                 ...      ...
# 1772  We are conscious of the nature of the raw mate...
# 1773  It’s hard to find the words to describe just h...
# 1774  This project was launched on 19 September 2017...
# 1775  Welcome\nWe are a team of passionate explorers...
# 1776  Hotel Svalbard Hotell | Polfareren\nLongyearby...
#
#                      author  \
# 0
# 1
# 2     Regin Winther Poulsen
# 3
# 4             Robin Pomeroy
# ...                     ...
# 1772
# 1773
# 1774
# 1775
# 1776
#
#                                              categories  \
# 0
# 1
# 2     Morning Brief|Argument|Argument|Report|Report|...
# 3
# 4                                                Arctic
# ...                                                 ...
# 1772
# 1773
# 1774
# 1775  Article|Svalbard|Travel Tips|Article|Svalbard|...
# 1776
#
#                                                    tags        date  \
# 0
# 1
# 2                                                        2020-12-07
# 3     environment|international|cooperation|arctic|f...
# 4     World Economic Forum|WEF|Davos|Klaus Schwab|gl...  2020-01-23
# ...                                                 ...         ...
# 1772  about kingspan|kingspan in the UK|UK|Great Bri...
# 1773  Funken Lodge|Longyearbyen|Norway|Sustainable l...  2020-02-15
# 1774  indgenous peoples|indigenous communities|indig...
# 1775                                                     2019-08-22
# 1776  Svalbard Hotell | Polfareren|Longyearbyen|Norw...  2020-04-06
#
#                                                sitename
# 0
# 1
# 2                                        Foreign Policy
# 3     International Issues - Environment - European ...
# 4                                  World Economic Forum
# ...                                                 ...
# 1772                           Kingspan | Great Britain
# 1773  Review of Funken Lodge, Longyearbyen, Norway -...
# 1774                                               OECD
# 1775                                       Secret Atlas
# 1776                                        Booking.com
#
# [1777 rows x 29 columns]

# %%
df2 = pd.read_csv('00-b source data corpus 2.csv')
df2.fillna('', inplace=True)
df2.rename(columns={'Manual actor name':'actor name'}, inplace = True)
df2
# Out:
#     result # search engine                                              query  \
# 0       33.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 1        4.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 2        0.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 3        9.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 4       41.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# ..       ...           ...                                                ...
# 528
# 529     51.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 530     88.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 531     26.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 532     21.0          bing  (“umhvørvi” OR “umhvørvis*”) AND ((“burturkast...
#
#     discourse language           domain  \
# 0               Danish          norskov
# 1               Danish             mfvm
# 2               Danish        wikipedia
# 3               Danish     miljoeportal
# 4               Danish              avl
# ..        ...      ...              ...
# 528             Danish  klimatilpasning
# 529             Danish          regionh
# 530             Danish          esbjerg
# 531             Danish             bane
# 532            Faroese              fnu
#
#                                   actor name  \
# 0
# 1
# 2
# 3
# 4
# ..                                       ...
# 528
# 529
# 530
# 531
# 532  Føroya Náttúru- og Umhvørvisfelag (FNU)
#
#                                          article title  \
# 0                                                Miljø
# 1    Ministeriet for Fødevarer, Landbrug og Fiskeri...
# 2              Miljø - Wikipedia, den frie encyklopædi
# 3               Danmarks Miljøportal Miljoeportalen.dk
# 4            Miljø - Aage Vestergaard Larsen A/S - AVL
# ..                                                 ...
# 528                          tilføjet fra holstebro.dk
# 529                                   Miljø - Region H
# 530                             Plan & Miljø - Esbjerg
# 531                      GAB Miljø Anlæg | Banedanmark
# 532            Føroya Náttúru- og Umhvørvisfelag (FNU)
#
#                                            article url  \
# 0                         https://www.norskov.dk/miljo
# 1                                     https://mfvm.dk/
# 2             https://da.wikipedia.org/wiki/Milj%C3%B8
# 3                             https://miljoeportal.dk/
# 4                                 https://avl.dk/miljo
# ..                                                 ...
# 528  https://www.klimatilpasning.dk/viden-om/fremti...
# 529  https://www.regionh.dk/til-fagfolk/miljoe/en-g...
# 530  https://www.esbjerg.dk/planer-projekter-og-tra...
# 531  https://www.bane.dk/da/Om-Banedanmark/Baeredyg...
# 532             https://www.facebook.com/natturuvernd/
#
#                                    article description  ...  \
# 0    Nørskov miljø er rigtig gode til at lave en si...  ...
# 1    Den 19. november 2020 er det besluttet, at Mil...  ...
# 2                                                       ...
# 3    Danmarks Miljøportal satser i vores strategi p...  ...
# 4    Miljø. Miljøet spares gennemsnitlig for 2,4 ki...  ...
# ..                                                 ...  ...
# 528                                                     ...
# 529  Miljø Med FN"s verdensmål som pejlemærke arbej...  ...
# 530            Esbjerg Kommunes Plan &amp; Miljøudvalg  ...
# 531  Håndtering af affald Jordforurening Luftforure...  ...
# 532  Ársaðalfundurin hjá Føroya Náttúru- og Umhvørv...  ...
#
#                                          canonical_url  \
# 0
# 1                   https://mfvm.dk/index.php?id=15654
# 2             https://da.wikipedia.org/wiki/Milj%C3%B8
# 3                             https://miljoeportal.dk/
# 4                                 https://avl.dk/miljo
# ..                                                 ...
# 528
# 529  https://www.regionh.dk/til-fagfolk/miljoe/en-g...
# 530  https://www.esbjerg.dk/planer-projekter-og-tra...
# 531  https://www.bane.dk/da/Om-Banedanmark/Baeredyg...
# 532             https://www.facebook.com/natturuvernd/
#
#                                                title  \
# 0                                              Miljø
# 1            Fødevareministeriet og Miljøministeriet
# 2            Miljø - Wikipedia, den frie encyklopædi
# 3                               Danmarks Miljøportal
# 4                Miljø - Aage Vestergaard Larsen A/S
# ..                                               ...
# 528                  Havniveau og klimaforandringer
# 529           Sådan arbejder vi med cirkulær økonomi
# 530             Grøn omstilling af energiforsyningen
# 531  \n\t\t\t\tVi reducerer vores el-forbrug\n\t\t\t
# 532          FNU - Føroya Náttúru- og Umhvørvisfelag
#
#                                            description  \
# 0    Nørskov Miljø hjælper virksomheder med alle ty...
# 1    Den 19. november 2020 er det besluttet, at Mil...
# 2
# 3                                 Danmarks Miljøportal
# 4    Miljøet spares for 2,4 kilo CO2 udslip for hve...
# ..                                                 ...
# 528
# 529  I Region Hovedstaden arbejder vi for en grøn o...
# 530               Grøn omstilling af energiforsyningen
# 531
# 532  FNU - Føroya Náttúru- og Umhvørvisfelag, Tórsh...
#
#                                            raw_content comments  \
# 0    De fleste virksomheder vil gerne have styr på ...
# 1    Den 19. november 2020 er det besluttet, at Mil...
# 2    Miljø\nMiljø betyder "omgivelser" og dækker og...
# 3    Seneste nyheder\nInvitation til webinar om Van...
# 4    Miljø\nMiljøet spares gennemsnitlig for 2,4 ki...
# ..                                                 ...      ...
# 528  Havniveau og klimaforandringer\nOpvarmningen a...
# 529  Afsæt i dialog med interessenter\nOmstillingen...
# 530  Grøn omstilling af energiforsyningen\nHer er v...
# 531  Vi reducerer vores el-forbrug\nVi forsyner de ...
# 532  UMHVØRVISVIKAN\nÍ Umhvørvisvikuni fer FNU at s...
#
#                                    author categories  \
# 0                                 Pelle P
# 1
# 2    Bidragsydere til Wikimedia-projekter
# 3
# 4
# ..                                    ...        ...
# 528
# 529
# 530
# 531
# 532
#
#                                                   tags        date  \
# 0    MiljøcertificeringMiljøforholdMiljøkortlægning...
# 1
# 2                                                       2003-01-03
# 3    miljøportal|miljøvenlig|Danmarks Miljø|data om...
# 4                                                       2019-08-30
# ..                                                 ...         ...
# 528  andet|Her markerer man hvis ingen andre emneor...
# 529  Cirkulær økonomi|Regional udvikling Ressourcee...  2021-04-27
# 530  Grøn omstilling af energiforsyningen|Grøn omst...  2021-03-16
# 531
# 532                                                     2021-04-13
#
#                                               sitename
# 0
# 1       Ministeriet for Fødevarer, Landbrug og Fiskeri
# 2                      Wikipedia, den frie encyklopædi
# 3                                 Danmarks Miljøportal
# 4                                                  AVL
# ..                                                 ...
# 528
# 529                                         regionh.dk
# 530                                         esbjerg.dk
# 531                                            Website
# 532  Føroya Náttúru- og Umhvørvisfelag - Startside ...
#
# [533 rows x 31 columns]

# %%
df = pd.DataFrame(columns=['domain', 'actor name', 'article url', 'raw_content', 'corpus'])
for index, row in df1.iterrows():
    df = df.append({
        'domain': row['domain'],
        'actor name': row['actor name'],
        'article url': row['article url'],
        'raw_content': row['raw_content'],
        'corpus': "Corpus 1"
    }, ignore_index=True)
for index, row in df2.iterrows():
    df = df.append({
        'domain': row['domain'],
        'actor name': row['actor name'],
        'article url': row['article url'],
        'raw_content': row['raw_content'],
        'corpus': "Corpus 2"
    }, ignore_index=True)

df.to_csv("01 data merged.csv", index = False, encoding='utf-8')
df
# Out:
#                domain                               actor name  \
# 0                 fas
# 1                 fas
# 2       foreignpolicy
# 3              europa
# 4             weforum
# ...               ...                                      ...
# 2305  klimatilpasning
# 2306          regionh
# 2307          esbjerg
# 2308             bane
# 2309              fnu  Føroya Náttúru- og Umhvørvisfelag (FNU)
#
#                                             article url  \
# 0               https://fas.org/sgp/crs/misc/R41153.pdf
# 1               https://fas.org/sgp/crs/misc/R41153.pdf
# 2     https://foreignpolicy.com/2020/12/07/forget-gr...
# 3     https://ec.europa.eu/environment/international...
# 4     https://www.weforum.org/agenda/2020/01/arctic-...
# ...                                                 ...
# 2305  https://www.klimatilpasning.dk/viden-om/fremti...
# 2306  https://www.regionh.dk/til-fagfolk/miljoe/en-g...
# 2307  https://www.esbjerg.dk/planer-projekter-og-tra...
# 2308  https://www.bane.dk/da/Om-Banedanmark/Baeredyg...
# 2309             https://www.facebook.com/natturuvernd/
#
#                                             raw_content    corpus
# 0                                                        Corpus 1
# 1                                                        Corpus 1
# 2     Jenis av Rana, foreign minister of the Faroe I...  Corpus 1
# 3     Accessibility tools\nService tools\nLanguage s...  Corpus 1
# 4     - Since the 1970s, we have lost 75% of the vol...  Corpus 1
# ...                                                 ...       ...
# 2305  Havniveau og klimaforandringer\nOpvarmningen a...  Corpus 2
# 2306  Afsæt i dialog med interessenter\nOmstillingen...  Corpus 2
# 2307  Grøn omstilling af energiforsyningen\nHer er v...  Corpus 2
# 2308  Vi reducerer vores el-forbrug\nVi forsyner de ...  Corpus 2
# 2309  UMHVØRVISVIKAN\nÍ Umhvørvisvikuni fer FNU at s...  Corpus 2
#
# [2310 rows x 5 columns]

# %% [markdown]
# # Group content by actor

# %%
actor_dict = {}
for index, row in df.iterrows():
    if row['actor name']:
        actor_id = row['actor name']
    else:
        actor_id = row['domain']
    if actor_id in actor_dict:
        actor_obj = actor_dict[actor_id]
    else:
        actor_obj = {}
        actor_obj['Id'] = actor_id
        actor_obj['urls'] = ''
        actor_obj['text'] = ''
    
    actor_obj['urls'] = actor_obj['urls'] + str(row['article url']) + ' '
    actor_obj['text'] = actor_obj['text'] + str(row['raw_content']) + ' . '
    
    actor_dict[actor_id] = actor_obj
print("Actor index built.")
# Out:
# Actor index built.

# %%
# DOWNLOAD ACTORS
actors_df = pd.DataFrame.from_dict(actor_dict, orient='index')
actors_df.to_csv("02 Actors with text.csv", index = False, encoding='utf-8')
actors_df
# Out:
#                                                                     Id  \
# fas                                                                fas
# foreignpolicy                                            foreignpolicy
# europa                                                          europa
# weforum                                                        weforum
# harvard                                                        harvard
# ...                                                                ...
# Brugseni                                                      Brugseni
# Tora guides                                                Tora guides
# Inunnguaq Hegelund: kok: lokal mad  Inunnguaq Hegelund: kok: lokal mad
# Vores fisk/aalisagaativut                    Vores fisk/aalisagaativut
# csrkompasset                                              csrkompasset
#
#                                                                                  urls  \
# fas                                 https://fas.org/sgp/crs/misc/R41153.pdf https:...
# foreignpolicy                       https://foreignpolicy.com/2020/12/07/forget-gr...
# europa                              https://ec.europa.eu/environment/international...
# weforum                             https://www.weforum.org/agenda/2020/01/arctic-...
# harvard                             https://www.hsph.harvard.edu/news/press-releas...
# ...                                                                               ...
# Brugseni                            https://brugseni.gl/gl/csr/ https://brugseni.g...
# Tora guides                                             https://tora.fo/da/about-us/
# Inunnguaq Hegelund: kok: lokal mad  https://knr.gl/kl/nutaarsiassat/nutaanik-malit...
# Vores fisk/aalisagaativut           https://naalakkersuisut.gl/~/media/Nanoq/Files...
# csrkompasset                        https://www.csrkompasset.dk/milj%C3%B8-0 https...
#
#                                                                                  text
# fas                                                                    .  .  .  .  .
# foreignpolicy                       Jenis av Rana, foreign minister of the Faroe I...
# europa                              Accessibility tools\nService tools\nLanguage s...
# weforum                             - Since the 1970s, we have lost 75% of the vol...
# harvard                             Harvard study finds circumpolar rivers most re...
# ...                                                                               ...
# Brugseni                            Brugsenimi takorluugarput piujuartitsilluni in...
# Tora guides                         Dine personlige data vil blive at at have din ...
# Inunnguaq Hegelund: kok: lokal mad  Inuussutissat suliarineqarsimasut ilaat kalaal...
# Vores fisk/aalisagaativut                                                          .
# csrkompasset                        Her kan I vælge at tilføje udvalgte miljøkrav,...
#
# [1134 rows x 3 columns]

# %% [markdown]
# # LDA: extract topics

# %%
import pandas as pd
# This is for text mining
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# Source file (CSV)
source_file = "02 Actors with text.csv"
text_col_name = "text"

# More features is more dimensions for each document. You should probably keep it at 1000.
no_features = 1000

# %%
# LOAD DATA
documents_dictionary = {}
df = pd.read_csv(source_file)

for index, row in df.iterrows():
    key = row['Id']
    text = str(row[text_col_name])
    if len(text)>10:
        documents_dictionary[key] = text

# %%
# LOAD STOP WORDS
import csv
stopwords = []
with open('stopwords-en-dk-is.txt', 'r') as fd:
    reader = csv.reader(fd)
    for row in reader:
        word = row[0]
        stopwords.append(word)
print("Stop words loaded. Ex:", stopwords[0], stopwords[1], stopwords[2],"...")
# Out:
# Stop words loaded. Ex: i me my ...

# %%
# COMPUTE LDA TOPICS
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents_dictionary.values())
tf_feature_names = tf_vectorizer.get_feature_names()
lda = LatentDirichletAllocation(n_components=number_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)
print("LDA topics computed.")
# Out:
# LDA topics computed.

# %%
# DISPLAY RESULTS (for monitoring)
no_top_words = 25 # How many words to keep for each topic (there may be many)

# Create a data frame for convenience (for download, actually)
topics_df = pd.DataFrame(columns=['topic','word','weight'])

# Display topics to check it works. For each topic, we only display the top words.
i = 0
for topic_idx, topic in enumerate(lda.components_):
    print("# TOPIC_%d:" % (topic_idx))
    for j in topic.argsort()[:-no_top_words - 1:-1]:
        print(str(topic[j]) + "   " + tf_feature_names[j])
        topics_df.loc[i] = ["TOPIC_"+str(topic_idx), tf_feature_names[j], topic[j]]
        i = i+1
    print(" ")

topics_df
# Out:
# # TOPIC_0:
# 2310.556609583542   nunavut
# 1521.6041214449897   inuit
# 922.3639019889447   canada
# 701.9871725936217   communities
# 663.7138438647889   community
# 631.7115410733961   arctic
# 602.4661224265056   food
# 570.3873996524894   government
# 389.8942620212871   people
# 372.98751818621855   canadian
# 336.8739458187958   health
# 317.4885876366333   iqaluit
# 308.4857934815002   territory
# 301.0744872562082   bay
# 288.97091061537833   walrus
# 271.1696554741933   northern
# 269.3626496140637   land
# 258.3972954881216   north
# 248.53517035456576   traditional
# 244.28934668424728   change
# 239.0541168946437   high
# 235.7002265153886   hunting
# 231.2271725912541   said
# 227.88384881396271   indigenous
# 216.2935064320453   development
#
# # TOPIC_1:
# 0.9193124468054333   shall
# 0.8794655044327578   arctic
# 0.8311736914914079   001
# 0.6170003703052461   developing
# 0.5942027556149216   convention
# 0.5203220522354044   canada
# 0.5000335303184551   marine
# 0.49385499850341386   international
# 0.48627426007824753   including
# 0.48303001933332607   government
# 0.4680509397815942   indigenous
# 0.4569955424621348   parties
# 0.4454608898027344   world
# 0.4250528322203361   article
# 0.42075704107554035   environmental
# 0.4153416059424501   development
# 0.39646906059604403   climate
# 0.38504823558132745   use
# 0.3776971137168572   activities
# 0.37618381252677563   region
# 0.3757371147110715   northern
# 0.3663915639065055   maritime
# 0.3592797316389164   days
# 0.3588080473900377   measures
# 0.3573271373810396   security
#
# # TOPIC_2:
# 288.6253954055641   vary
# 282.4260334799746   according
# 276.1304250763205   geographical
# 273.6792312838107   environmental
# 270.1456186068526   scientists
# 265.68767837157674   cultural
# 260.6810642485456   scientific
# 252.1410006084721   political
# 251.58689306875775   perspectives
# 246.7600812381158   define
# 243.80446688035187   arctic
# 212.953995880964   interact
# 212.4194613259128   having
# 209.32696140122403   areas
# 198.54322381735474   read
# 193.92472322455498   latitude
# 189.58295840224875   long
# 186.92074168117887   cool
# 185.3940644787494   summers
# 184.57806209728403   high
# 184.5360924763435   short
# 183.41314129084716   winters
# 167.71256691865864   news
# 129.72203674529985   station
# 69.1416504419834   field
#
# # TOPIC_3:
# 1.4882056468932279   arctic
# 1.2367359109017466   canada
# 1.126279382733879   indigenous
# 1.001236725948575   northern
# 0.9086235417236634   shall
# 0.8791420177543291   development
# 0.8550511340787503   government
# 0.8190399043448251   including
# 0.812264548806493   region
# 0.7200168920233677   section
# 0.7098745147313026   north
# 0.6806941546373823   environmental
# 0.6792643252780179   security
# 0.6764506766180326   gn
# 0.6743442453001526   communities
# 0.6576676810989707   change
# 0.6255402504109081   inuit
# 0.6110396337398125   agreement
# 0.5964821921864276   climate
# 0.571814501934434   federal
# 0.5527734413125526   nunavut
# 0.5505179308616232   provide
# 0.5477140901009948   international
# 0.5425271756558078   peoples
# 0.5406708606464652   gc
#
# # TOPIC_4:
# 1182.2865748474185   ice
# 1146.7767564716003   arctic
# 725.8306600860132   sea
# 374.19715396672666   ocean
# 358.42044753262286   climate
# 263.900600928853   data
# 223.63258942559975   change
# 172.48578163198064   warming
# 148.0175043225359   changes
# 142.52497675712067   year
# 138.3549363724923   extent
# 129.17400396490564   earth
# 126.45577663969313   summer
# 124.57811125637932   satellite
# 121.38552955556511   global
# 121.326254843044   temperatures
# 117.07788021175905   et
# 116.44324933692359   temperature
# 115.30024087496962   north
# 110.04415643400476   polar
# 109.71045425215709   al
# 109.66016458174889   average
# 109.60618203848864   greenland
# 109.50155097980912   snow
# 106.90518206656645   surface
#
# # TOPIC_5:
# 177.97295300227813   arctic
# 95.18211307305604   said
# 65.12387123410183   world
# 60.28279032315427   china
# 54.54773645504311   sea
# 50.90130790695385   space
# 37.868163424792485   ice
# 34.243741000779686   climate
# 32.60146182058864   passage
# 32.366328558802   ocean
# 30.460366498791732   like
# 30.38349725074776   year
# 30.097417508329453   global
# 28.951231603321006   women
# 27.98381026213702   iceland
# 26.876439888533643   countries
# 26.823774747228327   according
# 26.650980316163345   just
# 25.40894648984822   people
# 25.2396059763254   route
# 25.116582166988984   chinese
# 23.815968997324664   north
# 22.821589403983566   change
# 22.8023305441429   circle
# 22.378398874303358   new
#
# # TOPIC_6:
# 165.6716538472604   glaciers
# 157.78771540358392   diamonds
# 131.0729995227853   ice
# 127.32477011113602   area
# 108.70368751439736   reference
# 97.21163148927452   glacier
# 51.83094494559889   northern
# 46.44697371437507   loss
# 46.036993859109   island
# 41.58426190118097   http
# 41.49083679528595   2015
# 37.87502044271653   surface
# 37.68292248914723   10
# 36.31264266557369   canada
# 33.69045347041749   land
# 33.47495124716138   small
# 32.42172379640954   study
# 28.62921174715506   km
# 26.887392951335283   year
# 26.235019044891345   canadian
# 25.667113134940884   2000
# 24.69296331531202   period
# 24.234713882420976   total
# 23.203043902127718   org
# 22.202498877390077   doi
#
# # TOPIC_7:
# 179.28717987915596   food
# 103.64025166173968   think
# 64.32027135009974   going
# 56.63999845482358   like
# 56.52570986733215   just
# 54.8072923239832   security
# 51.07186526748446   circular
# 50.453086853543994   economy
# 48.572581976004415   know
# 47.29934877035752   nunavut
# 42.693432979514014   ve
# 41.82212525453882   arctic
# 41.56804756119928   canada
# 39.03087209927035   development
# 38.686920617301666   work
# 35.41582636824263   time
# 33.02808819442962   new
# 30.027792390397906   look
# 28.87830003497332   research
# 28.02511819243801   coast
# 27.62521391117725   things
# 26.888773212456044   ice
# 26.24451991083538   north
# 26.121542506225747   regulatory
# 25.596316043453246   don
#
# # TOPIC_8:
# 1023.0386717566381   emissions
# 699.2567819457844   ranked
# 604.3880077426146   water
# 385.80962359537   gas
# 345.14425471318145   pollution
# 339.22706050284813   united
# 330.32261542667516   co2
# 323.5204695806561   total
# 300.0723179858024   canada
# 292.2711759946123   population
# 3093.9874879943536   med
# 2953.8868036173044   som
# 2835.2930367050903   om
# 2706.2964036300614   kan
# 2422.4722927809385   der
# 2284.3189609434335   vi
# 2023.5759887624831   et
# 1943.7150574396871   har
# 1744.1680282526095   skal
# 1653.4759738307255   den
# 1642.1684301589373   eller
# 1567.7917161678295   du
# 1209.8654238866575   mere
# 1200.160644605986   fra
# 1183.3222718879697   ikke
# 931.9348224884343   ved
# 869.0930377373061   vil
# 855.5282894851952   være
#
# # TOPIC_27:
# 284.7618324907924   seed
# 252.6660205618822   vault
# 164.5427961424556   svalbard
# 117.89289025887629   global
# 107.00897561525639   food
# 70.33759628271162   world
# 56.4630278522871   diversity
# 49.9241070259106   climate
# 45.30539078901058   samples
# 44.69362270823397   international
# 43.98307371983293   bank
# 43.83583727269707   plant
# 43.45966132269022   agriculture
# 42.10833760615839   norwegian
# 38.48756913096572   says
# 37.33125699009249   norway
# 35.85913644170256   new
# 32.67007364423112   today
# 30.788598014362442   security
# 30.68338893530667   change
# 30.579778353759554   said
# 29.60695874337499   million
# 23.94155813216915   important
# 23.016196209074337   season
# 21.130027326247138   ministry
#
# # TOPIC_28:
# 574.1576958076115   canada
# 358.08109706521014   government
# 351.2122345420876   arctic
# 336.15680064763245   indigenous
# 327.2622008434282   federal
# 310.21233941741895   agreement
# 287.5717538880054   northern
# 268.7218941183264   shall
# 239.38023500690167   development
# 210.18186762816592   including
# 205.94625231812813   land
# 200.68888053340194   site
# 199.16718812969773   gc
# 195.51586164227308   peoples
# 192.28782176128925   policy
# 191.15048242681087   gn
# 179.06852202565986   canadian
# 177.80898715978392   reclamation
# 175.9233582745779   section
# 170.043795189811   international
# 168.01808707544478   security
# 165.20126910829933   north
# 159.53760077860238   provide
# 154.6014398055446   territorial
# 152.91728611271157   respect
#
# # TOPIC_29:
# 1.6241940275500362   arctic
# 1.219931646791063   ice
# 1.08426074206835   climate
# 1.0821489490370424   sea
# 0.9378177515994861   001
# 0.7185025214435166   snow
# 0.6779751560969397   developing
# 0.624202931100342   ocean
# 0.5820294719089836   shall
# 0.5130398957679636   world
# 0.5002801625558531   et
# 0.4818173232548954   development
# 0.47717990733276294   change
# 0.46716669997500865   research
# 0.4669127037387119   international
# 0.4665153993616762   environment
# 0.4575801911565249   science
# 0.4334540107171781   region
# 0.4174284190139386   high
# 0.4069278412190115   government
# 0.40471777371837037   al
# 0.3998531924915559   europe
# 0.39823535599141846   2020
# 0.39192571516805325   sustainable
# 0.3890888208227897   china
#
# # TOPIC_30:
# 3343.541131824762   line
# 2893.182190292885   array
# 1781.9667488830642   core
# 1610.5701310155519   render
# 1529.9966542626203   object
# 530.604058896272   handle
# 484.2071605198702   html
# 318.640000629787   theme
# 317.2281298632289   arcticnet
# 254.0481736755518   195
# 253.67199479537982   themes
# 252.35511720902096   437
# 226.36112210820156   view
# 198.73503530831942   component
# 193.41531275222334   null
# 190.80998071885315   display
# 187.24809549872526   490
# 186.9078513172652   64
# 186.0904630505471   template
# 105.88012646270916   company
# 105.505334804197   construction
# 105.21197791382603   resources
# 92.91724812230404   million
# 91.3505889118293   river
#         topic          word       weight
# 0     TOPIC_0       nunavut  2310.556610
# 1     TOPIC_0         inuit  1521.604121
# 2     TOPIC_0        canada   922.363902
# 3     TOPIC_0   communities   701.987173
# 4     TOPIC_0     community   663.713844
# ..        ...           ...          ...
# 995  TOPIC_39       company   105.880126
# 996  TOPIC_39  construction   105.505335
# 997  TOPIC_39     resources   105.211978
# 998  TOPIC_39       million    92.917248
# 999  TOPIC_39         river    91.350589
#
# [1000 rows x 3 columns]

# %%
# COMPUTE DOC x TOPIC RELATIONS (network)
# We create a data frame to store the content. It looks like a matrix.
df_matrix_style = pd.DataFrame(columns=['doc']+[("TOPIC_"+str(i)) for i in range(0,number_topics)])

# We create a second data frame with the same data. It looks like a list.
# Depending on what you want to do, one or the other are most convenient.
df_list_style = pd.DataFrame(columns=['doc', 'topic', 'weight'])

doc_topic = lda.transform(tf)
docs = list(documents_dictionary.keys())
topic_index = {}
i1 = 0
i2 = 0
for j in range(len(docs)):
    key = docs[j]
    topic_weights = list(doc_topic[j])
    
    # Index
    topic_index[key] = topic_weights
    
    # Matrix style
    df_matrix_style.loc[i1] = [key]+topic_weights
    i1 = i1+1
    
    # List style
    for k, w in enumerate(topic_weights):
        df_list_style.loc[i2] = [key, "TOPIC_"+str(k), w]
        i2 = i2+1

print("Done.")
# Out:
# Done.

# %%
# Output articles & topics, matrix style, to check that it works:
df_matrix_style
# Out:
#                                      doc   TOPIC_0   TOPIC_1   TOPIC_2  \
# 0                                    fas  0.025000  0.025000  0.025000
# 1                          foreignpolicy  0.000002  0.000002  0.000002
# 2                                 europa  0.000002  0.000002  0.000002
# 3                                weforum  0.000012  0.000012  0.000012
# 4                                harvard  0.000008  0.000008  0.003789
# ...                                  ...       ...       ...       ...
# 1023                   Polar Trophy Hunt  0.000439  0.000439  0.000439
# 1024                            Brugseni  0.000610  0.000610  0.000610
# 1025                         Tora guides  0.001471  0.001471  0.001471
# 1026  Inunnguaq Hegelund: kok: lokal mad  0.000063  0.000063  0.000063
# 1027                        csrkompasset  0.000030  0.000030  0.000030
#
#        TOPIC_3   TOPIC_4   TOPIC_5   TOPIC_6   TOPIC_7   TOPIC_8  ...  \
# 0     0.025000  0.025000  0.025000  0.025000  0.025000  0.025000  ...
# 1     0.000002  0.000002  0.000002  0.000002  0.000002  0.000002  ...
# 2     0.000002  0.013909  0.000002  0.001288  0.000002  0.000002  ...
# 3     0.000012  0.236665  0.545092  0.000012  0.000012  0.000012  ...
# 4     0.000008  0.000008  0.000008  0.000008  0.000008  0.001561  ...
# ...        ...       ...       ...       ...       ...       ...  ...
# 1023  0.000439  0.000439  0.000439  0.000439  0.000439  0.000439  ...
# 1024  0.000610  0.000610  0.000610  0.000610  0.000610  0.000610  ...
# 1025  0.001471  0.001471  0.001471  0.001471  0.001471  0.001471  ...
# 1026  0.000063  0.000063  0.000063  0.000063  0.000063  0.000063  ...
# 1027  0.000030  0.000030  0.000030  0.000030  0.000030  0.000030  ...
#
#       TOPIC_30  TOPIC_31  TOPIC_32  TOPIC_33  TOPIC_34  TOPIC_35  TOPIC_36  \
# 0     0.025000  0.025000  0.025000  0.025000  0.025000  0.025000  0.025000
# 1     0.000002  0.000002  0.999912  0.000002  0.000002  0.000002  0.000002
# 2     0.000575  0.006853  0.048148  0.000002  0.000002  0.000002  0.000002
# 3     0.000012  0.000012  0.000012  0.000012  0.000012  0.000012  0.000012
# 4     0.000008  0.000008  0.577952  0.000008  0.000008  0.000008  0.000008
# ...        ...       ...       ...       ...       ...       ...       ...
# 1023  0.000439  0.000439  0.000439  0.000439  0.000439  0.000439  0.000439
# 1024  0.000610  0.000610  0.000610  0.000610  0.000610  0.000610  0.000610
# 1025  0.001471  0.001471  0.001471  0.001471  0.001471  0.001471  0.001471
# 1026  0.000063  0.000063  0.000063  0.000063  0.000063  0.000063  0.000063
# 1027  0.000030  0.000030  0.000030  0.000030  0.000030  0.000030  0.000030
#
#       TOPIC_37  TOPIC_38  TOPIC_39
# 0     0.025000  0.025000  0.025000
# 1     0.000002  0.000002  0.000002
# 2     0.017844  0.176860  0.000002
# 3     0.023042  0.045810  0.000012
# 4     0.017707  0.048931  0.010782
# ...        ...       ...       ...
# 1023  0.000439  0.000439  0.000439
# 1024  0.000610  0.000610  0.000610
# 1025  0.001471  0.001471  0.001471
# 1026  0.000063  0.000063  0.000063
# 1027  0.000030  0.000030  0.000030
#
# [1028 rows x 41 columns]

# %%
# Output articles & topics, list style, to check that it works:
df_list_style
# Out:
#                 doc     topic   weight
# 0               fas   TOPIC_0  0.02500
# 1               fas   TOPIC_1  0.02500
# 2               fas   TOPIC_2  0.02500
# 3               fas   TOPIC_3  0.02500
# 4               fas   TOPIC_4  0.02500
# ...             ...       ...      ...
# 41115  csrkompasset  TOPIC_35  0.00003
# 41116  csrkompasset  TOPIC_36  0.00003
# 41117  csrkompasset  TOPIC_37  0.00003
# 41118  csrkompasset  TOPIC_38  0.00003
# 41119  csrkompasset  TOPIC_39  0.00003
#
# [41120 rows x 3 columns]

# %%
# DOWNLOAD LDA results
# Note: these files can be used in Tableau or Table2Net to build various visualizations.

topics_df.to_csv("03-a LDA topics and their words.csv", index = False, encoding='utf-8')
# df_matrix_style.to_csv("03-? LDA actors and topics matrix.csv", index = False, encoding='utf-8')
df_list_style.to_csv("03-b LDA actors and topics list style.csv", index = False, encoding='utf-8')

# %%
# ENRICH FILE (and monitor new version)
for topic_id, topic in enumerate(lda.components_):
    colname = "topic_"+str(topic_id)
    values = []
    for index, row in df.iterrows():
        key = row['Id']
        if key in topic_index:
            val = topic_index[key][topic_id]
        else:
            val = 0
        values.append(val)
    df.insert(len(df.columns), colname, values)
df
# Out:
#                                       Id  \
# 0                                    fas
# 1                          foreignpolicy
# 2                                 europa
# 3                                weforum
# 4                                harvard
# ...                                  ...
# 1129                            Brugseni
# 1130                         Tora guides
# 1131  Inunnguaq Hegelund: kok: lokal mad
# 1132           Vores fisk/aalisagaativut
# 1133                        csrkompasset
#
0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1133  0.000030  0.000030  0.000030  0.000030  0.000030  0.000030  0.000030
#
#       topic_38  topic_39
# 0     0.025000  0.025000
# 1     0.000002  0.000002
# 2     0.176860  0.000002
# 3     0.045810  0.000012
# 4     0.048931  0.010782
# ...        ...       ...
# 1129  0.000610  0.000610
# 1130  0.001471  0.001471
# 1131  0.000063  0.000063
# 1132  0.000000  0.000000
# 1133  0.000030  0.000030
#
# [1134 rows x 43 columns]

# %%
# DOWNLOAD ENRICHED FILE
df.drop(columns=[text_col_name]).to_csv("04 Actors and their topics.csv", index=False)

# %% [markdown]
# # Export LDA networks

# %%
# Export network of words and topics
import networkx as nx
G = nx.Graph()
for index, row in topics_df.iterrows():
    topic = 'T_'+str(row['topic'])
    word = 'W_'+str(row['word'])
    w = row['weight']
    
    G.add_edge(topic, word)
    G[topic][word]['weight'] = w
    
    G.nodes[topic]['label'] = str(row['topic'])
    G.nodes[topic]['type'] = 'topic'
    G.nodes[word]['label'] = str(row['word'])
    G.nodes[word]['type'] = 'word'
    
nx.write_gexf(G, "05 Words and topics.gexf")

# %%
# Export network of actors and topics
import networkx as nx
threshold = 0.001
G = nx.Graph()
for index, row in df_list_style.iterrows():
    topic = 'T_'+str(row['topic'])
    actor = 'A_'+str(row['doc'])
    w = row['weight']
    
    if w > threshold:
        G.add_edge(topic, actor)
        G[topic][actor]['weight'] = w

        G.nodes[topic]['label'] = str(row['topic'])
        G.nodes[topic]['type'] = 'topic'
        G.nodes[actor]['label'] = str(row['doc'])
        G.nodes[actor]['type'] = 'actor'
    
nx.write_gexf(G, "06 Actors and topics.gexf")

# %% [markdown]
# # UMAP after the topics

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import umap

# %%
# Load data
df = pd.read_csv("04 Actors and their topics.csv")
df = df.dropna()

# %%
# Prepare data
reducer = umap.UMAP()
umap_data = df[
    [
        "topic_0",
        "topic_1",
        "topic_2",
        "topic_3",
        "topic_4",
        "topic_5",
        "topic_6",
        "topic_7",
        "topic_8",
        "topic_9",
        "topic_10",
        "topic_11",
        "topic_12",
        "topic_13",
        "topic_14",
        "topic_15",
        "topic_16",
        "topic_17",
        "topic_18",
        "topic_19",
        "topic_20",
        "topic_21",
        "topic_22",
        "topic_23",
        "topic_24",
        "topic_25",
        "topic_26",
        "topic_27",
        "topic_28",
        "topic_29",
        "topic_30",
        "topic_31",
        "topic_32",
        "topic_33",
        "topic_34",
        "topic_35",
        "topic_36",
        "topic_37",
        "topic_38",
        "topic_39"
    ]
].values
scaled_umap_data = StandardScaler().fit_transform(umap_data)

# %%
# Compute embedding
embedding = reducer.fit_transform(scaled_umap_data)
embedding.shape

# %%
# Monitor embedding
plt.scatter(
    embedding[:, 0],
    embedding[:, 1]
)
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection of the dataset', fontsize=24)

# %%
# Enrich source and download
xvalues = []
yvalues = []
for index, row in df.iterrows():
    coord = embedding[index]
    xvalues.append(coord[0])
    yvalues.append(coord[1])
df.insert(len(df.columns), 'X-UMAP', xvalues)
df.insert(len(df.columns), 'Y-UMAP', yvalues)

df.to_csv("07 Actors with topics + UMAP layout.csv", index = False, encoding='utf-8')
