# %%
# SETTINGS

number_topics = 15

# %% [markdown]
# # Filter
#
# Here we assume that the source file already contains the text, as it's a subcorpus.

# %%
# Filter the input file
import pandas as pd

df = pd.read_csv('00 source data (urls).csv')
df.fillna('', inplace=True)

# /!\ FILTERING
df = df[df['language'] == 'Danish']

df.to_csv("01 data filtered.csv", index = False, encoding='utf-8')

df
# Out:
#     result # search engine                                              query  \
# 0       33.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 1        4.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 2        0.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 3        9.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 4       41.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# ..       ...           ...                                                ...
# 527     82.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 528
# 529     51.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 530     88.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
# 531     26.0          bing  "miljø*" AND (“affald” OR “forurening” OR “nat...
#
#     discourse language           domain Manual actor name  \
# 0               Danish          norskov
# 1               Danish             mfvm
# 2               Danish        wikipedia
# 3               Danish     miljoeportal
# 4               Danish              avl
# ..        ...      ...              ...               ...
# 527             Danish              fmk
# 528             Danish  klimatilpasning
# 529             Danish          regionh
# 530             Danish          esbjerg
# 531             Danish             bane
#
#                                          article title  \
# 0                                                Miljø
# 1    Ministeriet for Fødevarer, Landbrug og Fiskeri...
# 2              Miljø - Wikipedia, den frie encyklopædi
# 3               Danmarks Miljøportal Miljoeportalen.dk
# 4            Miljø - Aage Vestergaard Larsen A/S - AVL
# ..                                                 ...
# 527        Miljø og Byg - Faaborg-Midtfyn Municipality
# 528                          tilføjet fra holstebro.dk
# 529                                   Miljø - Region H
# 530                             Plan & Miljø - Esbjerg
# 531                      GAB Miljø Anlæg | Banedanmark
#
#                                            article url  \
# 0                         https://www.norskov.dk/miljo
# 1                                     https://mfvm.dk/
# 2             https://da.wikipedia.org/wiki/Milj%C3%B8
# 3                             https://miljoeportal.dk/
# 4                                 https://avl.dk/miljo
# ..                                                 ...
# 527  https://www.fmk.dk/borger/miljoe-energi-og-aff...
# 528  https://www.klimatilpasning.dk/viden-om/fremti...
# 529  https://www.regionh.dk/til-fagfolk/miljoe/en-g...
# 530  https://www.esbjerg.dk/planer-projekter-og-tra...
# 531  https://www.bane.dk/da/Om-Banedanmark/Baeredyg...
#
#                                    article description  ...  \
# 0    Nørskov miljø er rigtig gode til at lave en si...  ...
# 1    Den 19. november 2020 er det besluttet, at Mil...  ...
# 2                                                       ...
# 3    Danmarks Miljøportal satser i vores strategi p...  ...
# 4    Miljø. Miljøet spares gennemsnitlig for 2,4 ki...  ...
# ..                                                 ...  ...
# 527  Afdelingen Miljø og Byg i Faaborg-Midtfyn Komm...  ...
# 528                                                     ...
# 529  Miljø Med FN"s verdensmål som pejlemærke arbej...  ...
# 530            Esbjerg Kommunes Plan &amp; Miljøudvalg  ...
# 531  Håndtering af affald Jordforurening Luftforure...  ...
#
#                                          canonical_url  \
# 0
# 1                   https://mfvm.dk/index.php?id=15654
# 2             https://da.wikipedia.org/wiki/Milj%C3%B8
# 3                             https://miljoeportal.dk/
# 4                                 https://avl.dk/miljo
# ..                                                 ...
# 527
# 528
# 529  https://www.regionh.dk/til-fagfolk/miljoe/en-g...
# 530  https://www.esbjerg.dk/planer-projekter-og-tra...
# 531  https://www.bane.dk/da/Om-Banedanmark/Baeredyg...
#
#                                                title  \
# 0                                              Miljø
# 1            Fødevareministeriet og Miljøministeriet
# 2            Miljø - Wikipedia, den frie encyklopædi
# 3                               Danmarks Miljøportal
# 4                Miljø - Aage Vestergaard Larsen A/S
# ..                                               ...
# 527                         CLEAN Grøn Erhvervsvækst
# 528                  Havniveau og klimaforandringer
# 529           Sådan arbejder vi med cirkulær økonomi
# 530             Grøn omstilling af energiforsyningen
# 531  \n\t\t\t\tVi reducerer vores el-forbrug\n\t\t\t
#
#                                            description  \
# 0    Nørskov Miljø hjælper virksomheder med alle ty...
# 1    Den 19. november 2020 er det besluttet, at Mil...
# 2
# 3                                 Danmarks Miljøportal
# 4    Miljøet spares for 2,4 kilo CO2 udslip for hve...
# ..                                                 ...
# 527  Faaborg-Midtfyn Kommune er partner i det offen...
# 528
# 529  I Region Hovedstaden arbejder vi for en grøn o...
# 530               Grøn omstilling af energiforsyningen
# 531
#
#                                            raw_content comments  \
# 0    De fleste virksomheder vil gerne have styr på ...
# 1    Den 19. november 2020 er det besluttet, at Mil...
# 2    Miljø\nMiljø betyder "omgivelser" og dækker og...
# 3    Seneste nyheder\nInvitation til webinar om Van...
# 4    Miljø\nMiljøet spares gennemsnitlig for 2,4 ki...
# ..                                                 ...      ...
# 527  Faaborg-Midtfyn Kommune er partner i det offen...
# 528  Havniveau og klimaforandringer\nOpvarmningen a...
# 529  Afsæt i dialog med interessenter\nOmstillingen...
# 530  Grøn omstilling af energiforsyningen\nHer er v...
# 531  Vi reducerer vores el-forbrug\nVi forsyner de ...
#
#                                    author categories  \
# 0                                 Pelle P
# 1
# 2    Bidragsydere til Wikimedia-projekter
# 3
# 4
# ..                                    ...        ...
# 527
# 528
# 529
# 530
# 531
#
#                                                   tags        date  \
# 0    MiljøcertificeringMiljøforholdMiljøkortlægning...
# 1
# 2                                                       2003-01-03
# 3    miljøportal|miljøvenlig|Danmarks Miljø|data om...
# 4                                                       2019-08-30
# ..                                                 ...         ...
# 527  CLEAN Grøn Erhvervsvækst|CLEAN|Grøn Erhvervsvæ...
# 528  andet|Her markerer man hvis ingen andre emneor...
# 529  Cirkulær økonomi|Regional udvikling Ressourcee...  2021-04-27
# 530  Grøn omstilling af energiforsyningen|Grøn omst...  2021-03-16
# 531
#
#                                            sitename
# 0
# 1    Ministeriet for Fødevarer, Landbrug og Fiskeri
# 2                   Wikipedia, den frie encyklopædi
# 3                              Danmarks Miljøportal
# 4                                               AVL
# ..                                              ...
# 527
# 528
# 529                                      regionh.dk
# 530                                      esbjerg.dk
# 531                                         Website
#
# [354 rows x 31 columns]

# %% [markdown]
# # Group content by actor

# %%
actor_dict = {}
for index, row in df.iterrows():
    if row['Manual actor name']:
        actor_id = row['Manual actor name']
    else:
        actor_id = row['domain']
    if actor_id in actor_dict:
        actor_obj = actor_dict[actor_id]
    else:
        actor_obj = {}
        actor_obj['Id'] = actor_id
        actor_obj['urls'] = ''
        actor_obj['text'] = ''
        actor_obj['language'] = row['language']
    
    actor_obj['urls'] = actor_obj['urls'] + str(row['article url']) + ' '
    actor_obj['text'] = actor_obj['text'] + str(row['raw_content']) + ' . '
    
    actor_dict[actor_id] = actor_obj
print("Actor index built.")
# Out:
# Actor index built.

# %%
# DOWNLOAD ACTORS
actors_df = pd.DataFrame.from_dict(actor_dict, orient='index')
actors_df.to_csv("02 Actors with text.csv", index = False, encoding='utf-8')
actors_df
# Out:
#                                           Id  \
# norskov                              norskov
# mfvm                                    mfvm
# wikipedia                          wikipedia
# miljoeportal                    miljoeportal
# avl                                      avl
# ...                                      ...
# Desmi                                  Desmi
# Niras                                  Niras
# Grønlands Rejsebureau  Grønlands Rejsebureau
# MOE A/S                              MOE A/S
# csrkompasset                    csrkompasset
#
#                                                                     urls  \
# norskov                https://www.norskov.dk/miljo https://www.norsk...
# mfvm                   https://mfvm.dk/ https://mfvm.dk/fileadmin/use...
# wikipedia              https://da.wikipedia.org/wiki/Milj%C3%B8 https...
# miljoeportal           https://miljoeportal.dk/ https://miljoeportal....
# avl                           https://avl.dk/miljo https://avl.dk/miljo
# ...                                                                  ...
# Desmi                                https://www.desmi.com/about-desmi/
# Niras                             https://www.niras.com/sustainability/
# Grønlands Rejsebureau        https://www.greenland-travel.dk/om-os/csr/
# MOE A/S                 https://www.moe.global/services/sustainability/
# csrkompasset           https://www.csrkompasset.dk/milj%C3%B8-0 https...
#
#                                                                     text  \
# norskov                De fleste virksomheder vil gerne have styr på ...
# mfvm                   Den 19. november 2020 er det besluttet, at Mil...
# wikipedia              Miljø\nMiljø betyder "omgivelser" og dækker og...
# miljoeportal           Seneste nyheder\nInvitation til webinar om Van...
# avl                    Miljø\nMiljøet spares gennemsnitlig for 2,4 ki...
# ...                                                                  ...
# Desmi                  DESMI is a global company\nFounded in 1834 and...
# Niras                  Realising your sustainable potential\nWe make ...
# Grønlands Rejsebureau  For den bedste oplevelse anbefaler vi at du br...
# MOE A/S                                               Skip to content .
# csrkompasset           Her kan I vælge at tilføje udvalgte miljøkrav,...
#
#                       language
# norskov                 Danish
# mfvm                    Danish
# wikipedia               Danish
# miljoeportal            Danish
# avl                     Danish
# ...                        ...
# Desmi                   Danish
# Niras                   Danish
# Grønlands Rejsebureau   Danish
# MOE A/S                 Danish
# csrkompasset            Danish
#
# [230 rows x 4 columns]

# %% [markdown]
# # LDA: extract topics

# %%
import pandas as pd
# This is for text mining
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# Source file (CSV)
source_file = "02 Actors with text.csv"
text_col_name = "text"

# More features is more dimensions for each document. You should probably keep it at 1000.
no_features = 1000

# %%
# LOAD DATA
documents_dictionary = {}
df = pd.read_csv(source_file)

for index, row in df.iterrows():
    key = row['Id']
    text = str(row[text_col_name])
    if len(text)>10:
        documents_dictionary[key] = text

# %%
# COMPUTE LDA TOPICS
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents_dictionary.values())
tf_feature_names = tf_vectorizer.get_feature_names()
lda = LatentDirichletAllocation(n_components=number_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)
print("LDA topics computed.")
# Out:
# LDA topics computed.

# %%
# DISPLAY RESULTS (for monitoring)
no_top_words = 25 # How many words to keep for each topic (there may be many)

# Create a data frame for convenience (for download, actually)
topics_df = pd.DataFrame(columns=['topic','word','weight'])

# Display topics to check it works. For each topic, we only display the top words.
i = 0
for topic_idx, topic in enumerate(lda.components_):
    print("# TOPIC_%d:" % (topic_idx))
    for j in topic.argsort()[:-no_top_words - 1:-1]:
        print(str(topic[j]) + "   " + tf_feature_names[j])
        topics_df.loc[i] = ["TOPIC_"+str(topic_idx), tf_feature_names[j], topic[j]]
        i = i+1
    print(" ")

topics_df
# Out:
# # TOPIC_0:
# 14.271418272142986   08
# 11.161153797516475   30
# 9.497650421292626   og
# 6.008935056350464   af
# 5.894259127784971   00
# 5.3078042294713725   til
# 5.149267652427766   er
# 3.9021912862683905   der
# 3.836122929942377   det
# 3.341712235525103   med
# 3.3260597179418543   12
# 3.0837980693219227   på
# 2.8251655877555613   kommune
# 2.737829522547469   har
# 2.6085185144267866   en
# 2.2862305702569685   vi
# 2.2737199976529925   kan
# 2.2558021163901207   skal
# 2.188245532963702   om
# 2.0017353275689485   den
# 1.876210393375421   forbindelse
# 1.87617990075079   som
# 1.7993125252444253   ikke
# 1.752351238036226   år
# 1.7392018079717386   grøn
#
# # TOPIC_1:
# 67.96220557197015   cradle
# 26.694762203185796   af
# 26.488682414960238   og
# 22.56383700090269   der
# 21.879553363923684   eps
# 21.74622692622571   er
# 21.526788137630973   til
# 20.10334693480404   pureprint
# 16.419480296853667   kls
# 15.375565052624575   det
# 12.887427428083155   en
# 12.730639336101408   som
# 11.277495820921152   kan
# 9.566223382158713   vi
# 9.224667777913156   ikke
# 9.054005273620554   med
# 8.854484007824874   certified
# 8.256252039429326   har
# 7.5265320856226285   på
# 7.4871441845367155   byg
# 7.168840787683665   certificeret
# 7.124356732915777   eller
# 7.1015899808257865   miljø
# 6.722652894252018   om
# 6.701779395117852   den
#
# # TOPIC_2:
# 2.8789338270694427   global
# 2.600021993733323   og
# 2.3566124482235673   environmental
# 1.6867979821153904   sustainable
# 1.3917685048601949   er
# 1.213915008698071   vision
# 1.1271659412559194   100
# 1.1135396178879369   development
# 1.0924283942540354   en
# 1.089905883213169   på
# 1.0727735657827042   der
# 1.059873966340174   med
# 1.0570316479092166   innovative
# 1.0517348100017792   af
# 1.026026125162724   fra
# 1.0144805266487424   har
# 0.9901260074968063   som
# 0.9054023433384019   det
# 0.8963523104214831   børn
# 0.8916630531063112   et
# 0.8740734411617199   den
# 0.8728985808011193   om
# 0.8656525667663628   vores
# 0.847555119444687   kan
# 0.8214939947692831   ikke
#
# # TOPIC_3:
# 3031.6933807719006   og
# 1404.1252663414411   er
# 1264.5676301877595   til
# 1169.4814155978843   af
# 1065.6869356129237   en
# 1021.5082400724613   på
# 1006.8815384844735   med
# 923.7690109449695   det
# 884.9641278242797   vi
# 693.583171148038   der
# 668.1857604296163   som
# 602.3228907670614   kan
# 569.5232697962414   om
# 557.6708886788948   har
# 544.4986105260035   et
# 466.8109723309541   den
# 385.086822505865   skal
# 373.1234837835084   vores
# 330.4828755721117   du
# 300.76109667524423   fra
# 299.44870910161166   bæredygtig
# 299.372414898355   mere
# 287.3184230371405   bæredygtighed
# 268.93067039136497   ikke
# 248.39557404013752   eller
#
# # TOPIC_4:
# 9.764023175427154   og
# 3.9991615443765345   er
# 3.646728948676282   af
# 3.2826255297101667   med
# 3.271392263486379   på
# 2.908081360985929   en
# 2.770652540942147   til
# 2.2660822819266806   det
# 2.21175927942246   om
# 2.165402911416641   der
# 2.1384184763456604   vi
# 2.136932988244309   kan
# 2.07640156653226   har
# 1.9753505878961242   skal
# 1.969990266175081   den
# 1.947922874118016   et
# 1.9007661807154095   alle
# 1.879390667554833   som
# 1.5441528899608554   aalborg
# 1.4489740389033734   verdensmål
# 1.411572891602498   udvikling
# 1.3634385452081605   bæredygtig
# 1.3348410388992165   mere
# 1.3134817677217796   verdensmålene
# 1.2848858746954723   få
#
# # TOPIC_5:
# 88.8792317165058   og
# 49.586754953597996   af
# 44.02680591350818   aalborg
# 33.048386728652574   er
# 29.470798264092643   med
# 29.116204226642704   kommune
# 28.13458164558853   der
# 27.06319889204147   en
# 22.776712686563513   på
# 22.757701998651843   til
# 21.84406705343037   det
# 19.140299377023513   den
# 17.17997278238607   om
# 12.615324243022748   har
# 12.485175920219369   kontakt
# 12.436996017030806   som
# 11.876620277435668   år
# 11.78921466657005   tlf
# 11.457413416501758   et
# 11.367839550704629   information
# 11.159654059033517   kommunes
# 11.138767226044287   yderligere
# 10.909502696866022   læs
# 10.790615825517163   skal
# 9.374071127381205   mere
#
# # TOPIC_6:
# 199.49505044760082   og
# 107.21313344346113   af
# 66.99000069369866   til
# 46.93969303633231   på
# 39.60401328225656   verdensmål
# 35.85461595257576   en
# 35.42710606554809   alle
# 30.220272118462674   den
# 29.623511273819066   er
# 29.12445952306215   skal
# 28.966227028175712   om
# 28.300524355963883   det
# 27.03540818668806   adgang
# 26.151131000934946   med
# 24.027233851901727   fremme
# 21.420269911080954   fx
# 20.153326459108698   17
# 19.89022017794798   bæredygtig
# 19.497653204749597   sikre
# 19.234013553384425   vi
# 18.216899108112543   verdensmålene
# 17.48796019568447   har
# 17.363857193228856   som
# 16.762642178260396   fn
# 16.54307152555577   der
#
# # TOPIC_7:
# 27.616170537487193   og
# 14.645541450499671   af
# 14.012570252128624   er
# 9.814149423528015   til
# 9.230239552821152   en
# 8.339103311427724   det
# 8.2853464940106   på
# 8.14977732341496   den
# 7.758097985351085   som
# 6.569009823779573   med
# 6.02400082306947   kan
# 5.0608598343728675   om
# 5.040626243264356   der
# 4.800089010004643   et
# 4.388116335442939   har
# 4.199123616747745   vi
# 4.136326894914942   skal
# 4.0700764833804985   verdensmål
# 3.8077663812790994   fra
# 3.5198058738019062   mere
# 3.45335222382634   vil
# 3.0489885042818985   bæredygtig
# 2.96171713271071   fn
# 2.950100917164876   ved
# 2.8439625492101803   vores
#
# # TOPIC_8:
# 52.77635465386449   og
# 24.096298725879414   er
# 19.931831211196165   til
# 17.662856469236882   en
# 15.602480642588331   af
# 14.804990591387158   det
# 14.540031612365691   på
# 12.785856589670693   der
# 12.70419882460045   med
# 12.359300699957327   som
# 11.443864789703028   vi
# 10.537415518575346   verdensmålene
# 9.697327653675352   om
# 9.648692075236719   den
# 9.42228708311745   har
# 8.248766222526033   kan
# 7.985077706771989   et
# 7.966731226060454   verdensmål
# 7.11976245676124   du
# 5.612208223795651   fn
# 5.476837303475871   skal
# 5.411150202827582   vil
# 5.149834653662212   mere
# 4.996363129543397   ikke
# 4.64575643377204   menneskerettigheder
#
# # TOPIC_9:
# 3.655658220399979   og
# 2.577671997508745   af
# 2.3748054148449347   er
# 1.827977288915856   til
# 1.7518090984421983   på
# 1.549774626956883   det
# 1.426686538687879   en
# 1.3258570157948142   der
# 1.2263566847848923   alle
# 1.1877061099789696   den
# 1.1274754039797543   fn
# 1.1274620925190262   om
# 1.110530921389688   som
# 1.0674516586751452   et
# 1.0667591541966777   med
# 1.0483799041610382   danmark
# 1.0136798677326888   fra
# 1.0117308150850093   har
# 0.9968624392589203   udvikling
# 0.9567700648676482   mål
# 0.9418562409839345   også
# 0.9355493243564331   ikke
# 0.9340638108879331   mennesker
# 0.922309101438206   fattigdom
# 0.9196745327170891   vil
#
# # TOPIC_10:
# 1.4652848149312843   og
# 1.4428716592434725   er
# 1.3595450779703064   af
# 1.2880466648827429   30
# 1.1124004922898982   08
# 1.0907707869813765   en
# 1.0560883141218278   til
# 0.9846172835953868   på
# 0.977029337705367   12
# 0.9394078316522793   der
# 0.9117418367292999   år
# 0.9039724589597885   som
# 0.884109028341457   det
# 0.8828060136567941   skal
# 0.8591141912536527   00
# 0.8342311934285573   fra
# 0.8247575453938838   den
# 0.8149198107896868   verdensmål
# 0.8057290648371098   17
# 0.803496696887963   har
# 0.8016828021305856   med
# 0.7956883111679066   ulighed
# 0.7919835992591725   mere
# 0.7746667648764218   jeg
# 0.7675501951476662   planter
#
# # TOPIC_11:
# 4.175996446003624   sustainable
# 4.105175824885347   og
# 3.4065387039133403   er
# 3.0294279842638323   sustainability
# 2.784345307735997   af
# 2.2568789858912686   goals
# 2.1385948073744703   til
# 2.0395618790593373   med
# 1.9078225387153047   der
# 1.9074821196403506   det
# 1.8411380989100332   en
# 1.8307929259347167   som
# 1.8088062054973386   development
# 1.7817686384633633   sdg
# 1.7349308278113071   vi
# 1.7108820509310712   digital
# 1.6135845661457353   mere
# 1.5905298706589395   på
# 1.5667519036680515   har
# 1.5017560198919562   et
# 1.4343731891286002   om
# 1.3072834580434833   transport
# 1.2482263034515015   vores
# 1.2125102135062504   global
# 1.2090303022576978   skal
#
# # TOPIC_12:
# 25.65188500365526   eudp
# 20.323792640626152   og
# 11.321486278835067   er
# 10.810817434939741   af
# 9.922505212624554   til
# 9.286614804197004   bilag
# 8.449073487561511   du
# 7.857638601259533   der
# 7.663591228941064   en
# 7.6507589070351605   med
# 7.356901064224795   på
# 6.815608675218916   om
# 6.393822683034047   det
# 6.259039607694245   fra
# 5.848826343998052   sustainability
# 5.293476459050257   sustainable
# 5.277615349823462   dk
# 5.0479934802475475   den
# 4.97378699133304   projekter
# 4.947102676058732   ens
# 4.924729715800844   har
# 4.894191065337484   hvis
# 4.7804378472069615   skal
# 4.465411770614298   støtte
# 4.269595789297449   2013
#
# # TOPIC_13:
# 2.6149357712220342   og
# 1.9228326547476218   til
# 1.504463603134962   der
# 1.4227722668773168   en
# 1.2688998867774155   af
# 1.2132083940960778   om
# 1.1693859018791073   som
# 1.1677500062486355   er
# 1.1584311643733471   på
# 1.0921769273763402   30
# 1.0877685983591123   aalborg
# 0.9380205606904327   med
# 0.9299745004843434   den
# 0.9103487628898713   skal
# 0.8946658861674882   08
# 0.8906437367662358   det
# 0.8706448471893166   vi
# 0.8662323170455073   bliver
# 0.857520987977691   kan
# 0.8475761723486165   et
# 0.8447970457044848   virksomheder
# 0.8333360280281117   blev
# 0.8284805055550954   ved
# 0.8252074850624612   institut
# 0.790982063499016   verdensmålene
#
# # TOPIC_14:
# 7.22665276764794   og
# 4.9832794813923265   er
# 3.6440680834607773   af
# 3.4230166355963734   det
# 3.409225102663555   vi
# 3.152088620405734   en
# 3.100104212329785   på
# 2.644292777821083   med
# 2.6337350467414145   til
# 2.3429920493298573   der
# 2.090595982307416   om
# 1.9466256100501538   som
# 1.8813308896544065   den
# 1.7555029348511124   kan
# 1.5716109421127749   har
# 1.5124225070384751   fra
# 1.380526477879336   skal
# 1.363700133276052   et
# 1.3266838984067473   udvikling
# 1.3192622062929387   vores
# 1.2644610095940654   bæredygtig
# 1.0973925927852872   end
# 1.092298441542311   ved
# 1.077195957271155   år
# 1.0723343244558856   bæredygtighed
#         topic           word     weight
# 0     TOPIC_0             08  14.271418
# 1     TOPIC_0             30  11.161154
# 2     TOPIC_0             og   9.497650
# 3     TOPIC_0             af   6.008935
# 4     TOPIC_0             00   5.894259
# ..        ...            ...        ...
# 370  TOPIC_14     bæredygtig   1.264461
# 371  TOPIC_14            end   1.097393
# 372  TOPIC_14            ved   1.092298
# 373  TOPIC_14             år   1.077196
# 374  TOPIC_14  bæredygtighed   1.072334
#
# [375 rows x 3 columns]

# %%
# COMPUTE DOC x TOPIC RELATIONS (network)
# We create a data frame to store the content. It looks like a matrix.
df_matrix_style = pd.DataFrame(columns=['doc']+[("TOPIC_"+str(i)) for i in range(0,number_topics)])

# We create a second data frame with the same data. It looks like a list.
# Depending on what you want to do, one or the other are most convenient.
df_list_style = pd.DataFrame(columns=['doc', 'topic', 'weight'])

doc_topic = lda.transform(tf)
docs = list(documents_dictionary.keys())
topic_index = {}
i1 = 0
i2 = 0
for j in range(len(docs)):
    key = docs[j]
    topic_weights = list(doc_topic[j])
    
    # Index
    topic_index[key] = topic_weights
    
    # Matrix style
    df_matrix_style.loc[i1] = [key]+topic_weights
    i1 = i1+1
    
    # List style
    for k, w in enumerate(topic_weights):
        df_list_style.loc[i2] = [key, "TOPIC_"+str(k), w]
        i2 = i2+1

print("Done.")
# Out:
# Done.

# %%
# Output articles & topics, matrix style, to check that it works:
df_matrix_style
# Out:
#                        doc   TOPIC_0   TOPIC_1   TOPIC_2   TOPIC_3   TOPIC_4  \
# 0                  norskov  0.000163  0.000163  0.000163  0.997718  0.000163
# 1                     mfvm  0.003922  0.003922  0.003922  0.387306  0.003922
# 2                wikipedia  0.000038  0.000038  0.000038  0.800058  0.000038
# 3             miljoeportal  0.001149  0.001149  0.001149  0.983908  0.001149
# 4                      avl  0.000138  0.000138  0.000138  0.998068  0.000138
# ..                     ...       ...       ...       ...       ...       ...
# 215                  Desmi  0.004762  0.004762  0.933333  0.004762  0.004762
# 216                  Niras  0.002778  0.002778  0.002778  0.002778  0.002778
# 217  Grønlands Rejsebureau  0.000111  0.000111  0.000111  0.998442  0.000111
# 218                MOE A/S  0.066667  0.066667  0.066667  0.066667  0.066667
# 219           csrkompasset  0.000048  0.000048  0.000048  0.999330  0.000048
#
#       TOPIC_5   TOPIC_6   TOPIC_7   TOPIC_8   TOPIC_9  TOPIC_10  TOPIC_11  \
# 0    0.000163  0.000163  0.000163  0.000163  0.000163  0.000163  0.000163
# 1    0.561714  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2    0.000038  0.199450  0.000038  0.000038  0.000038  0.000038  0.000038
# 3    0.001149  0.001149  0.001149  0.001149  0.001149  0.001149  0.001149
# 4    0.000138  0.000138  0.000138  0.000138  0.000138  0.000138  0.000138
# ..        ...       ...       ...       ...       ...       ...       ...
# 215  0.004762  0.004762  0.004762  0.004762  0.004762  0.004762  0.004762
# 216  0.002778  0.002778  0.002778  0.002778  0.002778  0.002778  0.961111
# 217  0.000111  0.000111  0.000111  0.000111  0.000111  0.000111  0.000111
# 218  0.066667  0.066667  0.066667  0.066667  0.066667  0.066667  0.066667
# 219  0.000048  0.000048  0.000048  0.000048  0.000048  0.000048  0.000048
#
#      TOPIC_12  TOPIC_13  TOPIC_14
# 0    0.000163  0.000163  0.000163
# 1    0.003922  0.003922  0.003922
# 2    0.000038  0.000038  0.000038
# 3    0.001149  0.001149  0.001149
# 4    0.000138  0.000138  0.000138
# ..        ...       ...       ...
# 215  0.004762  0.004762  0.004762
# 216  0.002778  0.002778  0.002778
# 217  0.000111  0.000111  0.000111
# 218  0.066667  0.066667  0.066667
# 219  0.000048  0.000048  0.000048
#
# [220 rows x 16 columns]

# %%
# Output articles & topics, list style, to check that it works:
df_list_style
# Out:
#                doc     topic    weight
# 0          norskov   TOPIC_0  0.000163
# 1          norskov   TOPIC_1  0.000163
# 2          norskov   TOPIC_2  0.000163
# 3          norskov   TOPIC_3  0.997718
# 4          norskov   TOPIC_4  0.000163
# ...            ...       ...       ...
# 3295  csrkompasset  TOPIC_10  0.000048
# 3296  csrkompasset  TOPIC_11  0.000048
# 3297  csrkompasset  TOPIC_12  0.000048
# 3298  csrkompasset  TOPIC_13  0.000048
# 3299  csrkompasset  TOPIC_14  0.000048
#
# [3300 rows x 3 columns]

# %%
# DOWNLOAD LDA results
# Note: these files can be used in Tableau or Table2Net to build various visualizations.

topics_df.to_csv("03-a LDA topics and their words.csv", index = False, encoding='utf-8')
# df_matrix_style.to_csv("03-? LDA actors and topics matrix.csv", index = False, encoding='utf-8')
df_list_style.to_csv("03-b LDA actors and topics list style.csv", index = False, encoding='utf-8')

# %%
# ENRICH FILE (and monitor new version)
for topic_id, topic in enumerate(lda.components_):
    colname = "topic_"+str(topic_id)
    values = []
    for index, row in df.iterrows():
        key = row['Id']
        if key in topic_index:
            val = topic_index[key][topic_id]
        else:
            val = 0
        values.append(val)
    df.insert(len(df.columns), colname, values)
df
# Out:
#                         Id                                               urls  \
# 0                  norskov  https://www.norskov.dk/miljo https://www.norsk...
# 1                     mfvm  https://mfvm.dk/ https://mfvm.dk/fileadmin/use...
# 2                wikipedia  https://da.wikipedia.org/wiki/Milj%C3%B8 https...
# 3             miljoeportal  https://miljoeportal.dk/ https://miljoeportal....
# 4                      avl         https://avl.dk/miljo https://avl.dk/miljo
# ..                     ...                                                ...
# 225                  Desmi                https://www.desmi.com/about-desmi/
# 226                  Niras             https://www.niras.com/sustainability/
# 227  Grønlands Rejsebureau        https://www.greenland-travel.dk/om-os/csr/
# 228                MOE A/S   https://www.moe.global/services/sustainability/
# 229           csrkompasset  https://www.csrkompasset.dk/milj%C3%B8-0 https...
#
#                                                   text language   topic_0  \
# 0    De fleste virksomheder vil gerne have styr på ...   Danish  0.000163
# 1    Den 19. november 2020 er det besluttet, at Mil...   Danish  0.003922
# 2    Miljø\nMiljø betyder "omgivelser" og dækker og...   Danish  0.000038
# 3    Seneste nyheder\nInvitation til webinar om Van...   Danish  0.001149
# 4    Miljø\nMiljøet spares gennemsnitlig for 2,4 ki...   Danish  0.000138
# ..                                                 ...      ...       ...
# 225  DESMI is a global company\nFounded in 1834 and...   Danish  0.004762
# 226  Realising your sustainable potential\nWe make ...   Danish  0.002778
# 227  For den bedste oplevelse anbefaler vi at du br...   Danish  0.000111
# 228                                 Skip to content .    Danish  0.066667
# 229  Her kan I vælge at tilføje udvalgte miljøkrav,...   Danish  0.000048
#
#       topic_1   topic_2   topic_3   topic_4   topic_5   topic_6   topic_7  \
# 0    0.000163  0.000163  0.997718  0.000163  0.000163  0.000163  0.000163
# 1    0.003922  0.003922  0.387306  0.003922  0.561714  0.003922  0.003922
# 2    0.000038  0.000038  0.800058  0.000038  0.000038  0.199450  0.000038
# 3    0.001149  0.001149  0.983908  0.001149  0.001149  0.001149  0.001149
# 4    0.000138  0.000138  0.998068  0.000138  0.000138  0.000138  0.000138
# ..        ...       ...       ...       ...       ...       ...       ...
# 225  0.004762  0.933333  0.004762  0.004762  0.004762  0.004762  0.004762
# 226  0.002778  0.002778  0.002778  0.002778  0.002778  0.002778  0.002778
# 227  0.000111  0.000111  0.998442  0.000111  0.000111  0.000111  0.000111
# 228  0.066667  0.066667  0.066667  0.066667  0.066667  0.066667  0.066667
# 229  0.000048  0.000048  0.999330  0.000048  0.000048  0.000048  0.000048
#
#       topic_8   topic_9  topic_10  topic_11  topic_12  topic_13  topic_14
# 0    0.000163  0.000163  0.000163  0.000163  0.000163  0.000163  0.000163
# 1    0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 2    0.000038  0.000038  0.000038  0.000038  0.000038  0.000038  0.000038
# 3    0.001149  0.001149  0.001149  0.001149  0.001149  0.001149  0.001149
# 4    0.000138  0.000138  0.000138  0.000138  0.000138  0.000138  0.000138
# ..        ...       ...       ...       ...       ...       ...       ...
# 225  0.004762  0.004762  0.004762  0.004762  0.004762  0.004762  0.004762
# 226  0.002778  0.002778  0.002778  0.961111  0.002778  0.002778  0.002778
# 227  0.000111  0.000111  0.000111  0.000111  0.000111  0.000111  0.000111
# 228  0.066667  0.066667  0.066667  0.066667  0.066667  0.066667  0.066667
# 229  0.000048  0.000048  0.000048  0.000048  0.000048  0.000048  0.000048
#
# [230 rows x 19 columns]

# %%
# DOWNLOAD ENRICHED FILE
df.drop(columns=[text_col_name]).to_csv("04 Actors and their topics.csv", index=False)

# %% [markdown]
# # Export LDA networks

# %%
# Export network of words and topics
import networkx as nx
G = nx.Graph()
for index, row in topics_df.iterrows():
    topic = 'T_'+str(row['topic'])
    word = 'W_'+str(row['word'])
    w = row['weight']
    
    G.add_edge(topic, word)
    G[topic][word]['weight'] = w
    
    G.nodes[topic]['label'] = str(row['topic'])
    G.nodes[topic]['type'] = 'topic'
    G.nodes[word]['label'] = str(row['word'])
    G.nodes[word]['type'] = 'word'
    
nx.write_gexf(G, "05 Words and topics.gexf")

# %%
# Export network of actors and topics
import networkx as nx
threshold = 0.001
G = nx.Graph()
for index, row in df_list_style.iterrows():
    topic = 'T_'+str(row['topic'])
    actor = 'A_'+str(row['doc'])
    w = row['weight']
    
    if w > threshold:
        G.add_edge(topic, actor)
        G[topic][actor]['weight'] = w

        G.nodes[topic]['label'] = str(row['topic'])
        G.nodes[topic]['type'] = 'topic'
        G.nodes[actor]['label'] = str(row['doc'])
        G.nodes[actor]['type'] = 'actor'
    
nx.write_gexf(G, "06 Actors and topics.gexf")

# %% [markdown]
# # UMAP after the topics

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import umap

# %%
# Load data
df = pd.read_csv("04 Actors and their topics.csv")
df = df.dropna()

# %%
# Prepare data
reducer = umap.UMAP()
umap_data = df[
    [
        "topic_0",
        "topic_1",
        "topic_2",
        "topic_3",
        "topic_4",
        "topic_5",
        "topic_6",
        "topic_7",
        "topic_8",
        "topic_9",
        "topic_10",
        "topic_11",
        "topic_12",
        "topic_13",
        "topic_14"
    ]
].values
scaled_umap_data = StandardScaler().fit_transform(umap_data)

# %%
# Compute embedding
embedding = reducer.fit_transform(scaled_umap_data)
embedding.shape
# Out:
# (230, 2)

# %%
# Monitor embedding
plt.scatter(
    embedding[:, 0],
    embedding[:, 1]
)
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection of the dataset', fontsize=24)
# Out:
# Text(0.5, 1.0, 'UMAP projection of the dataset')

# %%
# Enrich source and download
xvalues = []
yvalues = []
for index, row in df.iterrows():
    coord = embedding[index]
    xvalues.append(coord[0])
    yvalues.append(coord[1])
df.insert(len(df.columns), 'X-UMAP', xvalues)
df.insert(len(df.columns), 'Y-UMAP', yvalues)

df.to_csv("07 Actors with topics + UMAP layout.csv", index = False, encoding='utf-8')
