# %%
# SETTINGS

number_topics = 15

# %% [markdown]
# # Filter
#
# Here we assume that the source file already contains the text, as it's a subcorpus.

# %%
# Filter the input file
import pandas as pd

df = pd.read_csv('00 source data (urls).csv')
df.fillna('', inplace=True)

# /!\ FILTERING
df = df[(df['area'] == 'Sami') | (df['area'] == 'arctic norway')]

df.to_csv("01 data filtered.csv", index = False, encoding='utf-8')

df
# Out:
#       result # search engine       discourse           area  \
# 1112      2675          bing         UN SDGs           Sami
# 1121      2662          bing         UN SDGs           Sami
# 1126      2664          bing         UN SDGs           Sami
# 1129      2665          bing         UN SDGs           Sami
# 1130      2677          bing         UN SDGs           Sami
# ...        ...           ...             ...            ...
# 1769      3999          bing  sustainability  arctic norway
# 1773      3997          bing  sustainability  arctic norway
# 1774      2678          bing         UN SDGs           Sami
# 1775      3919          bing  sustainability  arctic norway
# 1776      3992          bing  sustainability  arctic norway
#
#                  domain actor name  \
# 1112               unep
# 1121                 lu
# 1126               nbim
# 1129                msc
# 1130             europa
# ...                 ...        ...
# 1769                 un
# 1773        tripadvisor
# 1774               oecd
# 1775  secretatlastravel
# 1776            booking
#
#                                           article title  \
# 1112            Water | UNEP - UN Environment Programme
# 1121  Home | Lund University Centre for Sustainabili...
# 1126       The fund - Norges Bank Investment Management
# 1129  Sustainable Fishing | MSC | Marine Stewardship...
# 1130  Climate Action | Climate Action - European Com...
# ...                                                 ...
# 1769  Svalbard Satellite Station - United Nations Su...
# 1773  Sustainable luxury - Review of Funken Lodge, L...
# 1774  Linking Indigenous communities with regional d...
# 1775  Arctic Cruises, Private Expeditions ... - Secr...
# 1776  Svalbard Hotell | Polfareren, Longyearbyen – U...
#
#                                             article url  \
# 1112          https://www.unep.org/explore-topics/water
# 1121                          https://www.lucsus.lu.se/
# 1126                               https://www.nbim.no/
# 1129                               https://www.msc.org/
# 1130                https://ec.europa.eu/clima/index_en
# ...                                                 ...
# 1769  https://www.un.org/sustainabledevelopment/blog...
# 1773  https://www.tripadvisor.com/ShowUserReviews-g5...
# 1774  http://www.oecd.org/regional/regional-policy/i...
# 1775                     https://secretatlastravel.com/
# 1776     https://www.booking.com/hotel/no/svalbard.html
#
#                                     article description  \
# 1112  Water is fundamental to life on our planet, bu...
# 1121  LUCSUS is a world class sustainability centre ...
# 1126  The fund has a small stake in more than 9,000 ...
# 1129  For 20 years the MSC has been part of a team e...
# 1130  China, the EU and Canada co-convene the 5th Mi...
# ...                                                 ...
# 1769  Svalbard Satellite Station. Alarmed by melting...
# 1773  2/15/2020 · Funken Lodge: Sustainable luxury -...
# 1774  Indigenous peoples represent about 5% of the w...
# 1775  Svalbard Expedition Micro Cruises 2021 and 202...
# 1776  The hotel"s Polfareren Restaurant offers a men...
#
#       total nr of results (best guess)  ...  \
# 1112                            930000  ...
# 1121                            930000  ...
# 1126                            930000  ...
# 1129                            930000  ...
# 1130                            930000  ...
# ...                                ...  ...
# 1769                           1820000  ...
# 1773                           1820000  ...
# 1774                            930000  ...
# 1775                           1820000  ...
# 1776                           1820000  ...
#
#                                           canonical_url  \
# 1112
# 1121                           http://www.lucsus.lu.se/
# 1126
# 1129
# 1130                https://ec.europa.eu/clima/index_en
# ...                                                 ...
# 1769
# 1773
# 1774
# 1775                 https://www.secretatlastravel.com/
# 1776  https://www.booking.com/hotel/no/svalbard.en-g...
#
#                                                   title  \
# 1112
# 1121                            Find us on social media
# 1126                                     About the fund
# 1129
# 1130                                     Climate Action
# ...                                                 ...
# 1769                         Svalbard Satellite Station
# 1773  Sustainable luxury - Review of Funken Lodge, L...
# 1774  Linking Indigenous communities with regional d...
# 1775  Secret Atlas | Arctic Cruises & Photo Tours on...
# 1776  ★★★★ Svalbard Hotell | Polfareren, Longyearbye...
#
#                                             description  \
# 1112
# 1121
# 1126
# 1129
# 1130                                   Climate Action -
# ...                                                 ...
# 1769
# 1773  Funken Lodge: Sustainable luxury - See 206 tra...
# 1774  This project was launched on 19 September 2017...
# 1775  Cruises on Small Expedition Vessels to the Arc...
# 1776  Centrally located in Longyearbyen, Svalbard Ho...
#
#                                             raw_content comments  author  \
# 1112
# 1121  News\nFabiola Espinoza Córdova studies climate...
# 1126  The fund's market value nok\nWe work to safegu...
# 1129
# 1130  Today, the European Commission has opened a ne...
# ...                                                 ...      ...     ...
# 1769  Alarmed by melting glacier in Norway, Ban says...           Martin
# 1773  It’s hard to find the words to describe just h...
# 1774  This project was launched on 19 September 2017...
# 1775  Welcome\nWe are a team of passionate explorers...
# 1776  Hotel Svalbard Hotell | Polfareren\nLongyearby...
#
#                                              categories  \
# 1112
# 1121
# 1126
# 1129
# 1130
# ...                                                 ...
# 1769
# 1773
# 1774
# 1775  Article|Svalbard|Travel Tips|Article|Svalbard|...
# 1776
#
#                                                    tags        date  \
# 1112
# 1121                                                     2021-04-19
# 1126
# 1129
# 1130              European Commission|European Union|EU  2021-04-22
# ...                                                 ...         ...
# 1769                                                     2015-07-09
# 1773  Funken Lodge|Longyearbyen|Norway|Sustainable l...  2020-02-15
# 1774  indgenous peoples|indigenous communities|indig...
# 1775                                                     2019-08-22
# 1776  Svalbard Hotell | Polfareren|Longyearbyen|Norw...  2020-04-06
#
#                                                sitename
# 1112
# 1121  Lund University Centre for Sustainability Studies
# 1126
# 1129
# 1130               Climate Action - European Commission
# ...                                                 ...
# 1769
# 1773  Review of Funken Lodge, Longyearbyen, Norway -...
# 1774                                               OECD
# 1775                                       Secret Atlas
# 1776                                        Booking.com
#
# [315 rows x 29 columns]

# %% [markdown]
# # Group content by actor

# %%
actor_dict = {}
for index, row in df.iterrows():
    if row['actor name']:
        actor_id = row['actor name']
    else:
        actor_id = row['domain']
    if actor_id in actor_dict:
        actor_obj = actor_dict[actor_id]
    else:
        actor_obj = {}
        actor_obj['Id'] = actor_id
        actor_obj['urls'] = ''
        actor_obj['text'] = ''
        actor_obj['discourse: Climate change'] = 'False'
        actor_obj['discourse: Environment'] = 'False'
        actor_obj['discourse: Green growth'] = 'False'
        actor_obj['discourse: Sustainability'] = 'False'
        actor_obj['discourse: UN SDGs'] = 'False'
        actor_obj['area: Arctic'] = 'False'
        actor_obj['area: Arctic Norway'] = 'False'
        actor_obj['area: Extended Arctic'] = 'False'
        actor_obj['area: Faroed Islands'] = 'False'
        actor_obj['area: Greenland'] = 'False'
        actor_obj['area: Iceland'] = 'False'
        actor_obj['area: Nunavut'] = 'False'
        actor_obj['area: Sami'] = 'False'
    
    actor_obj['urls'] = actor_obj['urls'] + str(row['article url']) + ' '
    actor_obj['text'] = actor_obj['text'] + str(row['raw_content']) + ' . '

    if row['discourse'] == 'Climate change':
        actor_obj['discourse: Climate change'] = 'True'
    if row['discourse'] == 'environment':
        actor_obj['discourse: Environment'] = 'True'
    if row['discourse'] == 'green growth':
        actor_obj['discourse: Green growth'] = 'True'
    if row['discourse'] == 'sustainability':
        actor_obj['discourse: Sustainability'] = 'True'
    if row['discourse'] == 'UN SDGs':
        actor_obj['discourse: UN SDGs'] = 'True'
    if row['area'] == 'arctic':
        actor_obj['area: Arctic'] = 'True'
    if row['area'] == 'arctic norway':
        actor_obj['area: Arctic Norway'] = 'True'
    if row['area'] == 'extended arctic':
        actor_obj['area: Extended Arctic'] = 'True'
    if row['area'] == 'faroe islands':
        actor_obj['area: Faroed Islands'] = 'True'
    if row['area'] == 'greenland':
        actor_obj['area: Greenland'] = 'True'
    if row['area'] == 'Iceland':
        actor_obj['area: Iceland'] = 'True'
    if row['area'] == 'Nunavut':
        actor_obj['area: Nunavut'] = 'True'
    if row['area'] == 'Sami':
        actor_obj['area: Sami'] = 'True'
    
    actor_dict[actor_id] = actor_obj
print("Actor index built.")
# Out:
# Actor index built.

# %%
# DOWNLOAD ACTORS
actors_df = pd.DataFrame.from_dict(actor_dict, orient='index')
actors_df.to_csv("02 Actors with text.csv", index = False, encoding='utf-8')
actors_df
# Out:
#                                       Id  \
# unep                                unep
# lu                                    lu
# nbim                                nbim
# msc                                  msc
# europa                            europa
# ...                                  ...
# hurtigrutensvalbard  hurtigrutensvalbard
# sunchemical                  sunchemical
# oecd                                oecd
# secretatlastravel      secretatlastravel
# booking                          booking
#
#                                                                   urls  \
# unep                        https://www.unep.org/explore-topics/water
# lu                                          https://www.lucsus.lu.se/
# nbim                                             https://www.nbim.no/
# msc                  https://www.msc.org/ https://www.msc.org/media...
# europa               https://ec.europa.eu/clima/index_en https://ec...
# ...                                                                ...
# hurtigrutensvalbard  https://hurtigrutensvalbard.com/en/about-svalb...
# sunchemical          https://www.sunchemical.com/sustainability/sus...
# oecd                 http://www.oecd.org/regional/regional-policy/i...
# secretatlastravel                      https://secretatlastravel.com/
# booking                https://www.booking.com/hotel/no/svalbard.html
#
#                                                                   text  \
# unep                                                                .
# lu                   News\nFabiola Espinoza Córdova studies climate...
# nbim                 The fund's market value nok\nWe work to safegu...
# msc                                                              .  .
# europa               Today, the European Commission has opened a ne...
# ...                                                                ...
# hurtigrutensvalbard  Share:\nThe world leader in exploration travel...
# sunchemical          Our annual Corporate Sustainability Report foc...
# oecd                 This project was launched on 19 September 2017...
# secretatlastravel    Welcome\nWe are a team of passionate explorers...
# booking              Hotel Svalbard Hotell | Polfareren\nLongyearby...
#
#                     discourse: Climate change discourse: Environment  \
# unep                                    False                  False
# lu                                      False                  False
# nbim                                    False                  False
# msc                                     False                  False
# europa                                   True                   True
# ...                                       ...                    ...
# hurtigrutensvalbard                     False                  False
# sunchemical                             False                  False
# oecd                                    False                  False
# secretatlastravel                       False                  False
# booking                                 False                  False
#
#                     discourse: Green growth discourse: Sustainability  \
# unep                                  False                     False
# lu                                    False                     False
# nbim                                  False                     False
# msc                                   False                     False
# europa                                 True                      True
# ...                                     ...                       ...
# hurtigrutensvalbard                   False                      True
# sunchemical                           False                      True
# oecd                                  False                     False
# secretatlastravel                     False                      True
# booking                               False                      True
#
#                     discourse: UN SDGs area: Arctic area: Arctic Norway  \
# unep                              True        False               False
# lu                                True        False               False
# nbim                              True        False               False
# msc                               True        False                True
# europa                            True        False                True
# ...                                ...          ...                 ...
# hurtigrutensvalbard              False        False                True
# sunchemical                      False        False                True
# oecd                              True        False               False
# secretatlastravel                False        False                True
# booking                          False        False                True
#
#                     area: Extended Arctic area: Faroed Islands  \
# unep                                False                False
# lu                                  False                False
# nbim                                False                False
# msc                                 False                False
# europa                              False                False
# ...                                   ...                  ...
# hurtigrutensvalbard                 False                False
# sunchemical                         False                False
# oecd                                False                False
# secretatlastravel                   False                False
# booking                             False                False
#
#                     area: Greenland area: Iceland area: Nunavut area: Sami
# unep                          False         False         False       True
# lu                            False         False         False       True
# nbim                          False         False         False       True
# msc                           False         False         False       True
# europa                        False         False         False       True
# ...                             ...           ...           ...        ...
# hurtigrutensvalbard           False         False         False      False
# sunchemical                   False         False         False      False
# oecd                          False         False         False       True
# secretatlastravel             False         False         False      False
# booking                       False         False         False      False
#
# [193 rows x 16 columns]

# %% [markdown]
# # LDA: extract topics

# %%
import pandas as pd
# This is for text mining
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# Source file (CSV)
source_file = "02 Actors with text.csv"
text_col_name = "text"

# More features is more dimensions for each document. You should probably keep it at 1000.
no_features = 1000

# %%
# LOAD DATA
documents_dictionary = {}
df = pd.read_csv(source_file)

for index, row in df.iterrows():
    key = row['Id']
    text = str(row[text_col_name])
    if len(text)>10:
        documents_dictionary[key] = text

# %%
# COMPUTE LDA TOPICS
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents_dictionary.values())
tf_feature_names = tf_vectorizer.get_feature_names()
lda = LatentDirichletAllocation(n_components=number_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)
print("LDA topics computed.")
# Out:
# LDA topics computed.

# %%
# DISPLAY RESULTS (for monitoring)
no_top_words = 25 # How many words to keep for each topic (there may be many)

# Create a data frame for convenience (for download, actually)
topics_df = pd.DataFrame(columns=['topic','word','weight'])

# Display topics to check it works. For each topic, we only display the top words.
i = 0
for topic_idx, topic in enumerate(lda.components_):
    print("# TOPIC_%d:" % (topic_idx))
    for j in topic.argsort()[:-no_top_words - 1:-1]:
        print(str(topic[j]) + "   " + tf_feature_names[j])
        topics_df.loc[i] = ["TOPIC_"+str(topic_idx), tf_feature_names[j], topic[j]]
        i = i+1
    print(" ")

topics_df
# Out:
# # TOPIC_0:
# 70.54154168647295   arctic
# 40.29272272709631   ban
# 37.535569488751825   oil
# 33.559103416607726   fuel
# 32.05825690511988   hfo
# 28.012473670068275   heavy
# 22.232285525874147   waters
# 21.81470140923117   shipping
# 20.671667554151334   imo
# 17.29684592454035   svalbard
# 16.684524377282145   ships
# 14.488526779763799   states
# 14.463215795681108   air
# 14.4146144269477   spill
# 13.552164803348486   environment
# 13.217958256515747   use
# 12.69185264525832   said
# 12.089248270653822   new
# 11.79287189383227   norway
# 10.506460449016664   environmental
# 10.110575129683596   clean
# 10.092957693976718   plastic
# 10.060447408841688   international
# 10.008084941035023   vessels
# 8.64995061221749   decision
#
# # TOPIC_1:
# 3.025854257148007   seed
# 2.847099376793184   svalbard
# 2.1925584138389116   global
# 2.10236263266493   vault
# 1.8727354182161542   food
# 1.7007428072516975   world
# 1.5761729461531546   norway
# 1.5319878125093576   crop
# 1.4893629002439095   norwegian
# 1.4511199891952598   energy
# 1.3896286832884264   trust
# 1.330950328776445   sea
# 1.3155752859025038   international
# 1.3018118576241058   seeds
# 1.2925109148640237   new
# 1.2498436100842363   hydrogen
# 1.2352188236597832   genetic
# 1.232441334030996   development
# 1.2177383489388527   group
# 1.2089775482889766   climate
# 1.2088056377732068   diversity
# 1.1503173958033075   arctic
# 1.1405716380543018   longyearbyen
# 1.1265224915120178   agriculture
# 1.126110890030264   said
#
# # TOPIC_2:
# 3.0004435071399107   arctic
# 2.602043347495442   svalbard
# 1.5151195790663572   global
# 1.511867302688405   climate
# 1.468159280040223   longyearbyen
# 1.44991966413223   ships
# 1.4410827885241708   sustainable
# 1.3855399595098465   impact
# 1.3024659134991792   expeditions
# 1.290267120222389   polar
# 1.278825979600707   fuel
# 1.2700751023033028   ice
# 1.2199796490210186   heavy
# 1.2126730259147482   norway
# 1.2105964968420517   oil
# 1.1753475995342184   cruise
# 1.1671883529414424   waters
# 1.1321186669861374   ban
# 1.1279847066401327   use
# 1.1195559765403522   2019
# 1.1185204864955223   environmental
# 1.114155686334575   future
# 1.1086346206543904   government
# 1.0921587021078312   year
# 1.036581749552394   north
#
# # TOPIC_3:
# 43.806764287395225   eu
# 41.951441091400135   arctic
# 39.131454285870326   sustainable
# 37.83236418879357   development
# 31.40409268398481   indigenous
# 30.623717269139256   climate
# 29.60587920401473   sustainability
# 27.968943410987073   environmental
# 23.965172933725256   research
# 23.470230055112545   policy
# 22.72657750079735   global
# 21.81593577480087   work
# 20.102203326122325   social
# 19.921373642654974   environment
# 19.517590009041427   change
# 18.586932199609258   economic
# 18.483329695658448   european
# 18.37591677444434   peoples
# 18.210517486454634   emissions
# 17.980048310120452   impact
# 16.8276889385922   innovation
# 16.11990735479588   health
# 15.282857064769127   action
# 15.0984795612508   support
# 14.922806472703883   international
#
# # TOPIC_4:
# 43.16473079112224   polar
# 39.822650111248684   svalbard
# 36.495100125181644   ice
# 30.156662591234152   arctic
# 28.47650520622222   tourism
# 24.30810696327334   climate
# 24.2639163652234   data
# 23.668244819349088   2019
# 22.16064045586362   sea
# 21.793047396387617   norwegian
# 20.978569841776274   vessels
# 19.889814340600235   10
# 18.917063557781905   change
# 17.498435893310962   number
# 17.460474526733776   bears
# 15.96940820395695   environmental
# 15.649235454806593   et
# 15.595328247172574   study
# 15.30262072747795   doi
# 15.059486909180109   al
# 14.93493463859897   institute
# 13.354425815545024   2020
# 13.021347927015148   high
# 12.588937906964848   2018
# 12.260753989669322   pollutants
#
# # TOPIC_5:
# 255.25840118248732   svalbard
# 132.60479731582404   longyearbyen
# 93.62240977056886   arctic
# 86.39280174686692   world
# 66.43475498756146   polar
# 61.647947891221705   like
# 61.51353794143719   time
# 60.772174749832494   norway
# 56.65320948978683   people
# 53.06866270338567   town
# 52.63785050150498   tourism
# 51.39544739183623   sustainable
# 47.79758390727831   coal
# 46.02790738584547   local
# 45.04677279185322   just
# 44.822717075995556   day
# 41.43756595399996   north
# 40.90761722381512   industry
# 38.05367933512659   way
# 37.3936481375573   ice
# 36.8165530932672   make
# 35.649679570921336   visit
# 34.91927202234113   bears
# 34.88755132448809   read
# 34.87265330284694   new
#
# # TOPIC_6:
# 104.5581150403427   seed
# 97.7813870730236   vault
# 81.90137941506133   seeds
# 75.75747768964422   svalbard
# 51.87383875318406   global
# 40.562912880046646   food
# 37.864238342727916   crop
# 33.11600499955401   world
# 27.248080051893098   climate
# 25.358321865032156   bank
# 24.32407463967886   banks
# 24.102755220137144   norwegian
# 22.701430995670613   gene
# 20.407450364100242   samples
# 19.847069972225462   diversity
# 18.99189409494001   international
# 18.817089887430978   deposit
# 18.22701620009721   norway
# 17.113432357593435   trust
# 17.102322419896627   new
# 16.481174262719424   plant
# 16.420576750758276   archipelago
# 15.761770393941358   genetic
# 15.730783423484347   million
# 15.350618609076436   crops
#
# # TOPIC_7:
# 20.100192405948093   svalbard
# 13.952554730886346   additional
# 13.505574264527418   charge
# 10.14037514052656   site
# 8.913252525892155   property
# 8.018685181470964   business
# 7.454286132245891   government
# 6.583013787041317   norwegian
# 6.396416486573157   tourism
# 6.263973928095258   free
# 5.978321814671108   local
# 5.859270073296828   safety
# 5.847879138655783   methane
# 5.619629164739765   sustainable
# 5.441467128263608   large
# 5.209201870742355   question
# 5.170452697567219   facilities
# 5.099719340057625   longyearbyen
# 4.809274519756911   businesses
# 4.616670107031677   activities
# 4.5552065427995885   help
# 4.52954260836491   wants
# 4.476763459688521   development
# 4.470640529365124   service
# 4.0990526397470095   industry
#
# # TOPIC_8:
# 4.560731706478656   svalbard
# 2.4461870051160637   longyearbyen
# 2.0470899455997307   arctic
# 1.948382605719731   polar
# 1.7403150464824362   tourism
# 1.6877019427894762   cruise
# 1.5976199793616734   pdf
# 1.4488301284296634   world
# 1.4277947870934484   seed
# 1.419104635680764   expedition
# 1.3949815211593317   says
# 1.3769646138124976   norway
# 1.2884037896231129   international
# 1.2771392004202298   sustainable
# 1.268455321201377   climate
# 1.2573516311697785   global
# 1.2253473501810384   local
# 1.2205911426690514   food
# 1.1975439781801342   change
# 1.1583552985000904   nature
# 1.1544098718994464   environmental
# 1.1353755377401868   industry
# 1.112428391301247   ships
# 1.1026068961084103   destination
# 1.0906182684096324   sea
#
# # TOPIC_9:
# 2.322175120483535   svalbard
# 2.282043791888174   arctic
# 2.087787700689323   population
# 2.006583679005963   environment
# 1.3779085451790662   norwegian
# 1.3445959846028088   tourism
# 1.2941065930946543   nordic
# 1.2930752445422269   water
# 1.2689384111118909   waste
# 1.2621497328351678   ice
# 1.2363840628565246   polar
# 1.2319465595608918   social
# 1.2156071562096427   activities
# 1.2059274054145936   film
# 1.2004424522433308   research
# 1.16911401994211   festival
# 1.1039768625635247   environmental
# 1.0957562059204746   north
# 1.0934510181545811   available
# 1.0620723604729525   coastal
# 1.0593709085441307   economic
# 1.056313870141489   plastic
# 1.0543599860339412   world
# 1.0529014245562367   access
# 1.0499653767323418   norway
#
# # TOPIC_10:
# 314.898297631993   svalbard
# 164.50064580439428   arctic
# 137.14503229770202   polar
# 68.3808934629423   ice
# 58.71600151711868   bears
# 53.760360234811394   spitsbergen
# 51.243334436362154   bear
# 51.00223148017335   environmental
# 49.545076349924116   norwegian
# 48.69897017839782   environment
# 48.63047288480363   sea
# 47.797352886433146   norway
# 47.23488277092013   areas
# 46.82565701081547   section
# 43.74132262120853   use
# 42.86734237545686   act
# 42.830805353324486   time
# 42.496662182965345   fishing
# 41.21276111342413   governor
# 40.70928090875872   shall
# 40.3845097121063   regulations
# 40.33673656972484   north
# 38.91105870322874   area
# 38.698711641901276   20
# 38.46135695371623   land
#
# # TOPIC_11:
# 43.692030645060655   warranty
# 23.171922015955705   quartz
# 21.183431619953467   product
# 20.852269958287934   damage
# 18.336276745097965   petroleum
# 17.119332774906688   does
# 16.245619032699345   cover
# 15.814344814007807   regulations
# 15.355397199775627   art
# 14.843207941666964   activities
# 12.775025665416734   pollution
# 12.549400917388235   norwegian
# 12.494754268930764   para
# 12.420102801972897   www
# 10.865378689030877   surface
# 10.611508833233957   10
# 10.17458666647182   http
# 10.120952026192384   limited
# 10.006239010611765   june
# 9.75676401288005   2010
# 9.36810558702519   liability
# 8.867415451608894   use
# 8.810394612120781   svalbard
# 8.550370929686933   shall
# 8.549260667470616   cm
#
# # TOPIC_12:
# 221.18502284172638   svalbard
# 124.06201952601282   passengers
# 123.36612265313677   expedition
# 122.26065132304717   2021
# 117.3523993210287   days
# 114.077770423169   usd
# 108.44690393903028   2022
# 83.86937558859267   11
# 75.44759446538724   12
# 66.42571168652466   arctic
# 61.66016029114668   guide
# 53.032331004550045   53
# 47.67380557085955   ice
# 45.8254628224544   quest
# 38.264574802790506   adventure
# 33.64587652123582   10
# 33.28777513658289   stockholm
# 31.907116812607065   north
# 30.395353724683794   polar
# 28.53026840694156   jun
# 28.33992256755156   aug
# 28.099184944294247   590
# 27.821899880531134   jul
# 25.869279049906392   cruise
# 23.74618006650637   sea
#
# # TOPIC_13:
# 40.820855773770724   svalbard
# 39.08896970186735   energy
# 28.988769142915753   hydrogen
# 21.895797844609564   power
# 16.679557219743465   solution
# 15.422725769403149   reindeer
# 14.551791819243752   coal
# 12.61210677549339   renewable
# 12.40320704814746   statkraft
# 10.742354652494752   new
# 10.494810884708965   plant
# 10.002793877544   electricity
# 9.974061245817834   wind
# 9.550914730031431   2016
# 8.979392875808808   proposal
# 8.616641127281579   business
# 8.474429519424833   norway
# 8.414355598081357   fuel
# 8.25828212787712   gas
# 8.221654715673438   says
# 7.971593899404434   report
# 7.861376239913514   production
# 7.633012276679462   north
# 7.536293271131661   december
# 7.461104983961329   future
#
# # TOPIC_14:
# 1.6774242746700516   indigenous
# 1.3940917045971066   arctic
# 1.3078237056327529   world
# 1.2565651450125477   svalbard
# 1.2482492932198046   polar
# 1.1240420584372166   climate
# 1.0924901234823425   norwegian
# 1.0865087436616319   2020
# 1.0761739875849328   peoples
# 1.0521943239396851   environmental
# 1.0470761064671088   ban
# 1.024083063842286   change
# 1.0222136978782332   shall
# 1.0029262406068657   new
# 0.9944411356379845   2021
# 0.9935727577176487   work
# 0.969351560165353   global
# 0.9651773262535388   environment
# 0.962004274115882   2019
# 0.9467617128664132   act
# 0.9385137484748916   activities
# 0.9325579582907255   energy
# 0.9299491097556191   impact
# 0.929208231991781   information
# 0.9211311811137673   rights
#         topic         word     weight
# 0     TOPIC_0       arctic  70.541542
# 1     TOPIC_0          ban  40.292723
# 2     TOPIC_0          oil  37.535569
# 3     TOPIC_0         fuel  33.559103
# 4     TOPIC_0          hfo  32.058257
# ..        ...          ...        ...
# 370  TOPIC_14   activities   0.938514
# 371  TOPIC_14       energy   0.932558
# 372  TOPIC_14       impact   0.929949
# 373  TOPIC_14  information   0.929208
# 374  TOPIC_14       rights   0.921131
#
# [375 rows x 3 columns]

# %%
# COMPUTE DOC x TOPIC RELATIONS (network)
# We create a data frame to store the content. It looks like a matrix.
df_matrix_style = pd.DataFrame(columns=['doc']+[("TOPIC_"+str(i)) for i in range(0,number_topics)])

# We create a second data frame with the same data. It looks like a list.
# Depending on what you want to do, one or the other are most convenient.
df_list_style = pd.DataFrame(columns=['doc', 'topic', 'weight'])

doc_topic = lda.transform(tf)
docs = list(documents_dictionary.keys())
topic_index = {}
i1 = 0
i2 = 0
for j in range(len(docs)):
    key = docs[j]
    topic_weights = list(doc_topic[j])
    
    # Index
    topic_index[key] = topic_weights
    
    # Matrix style
    df_matrix_style.loc[i1] = [key]+topic_weights
    i1 = i1+1
    
    # List style
    for k, w in enumerate(topic_weights):
        df_list_style.loc[i2] = [key, "TOPIC_"+str(k), w]
        i2 = i2+1

print("Done.")
# Out:
# Done.

# %%
# Output articles & topics, matrix style, to check that it works:
df_matrix_style
# Out:
#                      doc   TOPIC_0   TOPIC_1   TOPIC_2   TOPIC_3   TOPIC_4  \
# 0                     lu  0.002020  0.002020  0.002020  0.856402  0.002020
# 1                   nbim  0.000490  0.000490  0.000490  0.571518  0.000490
# 2                 europa  0.000024  0.000024  0.000024  0.999671  0.000024
# 3                  iwgia  0.000289  0.000289  0.000289  0.995960  0.000289
# 4              northvolt  0.004167  0.004167  0.004167  0.468394  0.004167
# ..                   ...       ...       ...       ...       ...       ...
# 164  hurtigrutensvalbard  0.000590  0.000590  0.000590  0.000590  0.000590
# 165          sunchemical  0.001307  0.001307  0.001307  0.981699  0.001307
# 166                 oecd  0.000601  0.000601  0.000601  0.991592  0.000601
# 167    secretatlastravel  0.000490  0.000490  0.000490  0.000490  0.000490
# 168              booking  0.000285  0.000285  0.000285  0.000285  0.000285
#
#       TOPIC_5   TOPIC_6   TOPIC_7   TOPIC_8   TOPIC_9  TOPIC_10  TOPIC_11  \
# 0    0.002020  0.002020  0.002020  0.002020  0.002020  0.002020  0.002020
# 1    0.089477  0.117783  0.000490  0.000490  0.000490  0.215830  0.000490
# 2    0.000024  0.000024  0.000024  0.000024  0.000024  0.000024  0.000024
# 3    0.000289  0.000289  0.000289  0.000289  0.000289  0.000289  0.000289
# 4    0.477439  0.004167  0.004167  0.004167  0.004167  0.004167  0.004167
# ..        ...       ...       ...       ...       ...       ...       ...
# 164  0.991740  0.000590  0.000590  0.000590  0.000590  0.000590  0.000590
# 165  0.001307  0.001307  0.001307  0.001307  0.001307  0.001307  0.001307
# 166  0.000601  0.000601  0.000601  0.000601  0.000601  0.000601  0.000601
# 167  0.368023  0.000490  0.000490  0.000490  0.000490  0.000490  0.000490
# 168  0.000285  0.000285  0.996011  0.000285  0.000285  0.000285  0.000285
#
#      TOPIC_12  TOPIC_13  TOPIC_14
# 0    0.117336  0.002020  0.002020
# 1    0.000490  0.000490  0.000490
# 2    0.000024  0.000024  0.000024
# 3    0.000289  0.000289  0.000289
# 4    0.004167  0.004167  0.004167
# ..        ...       ...       ...
# 164  0.000590  0.000590  0.000590
# 165  0.001307  0.001307  0.001307
# 166  0.000601  0.000601  0.000601
# 167  0.625605  0.000490  0.000490
# 168  0.000285  0.000285  0.000285
#
# [169 rows x 16 columns]

# %%
# Output articles & topics, list style, to check that it works:
df_list_style
# Out:
#           doc     topic    weight
# 0          lu   TOPIC_0  0.002020
# 1          lu   TOPIC_1  0.002020
# 2          lu   TOPIC_2  0.002020
# 3          lu   TOPIC_3  0.856402
# 4          lu   TOPIC_4  0.002020
# ...       ...       ...       ...
# 2530  booking  TOPIC_10  0.000285
# 2531  booking  TOPIC_11  0.000285
# 2532  booking  TOPIC_12  0.000285
# 2533  booking  TOPIC_13  0.000285
# 2534  booking  TOPIC_14  0.000285
#
# [2535 rows x 3 columns]

# %%
# DOWNLOAD LDA results
# Note: these files can be used in Tableau or Table2Net to build various visualizations.

topics_df.to_csv("03-a LDA topics and their words.csv", index = False, encoding='utf-8')
# df_matrix_style.to_csv("03-? LDA actors and topics matrix.csv", index = False, encoding='utf-8')
df_list_style.to_csv("03-b LDA actors and topics list style.csv", index = False, encoding='utf-8')

# %%
# ENRICH FILE (and monitor new version)
for topic_id, topic in enumerate(lda.components_):
    colname = "topic_"+str(topic_id)
    values = []
    for index, row in df.iterrows():
        key = row['Id']
        if key in topic_index:
            val = topic_index[key][topic_id]
        else:
            val = 0
        values.append(val)
    df.insert(len(df.columns), colname, values)
df
# Out:
#                       Id                                               urls  \
# 0                   unep         https://www.unep.org/explore-topics/water
# 1                     lu                         https://www.lucsus.lu.se/
# 2                   nbim                              https://www.nbim.no/
# 3                    msc  https://www.msc.org/ https://www.msc.org/media...
# 4                 europa  https://ec.europa.eu/clima/index_en https://ec...
# ..                   ...                                                ...
# 188  hurtigrutensvalbard  https://hurtigrutensvalbard.com/en/about-svalb...
# 189          sunchemical  https://www.sunchemical.com/sustainability/sus...
# 190                 oecd  http://www.oecd.org/regional/regional-policy/i...
# 191    secretatlastravel                    https://secretatlastravel.com/
# 192              booking    https://www.booking.com/hotel/no/svalbard.html
#
#                                                   text  \
# 0                                                   .
# 1    News\nFabiola Espinoza Córdova studies climate...
# 2    The fund's market value nok\nWe work to safegu...
# 3                                                .  .
# 4    Today, the European Commission has opened a ne...
# ..                                                 ...
# 188  Share:\nThe world leader in exploration travel...
# 189  Our annual Corporate Sustainability Report foc...
# 190  This project was launched on 19 September 2017...
# 191  Welcome\nWe are a team of passionate explorers...
# 192  Hotel Svalbard Hotell | Polfareren\nLongyearby...
#
#      discourse: Climate change  discourse: Environment  \
# 0                        False                   False
# 1                        False                   False
# 2                        False                   False
# 3                        False                   False
# 4                         True                    True
# ..                         ...                     ...
# 188                      False                   False
# 189                      False                   False
# 190                      False                   False
# 191                      False                   False
# 192                      False                   False
#
#      discourse: Green growth  discourse: Sustainability  discourse: UN SDGs  \
# 0                      False                      False                True
# 1                      False                      False                True
# 2                      False                      False                True
# 3                      False                      False                True
# 4                       True                       True                True
# ..                       ...                        ...                 ...
# 188                    False                       True               False
# 189                    False                       True               False
# 190                    False                      False                True
# 191                    False                       True               False
# 192                    False                       True               False
#
#      area: Arctic  area: Arctic Norway  ...   topic_5   topic_6   topic_7  \
# 0           False                False  ...  0.000000  0.000000  0.000000
# 1           False                False  ...  0.002020  0.002020  0.002020
# 2           False                False  ...  0.089477  0.117783  0.000490
# 3           False                 True  ...  0.000000  0.000000  0.000000
# 4           False                 True  ...  0.000024  0.000024  0.000024
# ..            ...                  ...  ...       ...       ...       ...
# 188         False                 True  ...  0.991740  0.000590  0.000590
# 189         False                 True  ...  0.001307  0.001307  0.001307
# 190         False                False  ...  0.000601  0.000601  0.000601
# 191         False                 True  ...  0.368023  0.000490  0.000490
# 192         False                 True  ...  0.000285  0.000285  0.996011
#
#       topic_8   topic_9  topic_10  topic_11  topic_12  topic_13  topic_14
# 0    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    0.002020  0.002020  0.002020  0.002020  0.117336  0.002020  0.002020
# 2    0.000490  0.000490  0.215830  0.000490  0.000490  0.000490  0.000490
# 3    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    0.000024  0.000024  0.000024  0.000024  0.000024  0.000024  0.000024
# ..        ...       ...       ...       ...       ...       ...       ...
# 188  0.000590  0.000590  0.000590  0.000590  0.000590  0.000590  0.000590
# 189  0.001307  0.001307  0.001307  0.001307  0.001307  0.001307  0.001307
# 190  0.000601  0.000601  0.000601  0.000601  0.000601  0.000601  0.000601
# 191  0.000490  0.000490  0.000490  0.000490  0.625605  0.000490  0.000490
# 192  0.000285  0.000285  0.000285  0.000285  0.000285  0.000285  0.000285
#
# [193 rows x 31 columns]

# %%
# DOWNLOAD ENRICHED FILE
df.drop(columns=[text_col_name]).to_csv("04 Actors and their topics.csv", index=False)

# %% [markdown]
# # Export LDA networks

# %%
# Export network of words and topics
import networkx as nx
G = nx.Graph()
for index, row in topics_df.iterrows():
    topic = 'T_'+str(row['topic'])
    word = 'W_'+str(row['word'])
    w = row['weight']
    
    G.add_edge(topic, word)
    G[topic][word]['weight'] = w
    
    G.nodes[topic]['label'] = str(row['topic'])
    G.nodes[topic]['type'] = 'topic'
    G.nodes[word]['label'] = str(row['word'])
    G.nodes[word]['type'] = 'word'
    
nx.write_gexf(G, "05 Words and topics.gexf")

# %%
# Export network of actors and topics
import networkx as nx
threshold = 0.001
G = nx.Graph()
for index, row in df_list_style.iterrows():
    topic = 'T_'+str(row['topic'])
    actor = 'A_'+str(row['doc'])
    w = row['weight']
    
    if w > threshold:
        G.add_edge(topic, actor)
        G[topic][actor]['weight'] = w

        G.nodes[topic]['label'] = str(row['topic'])
        G.nodes[topic]['type'] = 'topic'
        G.nodes[actor]['label'] = str(row['doc'])
        G.nodes[actor]['type'] = 'actor'
    
nx.write_gexf(G, "06 Actors and topics.gexf")

# %% [markdown]
# # UMAP after the topics

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import umap

# %%
# Load data
df = pd.read_csv("04 Actors and their topics.csv")
df = df.dropna()

# %%
# Prepare data
reducer = umap.UMAP()
umap_data = df[
    [
        "topic_0",
        "topic_1",
        "topic_2",
        "topic_3",
        "topic_4",
        "topic_5",
        "topic_6",
        "topic_7",
        "topic_8",
        "topic_9",
        "topic_10",
        "topic_11",
        "topic_12",
        "topic_13",
        "topic_14"
    ]
].values
scaled_umap_data = StandardScaler().fit_transform(umap_data)

# %%
# Compute embedding
embedding = reducer.fit_transform(scaled_umap_data)
embedding.shape
# Out:
# (193, 2)

# %%
# Monitor embedding
plt.scatter(
    embedding[:, 0],
    embedding[:, 1]
)
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection of the dataset', fontsize=24)
# Out:
# Text(0.5, 1.0, 'UMAP projection of the dataset')

# %%
# Enrich source and download
xvalues = []
yvalues = []
for index, row in df.iterrows():
    coord = embedding[index]
    xvalues.append(coord[0])
    yvalues.append(coord[1])
df.insert(len(df.columns), 'X-UMAP', xvalues)
df.insert(len(df.columns), 'Y-UMAP', yvalues)

df.to_csv("07 Actors with topics + UMAP layout.csv", index = False, encoding='utf-8')
