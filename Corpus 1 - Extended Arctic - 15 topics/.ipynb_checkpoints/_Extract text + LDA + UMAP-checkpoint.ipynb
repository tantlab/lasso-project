# %%
# SETTINGS

number_topics = 15

# %% [markdown]
# # Filter
#
# Here we assume that the source file already contains the text, as it's a subcorpus.

# %%
# Filter the input file
import pandas as pd

df = pd.read_csv('00 source data (urls).csv')
df.fillna('', inplace=True)

# /!\ FILTERING
df = df[df['area'] == 'extended arctic']

df.to_csv("01 data filtered.csv", index = False, encoding='utf-8')

df
# Out:
#       result # search engine       discourse             area        domain  \
# 345        515          bing     environment  extended arctic          unep
# 354        538          bing     environment  extended arctic          unep
# 360        510          bing     environment  extended arctic         aecom
# 363        535          bing     environment  extended arctic     ducksters
# 366        530          bing     environment  extended arctic     worldbank
# ...        ...           ...             ...              ...           ...
# 913        998          bing  sustainability  extended arctic            un
# 942        935          bing  sustainability  extended arctic       denmark
# 996        857          bing    green growth  extended arctic  adidas-group
# 1037       934          bing  sustainability  extended arctic      tescoplc
# 1473       989          bing  sustainability  extended arctic  adidas-group
#
#      actor name                                      article title  \
# 345                                UNEP - UN Environment Programme
# 354                                           Environment Assembly
# 360                                 Environmental Services | AECOM
# 363                               Environment for Kids - Ducksters
# 366                              Environment Overview - World Bank
# ...         ...                                                ...
# 913                        ENVIRONMENTAL AND SOCIAL SUSTAINABILITY
# 942              Sustainability in Denmark | The pioneer in pro...
# 996                                      adidas - General Approach
# 1037                                    Sustainability - Tesco PLC
# 1473                               adidas - Sustainability History
#
#                                             article url  \
# 345                               https://www.unep.org/
# 354           https://www.unep.org/environmentassembly/
# 360   https://aecom.com/services/environmental-servi...
# 363      https://www.ducksters.com/science/environment/
# 366   https://www.worldbank.org/en/topic/environment...
# ...                                                 ...
# 913   https://sustainabledevelopment.un.org/content/...
# 942   https://denmark.dk/innovation-and-design/susta...
# 996   https://www.adidas-group.com/en/sustainability...
# 1037           https://www.tescoplc.com/sustainability/
# 1473  https://www.adidas-group.com/en/sustainability...
#
#                                     article description  \
# 345   A healthy environment plays a key role in meet...
# 354   The United Nations Environment Assembly is the...
# 360   The AECOM environmental services group helps i...
# 363   The Earth"s environment is constantly recyclin...
# 366   4/16/2020 · The World Bank’s Environment, Natu...
# ...                                                 ...
# 913   sustainability of its administrative and opera...
# 942   Sustainability in Denmark For hundreds of year...
# 996   Sustainability as integral part of ‘own the ga...
# 1037  Tesco takes action to improve marine sustainab...
# 1473  Product sustainability is king. The collection...
#
#       total nr of results (best guess)  ...  \
# 345                           21900000  ...
# 354                           21900000  ...
# 360                           21900000  ...
# 363                           21900000  ...
# 366                           21900000  ...
# ...                                ...  ...
# 913                           16800000  ...
# 942                           16800000  ...
# 996                           83100000  ...
# 1037                          16800000  ...
# 1473                          16800000  ...
#
#                                           canonical_url  \
# 345
# 354
# 360   https://aecom.com/services/environmental-servi...
# 363
# 366   https://www.worldbank.org/en/topic/environment...
# ...                                                 ...
# 913
# 942   https://denmark.dk/innovation-and-design/susta...
# 996
# 1037
# 1473
#
#                                title  \
# 345
# 354
# 360   Environmental Services | AECOM
# 363                  The Environment
# 366                         Overview
# ...                              ...
# 913
# 942     Sustainability and the Danes
# 996
# 1037
# 1473
#
#                                             description  \
# 345
# 354
# 360   The AECOM environmental services group helps i...
# 363   Kids learn about the environment and why keepi...
# 366   Over the last 20 years, countries have been ac...
# ...                                                 ...
# 913
# 942     Sustainability in Denmark, cleaning the beaches
# 996
# 1037
# 1473
#
#                                             raw_content comments author  \
# 345
# 354
# 360   Our environmental services help industrial and...
# 363   The environment is everything around us. All o...
# 366   Context\nThe sustainable management of the env...
# ...                                                 ...      ...    ...
# 913
# 942   Sustainability in Denmark\nWhat is sustainabil...
# 996
# 1037
# 1473
#
#      categories                                               tags  \
# 345
# 354
# 360                                                       services
# 363              environment|ecosystem|learn|science|teachers|s...
# 366                              Environment and Natural Resources
# ...         ...                                                ...
# 913
# 942
# 996
# 1037
# 1473
#
#             date    sitename
# 345
# 354
# 360   2015-09-17       AECOM
# 363
# 366               World Bank
# ...          ...         ...
# 913
# 942   2018-06-08  Denmark.dk
# 996
# 1037
# 1473
#
# [280 rows x 29 columns]

# %% [markdown]
# # Group content by actor

# %%
actor_dict = {}
for index, row in df.iterrows():
    if row['actor name']:
        actor_id = row['actor name']
    else:
        actor_id = row['domain']
    if actor_id in actor_dict:
        actor_obj = actor_dict[actor_id]
    else:
        actor_obj = {}
        actor_obj['Id'] = actor_id
        actor_obj['urls'] = ''
        actor_obj['text'] = ''
        actor_obj['discourse: Climate change'] = 'False'
        actor_obj['discourse: Environment'] = 'False'
        actor_obj['discourse: Green growth'] = 'False'
        actor_obj['discourse: Sustainability'] = 'False'
        actor_obj['discourse: UN SDGs'] = 'False'
        actor_obj['area: Arctic'] = 'False'
        actor_obj['area: Arctic Norway'] = 'False'
        actor_obj['area: Extended Arctic'] = 'False'
        actor_obj['area: Faroed Islands'] = 'False'
        actor_obj['area: Greenland'] = 'False'
        actor_obj['area: Iceland'] = 'False'
        actor_obj['area: Nunavut'] = 'False'
        actor_obj['area: Sami'] = 'False'
    
    actor_obj['urls'] = actor_obj['urls'] + str(row['article url']) + ' '
    actor_obj['text'] = actor_obj['text'] + str(row['raw_content']) + ' . '

    if row['discourse'] == 'Climate change':
        actor_obj['discourse: Climate change'] = 'True'
    if row['discourse'] == 'environment':
        actor_obj['discourse: Environment'] = 'True'
    if row['discourse'] == 'green growth':
        actor_obj['discourse: Green growth'] = 'True'
    if row['discourse'] == 'sustainability':
        actor_obj['discourse: Sustainability'] = 'True'
    if row['discourse'] == 'UN SDGs':
        actor_obj['discourse: UN SDGs'] = 'True'
    if row['area'] == 'arctic':
        actor_obj['area: Arctic'] = 'True'
    if row['area'] == 'arctic norway':
        actor_obj['area: Arctic Norway'] = 'True'
    if row['area'] == 'extended arctic':
        actor_obj['area: Extended Arctic'] = 'True'
    if row['area'] == 'faroe islands':
        actor_obj['area: Faroed Islands'] = 'True'
    if row['area'] == 'greenland':
        actor_obj['area: Greenland'] = 'True'
    if row['area'] == 'Iceland':
        actor_obj['area: Iceland'] = 'True'
    if row['area'] == 'Nunavut':
        actor_obj['area: Nunavut'] = 'True'
    if row['area'] == 'Sami':
        actor_obj['area: Sami'] = 'True'
    
    actor_dict[actor_id] = actor_obj
print("Actor index built.")
# Out:
# Actor index built.

# %%
# DOWNLOAD ACTORS
actors_df = pd.DataFrame.from_dict(actor_dict, orient='index')
actors_df.to_csv("02 Actors with text.csv", index = False, encoding='utf-8')
actors_df
# Out:
#                                 Id  \
# unep                          unep
# aecom                        aecom
# ducksters                ducksters
# worldbank                worldbank
# un                              un
# ...                            ...
# 50climateleaders  50climateleaders
# denmark                    denmark
# unglobalcompact    unglobalcompact
# adidas-group          adidas-group
# tescoplc                  tescoplc
#
#                                                                urls  \
# unep              https://www.unep.org/ https://www.unep.org/env...
# aecom             https://aecom.com/services/environmental-servi...
# ducksters           https://www.ducksters.com/science/environment/
# worldbank         https://www.worldbank.org/en/topic/environment...
# un                https://unstats.un.org/UNSD/envstats/index.csh...
# ...                                                             ...
# 50climateleaders                 https://www.50climateleaders.com/
# denmark           https://denmark.dk/innovation-and-design/susta...
# unglobalcompact   https://www.unglobalcompact.org/what-is-gc/our...
# adidas-group      https://www.adidas-group.com/en/sustainability...
# tescoplc                  https://www.tescoplc.com/sustainability/
#
#                                                                text  \
# unep                                                    .  .  .  .
# aecom             Our environmental services help industrial and...
# ducksters         The environment is everything around us. All o...
# worldbank         Context\nThe sustainable management of the env...
# un                Work Programme\nThe Environment Statistics Sec...
# ...                                                             ...
# 50climateleaders  Sulzer: The power of fluid engineering\nActis:...
# denmark           Sustainability in Denmark\nWhat is sustainabil...
# unglobalcompact    . Today’s business landscape is characterized...
# adidas-group                                                  .  .
# tescoplc                                                         .
#
#                  discourse: Climate change discourse: Environment  \
# unep                                 False                   True
# aecom                                False                   True
# ducksters                            False                   True
# worldbank                            False                   True
# un                                   False                   True
# ...                                    ...                    ...
# 50climateleaders                     False                  False
# denmark                              False                  False
# unglobalcompact                      False                   True
# adidas-group                         False                  False
# tescoplc                             False                  False
#
#                  discourse: Green growth discourse: Sustainability  \
# unep                                True                     False
# aecom                              False                      True
# ducksters                          False                     False
# worldbank                          False                     False
# un                                  True                      True
# ...                                  ...                       ...
# 50climateleaders                   False                      True
# denmark                             True                      True
# unglobalcompact                     True                     False
# adidas-group                        True                      True
# tescoplc                           False                      True
#
#                  discourse: UN SDGs area: Arctic area: Arctic Norway  \
# unep                          False        False               False
# aecom                         False        False               False
# ducksters                     False        False               False
# worldbank                     False        False               False
# un                            False        False               False
# ...                             ...          ...                 ...
# 50climateleaders              False        False               False
# denmark                       False        False               False
# unglobalcompact               False        False               False
# adidas-group                  False        False               False
# tescoplc                      False        False               False
#
#                  area: Extended Arctic area: Faroed Islands area: Greenland  \
# unep                              True                False           False
# aecom                             True                False           False
# ducksters                         True                False           False
# worldbank                         True                False           False
# un                                True                False           False
# ...                                ...                  ...             ...
# 50climateleaders                  True                False           False
# denmark                           True                False           False
# unglobalcompact                   True                False           False
# adidas-group                      True                False           False
# tescoplc                          True                False           False
#
#                  area: Iceland area: Nunavut area: Sami
# unep                     False         False      False
# aecom                    False         False      False
# ducksters                False         False      False
# worldbank                False         False      False
# un                       False         False      False
# ...                        ...           ...        ...
# 50climateleaders         False         False      False
# denmark                  False         False      False
# unglobalcompact          False         False      False
# adidas-group             False         False      False
# tescoplc                 False         False      False
#
# [202 rows x 16 columns]

# %% [markdown]
# # LDA: extract topics

# %%
import pandas as pd
# This is for text mining
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# Source file (CSV)
source_file = "02 Actors with text.csv"
text_col_name = "text"

# More features is more dimensions for each document. You should probably keep it at 1000.
no_features = 1000

# %%
# LOAD DATA
documents_dictionary = {}
df = pd.read_csv(source_file)

for index, row in df.iterrows():
    key = row['Id']
    text = str(row[text_col_name])
    if len(text)>10:
        documents_dictionary[key] = text

# %%
# COMPUTE LDA TOPICS
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents_dictionary.values())
tf_feature_names = tf_vectorizer.get_feature_names()
lda = LatentDirichletAllocation(n_components=number_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)
print("LDA topics computed.")
# Out:
# LDA topics computed.

# %%
# DISPLAY RESULTS (for monitoring)
no_top_words = 25 # How many words to keep for each topic (there may be many)

# Create a data frame for convenience (for download, actually)
topics_df = pd.DataFrame(columns=['topic','word','weight'])

# Display topics to check it works. For each topic, we only display the top words.
i = 0
for topic_idx, topic in enumerate(lda.components_):
    print("# TOPIC_%d:" % (topic_idx))
    for j in topic.argsort()[:-no_top_words - 1:-1]:
        print(str(topic[j]) + "   " + tf_feature_names[j])
        topics_df.loc[i] = ["TOPIC_"+str(topic_idx), tf_feature_names[j], topic[j]]
        i = i+1
    print(" ")

topics_df
# Out:
# # TOPIC_0:
# 6.856292462229249   covid
# 4.70277764753598   health
# 4.592292984607278   university
# 4.190395146413412   energy
# 3.7381799531894084   19
# 3.5313058240957744   sustainability
# 3.4772809707090913   people
# 3.290576980012149   study
# 3.131598824141872   school
# 3.1131044158368364   business
# 2.787683452648913   special
# 2.672615445349866   environmental
# 2.5892012111227953   air
# 2.5302491722111466   world
# 2.486303744835124   research
# 2.3813421577053853   international
# 2.260380921179885   reduction
# 2.189147057250002   science
# 2.1683523753152265   positive
# 2.159995336072876   year
# 2.064588504642481   environment
# 2.032853183025543   technology
# 1.9951775609390037   new
# 1.9948856334067342   power
# 1.9743388775810329   renewable
#
# # TOPIC_1:
# 8.06520863159847   yukon
# 5.035427235655434   number
# 3.0238892332762495   wildlife
# 2.7379889190941675   provides
# 2.567973732610535   water
# 2.4310823501895813   management
# 2.252688760633365   environmental
# 2.228680511868961   energy
# 2.098728422731139   change
# 1.9906205771624141   climate
# 1.9745290861235192   health
# 1.7136616297058256   policy
# 1.6706047356314975   government
# 1.630001482564605   fish
# 1.6070044838762647   monitoring
# 1.5891262119023295   2021
# 1.5639472196461068   environment
# 1.5482827724968602   animal
# 1.520868081455901   public
# 1.5164751740942888   sustainability
# 1.4910802114430206   issue
# 1.4815497131247994   chief
# 1.4175382319805394   special
# 1.412722042272015   programs
# 1.397038020355178   executive
#
# # TOPIC_2:
# 6.874833539656791   norway
# 6.571939074633414   environmental
# 4.61465465085629   business
# 4.508444262228066   sustainable
# 4.445292175976878   21
# 4.076828303434591   development
# 3.6200235334999946   water
# 3.439048024003607   new
# 3.3380967285913274   green
# 2.933412379407773   health
# 2.927089578588251   economy
# 2.8901354192706488   sustainability
# 2.889813908077334   community
# 2.7068343070026697   air
# 2.681729956816496   awareness
# 2.592009911877307   energy
# 2.5474671401574662   use
# 2.494746684970045   company
# 2.4394087175863284   region
# 2.298812332144433   public
# 2.2644103509012674   quality
# 2.1785029378272345   issue
# 2.0939015272905825   food
# 2.068220285951052   environment
# 1.9956741747671758   waste
#
# # TOPIC_3:
# 7.2656880700389115   energy
# 5.828274313730755   special
# 3.41476494896495   systems
# 3.2075777031492425   water
# 3.18414392206754   issue
# 3.076886889711762   health
# 2.7099640118825037   interests
# 2.5542230854006007   renewable
# 2.438464618586087   business
# 2.3127028195741897   pollution
# 2.2892150917352514   environmental
# 2.1713028545475512   journals
# 2.1356704652740452   green
# 2.0674841977524547   recycled
# 2.06624516060003   environment
# 2.024561142571333   issues
# 1.9740586180906283   sustainability
# 1.9674546833716398   plastic
# 1.9561619295122252   collections
# 1.8967046446299114   sustainable
# 1.8605163430795542   power
# 1.8534904431267913   building
# 1.7993258677307142   energies
# 1.6738335274122087   management
# 1.6453270780034133   products
#
# # TOPIC_4:
# 290.45926474952597   sustainable
# 288.9906099099491   sustainability
# 250.78686515222117   business
# 125.51033875199343   development
# 123.83793833402403   environmental
# 122.65949175542842   world
# 114.91644691231721   global
# 96.34769230022853   new
# 92.99545631384933   environment
# 92.88203215691169   companies
# 90.15960590751695   company
# 89.99911803110116   climate
# 89.78473110454213   people
# 78.80833665338166   energy
# 77.52913959020232   use
# 76.58630020137237   help
# 74.96254032263016   social
# 72.89190106187853   change
# 72.6131542311287   products
# 72.42926875376213   emissions
# 70.14887730145907   future
# 69.51675430104763   green
# 69.23529841455921   carbon
# 68.58805598945351   impact
# 67.55624499075418   value
#
# # TOPIC_5:
# 30.77127647040652   environmental
# 28.837081653340395   war
# 28.815506785367646   water
# 27.773837266353684   energy
# 25.127955529190114   gas
# 16.42195890869244   oil
# 16.094049385191752   environment
# 14.571965627481577   air
# 13.229290737446199   natural
# 11.870319575562528   world
# 11.462033440128646   united
# 11.376499608322574   new
# 11.337673646030346   week
# 11.159733524787562   000
# 11.0754037414679   science
# 10.608321930892588   caused
# 10.581059603624949   power
# 10.392915414441665   health
# 10.338827715305339   people
# 9.860259189440859   drought
# 9.729059490891288   states
# 9.492204845136921   land
# 9.40764677325071   normal
# 9.011825737241427   pollution
# 8.835279393206376   denmark
#
# # TOPIC_6:
# 64.00327113737036   pollution
# 61.790786809846686   health
# 56.575752752853006   air
# 55.72477382034057   water
# 51.26795249714959   quality
# 45.84745639968667   oecd
# 32.315102090309395   meter
# 31.616837545595025   cubic
# 29.780771647037074   environmental
# 25.58587400213803   countries
# 24.84489811923905   set
# 24.656625091991426   environment
# 24.152258379675853   people
# 23.9188195186042   average
# 23.70387030958398   urban
# 23.49037150389064   small
# 23.26921178368804   human
# 22.935765253268283   term
# 22.765454928728364   despite
# 22.702223852109267   pm2
# 22.31730733527693   diseases
# 22.014405758538516   respiratory
# 21.81242527162113   lung
# 19.793391987215408   emissions
# 18.848029913078847   lives
#
# # TOPIC_7:
# 266.08076773646053   energy
# 200.24538591591806   sustainability
# 159.8433840767485   special
# 150.93357284759014   sustainable
# 106.38401974628432   issue
# 95.4157450665053   development
# 94.24680176533079   systems
# 83.34701826069002   environmental
# 81.80687577547972   interests
# 74.54539875836902   issues
# 61.87024096192479   renewable
# 61.29138714580587   website
# 57.223840509982544   journals
# 55.41327420822161   power
# 54.316763306829216   collections
# 53.31574495825198   business
# 50.584581209385306   university
# 50.53738390880158   engineering
# 47.5599102590988   management
# 44.94117993982431   research
# 41.977145305245244   environment
# 41.36060805745747   building
# 39.102821268701135   economic
# 38.955206032292466   energies
# 37.62371285624876   economy
#
# # TOPIC_8:
# 2.2363263151989714   energy
# 2.1227657128220123   health
# 2.0311260395037367   issue
# 1.7245922722502078   environmental
# 1.7111193210021847   sustainability
# 1.6788458286666603   special
# 1.6052188126262381   research
# 1.5293192602023993   world
# 1.3388488489185335   program
# 1.3359408437225646   environment
# 1.3102133289350317   economy
# 1.278378377530135   renewable
# 1.263256656748525   systems
# 1.262318370904564   water
# 1.2279624593506457   help
# 1.1767765384016398   people
# 1.1434703644379223   new
# 1.1414490766592977   sustainable
# 1.093585094073254   interests
# 1.0847523325769832   website
# 1.084683154306904   ecovadis
# 1.084598320798417   war
# 1.0488475987902726   economic
# 1.0438826487157513   business
# 1.0418446080871613   suppliers
#
# # TOPIC_9:
# 22.43847131504445   sustainability
# 22.342493330162412   environment
# 20.590531170962272   executive
# 16.59681321666181   chief
# 16.227402744497013   business
# 14.90294411978012   global
# 14.10336495265344   committee
# 13.080282897900032   world
# 11.817350699272826   career
# 11.753689777657188   volvo
# 10.515444182617196   board
# 10.177177357634577   trade
# 9.826214470817044   programme
# 9.803578437665447   2019
# 9.136480835435238   cars
# 9.049783935245555   management
# 9.034324845799327   report
# 8.80243189920385   company
# 8.749911497038768   sustainable
# 8.470146350552373   group
# 7.65139378396301   experience
# 6.786272982654301   development
# 6.726511036651741   climate
# 6.632094827435426   students
# 6.60592807091104   innovation
#
# # TOPIC_10:
# 23.478787499755068   sustainability
# 17.385986527474213   marketing
# 17.38378780118892   sustainable
# 16.954684023389966   green
# 16.510916120884   product
# 15.133809976929623   products
# 14.683277546887362   consumers
# 13.501909332183422   companies
# 13.37733920847566   company
# 10.088984628099189   com
# 9.437070362653676   new
# 9.168153293813214   business
# 9.162985242319364   http
# 9.105492837895868   www
# 8.495652788775162   consumer
# 8.181023280918215   use
# 8.000739622607764   water
# 7.701240810217715   local
# 7.331881164232269   market
# 7.315143317052176   value
# 6.597108847181053   energy
# 6.4186096021631105   brand
# 6.376680922093497   price
# 6.114466812362642   example
# 6.052371708683544   packaging
#
# # TOPIC_11:
# 58.531595733492296   sustainable
# 41.56381754814642   new
# 36.482086375090766   tea
# 34.54927721515352   window
# 30.744305102191376   farmers
# 30.188306815037784   supply
# 28.926598494290356   opens
# 27.451296163457112   sustainability
# 27.290330548063412   pdf
# 26.949747519270844   suppliers
# 22.736835789743214   agriculture
# 20.71514344108266   sourcing
# 19.88692428848868   chain
# 19.42026204014023   industry
# 18.192481478212873   change
# 17.298257296230375   climate
# 16.929323690241198   global
# 16.514348839394916   work
# 16.34775056587295   business
# 16.065147729937824   working
# 15.858341966346195   code
# 15.654098421348328   dairy
# 15.28291073711545   environmental
# 14.842207083427832   make
# 14.341921691685458   world
#
# # TOPIC_12:
# 2.9096274214156006   weather
# 1.879274371174459   cloud
# 1.7729147896695017   guide
# 1.7181316278834502   sustainable
# 1.7083583195923515   supplier
# 1.6628238561422395   canada
# 1.609977930906457   understand
# 1.4911507544742408   climate
# 1.4758460942844982   service
# 1.472265555395256   environmental
# 1.4362561485375063   energy
# 1.40199671970002   services
# 1.390689294045169   centre
# 1.383021472484222   sustainability
# 1.3692721433594162   water
# 1.3453715370854615   data
# 1.326070818939621   marine
# 1.273117133028934   economy
# 1.2466337594070187   wind
# 1.1969870299237668   level
# 1.190308967205713   green
# 1.1857125456288689   business
# 1.1711319672060534   training
# 1.165398710428128   special
# 1.15876576713821   world
#
# # TOPIC_13:
# 12.443464411740997   packaging
# 11.089609196522579   sustainability
# 8.804037435977047   awards
# 7.3626382365113345   category
# 6.641710718167291   competition
# 6.062367242843116   pepsico
# 5.637415439811794   sustainable
# 5.502795806852534   innovation
# 4.489500964158963   europe
# 3.929840832252417   year
# 3.7633420851504367   summit
# 3.759666082700109   categories
# 3.6883288430185774   business
# 3.6793406710169996   information
# 3.383966937799238   best
# 3.2857285782360335   innovations
# 3.176295781411708   september
# 3.1048848438664334   company
# 3.0596002740454336   environmental
# 2.9911736552735047   particular
# 2.93763968325367   products
# 2.9369303948261845   product
# 2.9077283328725363   2021
# 2.8986655007437334   value
# 2.798814981287755   events
#
# # TOPIC_14:
# 9.431065953002125   oecd
# 9.383302960493344   ups
# 5.911202547269288   growth
# 5.887306090412308   sustainable
# 5.767128030255644   business
# 4.911338499087264   environmental
# 4.56912969470404   covid
# 4.277438958025331   countries
# 4.047200128341419   green
# 3.9377265960304086   sustainability
# 3.9033504593326875   19
# 3.59256341656366   read
# 3.3036795845049323   economic
# 3.1653006776551242   world
# 3.093826131305119   development
# 2.879412923452425   policy
# 2.8438185056657663   quality
# 2.4402215170582306   water
# 2.4388138624396767   human
# 2.4376479311866786   progress
# 2.418154833307324   pollution
# 2.37255209498194   air
# 2.368573656457314   global
# 2.344106446301987   recovery
# 2.3341398800302184   companies
#         topic        word    weight
# 0     TOPIC_0       covid  6.856292
# 1     TOPIC_0      health  4.702778
# 2     TOPIC_0  university  4.592293
# 3     TOPIC_0      energy  4.190395
# 4     TOPIC_0          19  3.738180
# ..        ...         ...       ...
# 370  TOPIC_14   pollution  2.418155
# 371  TOPIC_14         air  2.372552
# 372  TOPIC_14      global  2.368574
# 373  TOPIC_14    recovery  2.344106
# 374  TOPIC_14   companies  2.334140
#
# [375 rows x 3 columns]

# %%
# COMPUTE DOC x TOPIC RELATIONS (network)
# We create a data frame to store the content. It looks like a matrix.
df_matrix_style = pd.DataFrame(columns=['doc']+[("TOPIC_"+str(i)) for i in range(0,number_topics)])

# We create a second data frame with the same data. It looks like a list.
# Depending on what you want to do, one or the other are most convenient.
df_list_style = pd.DataFrame(columns=['doc', 'topic', 'weight'])

doc_topic = lda.transform(tf)
docs = list(documents_dictionary.keys())
topic_index = {}
i1 = 0
i2 = 0
for j in range(len(docs)):
    key = docs[j]
    topic_weights = list(doc_topic[j])
    
    # Index
    topic_index[key] = topic_weights
    
    # Matrix style
    df_matrix_style.loc[i1] = [key]+topic_weights
    i1 = i1+1
    
    # List style
    for k, w in enumerate(topic_weights):
        df_list_style.loc[i2] = [key, "TOPIC_"+str(k), w]
        i2 = i2+1

print("Done.")
# Out:
# Done.

# %%
# Output articles & topics, matrix style, to check that it works:
df_matrix_style
# Out:
#                   doc   TOPIC_0   TOPIC_1   TOPIC_2   TOPIC_3   TOPIC_4  \
# 0                unep  0.066667  0.066667  0.066667  0.066667  0.066667
# 1               aecom  0.000252  0.000252  0.000252  0.000252  0.847562
# 2           ducksters  0.000623  0.000623  0.000623  0.000623  0.154162
# 3           worldbank  0.000392  0.000392  0.000392  0.000392  0.926726
# 4                  un  0.000040  0.000040  0.000040  0.000040  0.999443
# ..                ...       ...       ...       ...       ...       ...
# 172             alcoa  0.013333  0.013333  0.013333  0.013333  0.013333
# 173          vodafone  0.001258  0.001258  0.001258  0.001258  0.982390
# 174  50climateleaders  0.000130  0.000130  0.000130  0.000130  0.848413
# 175           denmark  0.000270  0.000270  0.000270  0.000270  0.532263
# 176   unglobalcompact  0.000612  0.000612  0.000612  0.000612  0.991437
#
#       TOPIC_5   TOPIC_6   TOPIC_7   TOPIC_8   TOPIC_9  TOPIC_10  TOPIC_11  \
# 0    0.066667  0.066667  0.066667  0.066667  0.066667  0.066667  0.066667
# 1    0.000252  0.000252  0.149167  0.000252  0.000252  0.000252  0.000252
# 2    0.837738  0.000623  0.000623  0.000623  0.000623  0.000623  0.000623
# 3    0.000392  0.068176  0.000392  0.000392  0.000392  0.000392  0.000392
# 4    0.000040  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040
# ..        ...       ...       ...       ...       ...       ...       ...
# 172  0.013333  0.013333  0.013333  0.013333  0.013333  0.813333  0.013333
# 173  0.001258  0.001258  0.001258  0.001258  0.001258  0.001258  0.001258
# 174  0.000130  0.000130  0.149901  0.000130  0.000130  0.000130  0.000130
# 175  0.364083  0.000270  0.100415  0.000270  0.000270  0.000270  0.000270
# 176  0.000612  0.000612  0.000612  0.000612  0.000612  0.000612  0.000612
#
#      TOPIC_12  TOPIC_13  TOPIC_14
# 0    0.066667  0.066667  0.066667
# 1    0.000252  0.000252  0.000252
# 2    0.000623  0.000623  0.000623
# 3    0.000392  0.000392  0.000392
# 4    0.000040  0.000040  0.000040
# ..        ...       ...       ...
# 172  0.013333  0.013333  0.013333
# 173  0.001258  0.001258  0.001258
# 174  0.000130  0.000130  0.000130
# 175  0.000270  0.000270  0.000270
# 176  0.000612  0.000612  0.000612
#
# [177 rows x 16 columns]

# %%
# Output articles & topics, list style, to check that it works:
df_list_style
# Out:
#                   doc     topic    weight
# 0                unep   TOPIC_0  0.066667
# 1                unep   TOPIC_1  0.066667
# 2                unep   TOPIC_2  0.066667
# 3                unep   TOPIC_3  0.066667
# 4                unep   TOPIC_4  0.066667
# ...               ...       ...       ...
# 2650  unglobalcompact  TOPIC_10  0.000612
# 2651  unglobalcompact  TOPIC_11  0.000612
# 2652  unglobalcompact  TOPIC_12  0.000612
# 2653  unglobalcompact  TOPIC_13  0.000612
# 2654  unglobalcompact  TOPIC_14  0.000612
#
# [2655 rows x 3 columns]

# %%
# DOWNLOAD LDA results
# Note: these files can be used in Tableau or Table2Net to build various visualizations.

topics_df.to_csv("03-a LDA topics and their words.csv", index = False, encoding='utf-8')
# df_matrix_style.to_csv("03-? LDA actors and topics matrix.csv", index = False, encoding='utf-8')
df_list_style.to_csv("03-b LDA actors and topics list style.csv", index = False, encoding='utf-8')

# %%
# ENRICH FILE (and monitor new version)
for topic_id, topic in enumerate(lda.components_):
    colname = "topic_"+str(topic_id)
    values = []
    for index, row in df.iterrows():
        key = row['Id']
        if key in topic_index:
            val = topic_index[key][topic_id]
        else:
            val = 0
        values.append(val)
    df.insert(len(df.columns), colname, values)
df
# Out:
#                    Id                                               urls  \
# 0                unep  https://www.unep.org/ https://www.unep.org/env...
# 1               aecom  https://aecom.com/services/environmental-servi...
# 2           ducksters    https://www.ducksters.com/science/environment/
# 3           worldbank  https://www.worldbank.org/en/topic/environment...
# 4                  un  https://unstats.un.org/UNSD/envstats/index.csh...
# ..                ...                                                ...
# 197  50climateleaders                 https://www.50climateleaders.com/
# 198           denmark  https://denmark.dk/innovation-and-design/susta...
# 199   unglobalcompact  https://www.unglobalcompact.org/what-is-gc/our...
# 200      adidas-group  https://www.adidas-group.com/en/sustainability...
# 201          tescoplc          https://www.tescoplc.com/sustainability/
#
#                                                   text  \
# 0                                          .  .  .  .
# 1    Our environmental services help industrial and...
# 2    The environment is everything around us. All o...
# 3    Context\nThe sustainable management of the env...
# 4    Work Programme\nThe Environment Statistics Sec...
# ..                                                 ...
# 197  Sulzer: The power of fluid engineering\nActis:...
# 198  Sustainability in Denmark\nWhat is sustainabil...
# 199   . Today’s business landscape is characterized...
# 200                                              .  .
# 201                                                 .
#
#      discourse: Climate change  discourse: Environment  \
# 0                        False                    True
# 1                        False                    True
# 2                        False                    True
# 3                        False                    True
# 4                        False                    True
# ..                         ...                     ...
# 197                      False                   False
# 198                      False                   False
# 199                      False                    True
# 200                      False                   False
# 201                      False                   False
#
#      discourse: Green growth  discourse: Sustainability  discourse: UN SDGs  \
# 0                       True                      False               False
# 1                      False                       True               False
# 2                      False                      False               False
# 3                      False                      False               False
# 4                       True                       True               False
# ..                       ...                        ...                 ...
# 197                    False                       True               False
# 198                     True                       True               False
# 199                     True                      False               False
# 200                     True                       True               False
# 201                    False                       True               False
#
#      area: Arctic  area: Arctic Norway  ...   topic_5   topic_6   topic_7  \
# 0           False                False  ...  0.066667  0.066667  0.066667
# 1           False                False  ...  0.000252  0.000252  0.149167
# 2           False                False  ...  0.837738  0.000623  0.000623
# 3           False                False  ...  0.000392  0.068176  0.000392
# 4           False                False  ...  0.000040  0.000040  0.000040
# ..            ...                  ...  ...       ...       ...       ...
# 197         False                False  ...  0.000130  0.000130  0.149901
# 198         False                False  ...  0.364083  0.000270  0.100415
# 199         False                False  ...  0.000612  0.000612  0.000612
# 200         False                False  ...  0.000000  0.000000  0.000000
# 201         False                False  ...  0.000000  0.000000  0.000000
#
#       topic_8   topic_9  topic_10  topic_11  topic_12  topic_13  topic_14
# 0    0.066667  0.066667  0.066667  0.066667  0.066667  0.066667  0.066667
# 1    0.000252  0.000252  0.000252  0.000252  0.000252  0.000252  0.000252
# 2    0.000623  0.000623  0.000623  0.000623  0.000623  0.000623  0.000623
# 3    0.000392  0.000392  0.000392  0.000392  0.000392  0.000392  0.000392
# 4    0.000040  0.000040  0.000040  0.000040  0.000040  0.000040  0.000040
# ..        ...       ...       ...       ...       ...       ...       ...
# 197  0.000130  0.000130  0.000130  0.000130  0.000130  0.000130  0.000130
# 198  0.000270  0.000270  0.000270  0.000270  0.000270  0.000270  0.000270
# 199  0.000612  0.000612  0.000612  0.000612  0.000612  0.000612  0.000612
# 200  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 201  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [202 rows x 31 columns]

# %%
# DOWNLOAD ENRICHED FILE
df.drop(columns=[text_col_name]).to_csv("04 Actors and their topics.csv", index=False)

# %% [markdown]
# # Export LDA networks

# %%
# Export network of words and topics
import networkx as nx
G = nx.Graph()
for index, row in topics_df.iterrows():
    topic = 'T_'+str(row['topic'])
    word = 'W_'+str(row['word'])
    w = row['weight']
    
    G.add_edge(topic, word)
    G[topic][word]['weight'] = w
    
    G.nodes[topic]['label'] = str(row['topic'])
    G.nodes[topic]['type'] = 'topic'
    G.nodes[word]['label'] = str(row['word'])
    G.nodes[word]['type'] = 'word'
    
nx.write_gexf(G, "05 Words and topics.gexf")

# %%
# Export network of actors and topics
import networkx as nx
threshold = 0.001
G = nx.Graph()
for index, row in df_list_style.iterrows():
    topic = 'T_'+str(row['topic'])
    actor = 'A_'+str(row['doc'])
    w = row['weight']
    
    if w > threshold:
        G.add_edge(topic, actor)
        G[topic][actor]['weight'] = w

        G.nodes[topic]['label'] = str(row['topic'])
        G.nodes[topic]['type'] = 'topic'
        G.nodes[actor]['label'] = str(row['doc'])
        G.nodes[actor]['type'] = 'actor'
    
nx.write_gexf(G, "06 Actors and topics.gexf")

# %% [markdown]
# # UMAP after the topics

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import umap

# %%
# Load data
df = pd.read_csv("04 Actors and their topics.csv")
df = df.dropna()

# %%
# Prepare data
reducer = umap.UMAP()
umap_data = df[
    [
        "topic_0",
        "topic_1",
        "topic_2",
        "topic_3",
        "topic_4",
        "topic_5",
        "topic_6",
        "topic_7",
        "topic_8",
        "topic_9",
        "topic_10",
        "topic_11",
        "topic_12",
        "topic_13",
        "topic_14"
    ]
].values
scaled_umap_data = StandardScaler().fit_transform(umap_data)

# %%
# Compute embedding
embedding = reducer.fit_transform(scaled_umap_data)
embedding.shape
# Out:
# (202, 2)

# %%
# Monitor embedding
plt.scatter(
    embedding[:, 0],
    embedding[:, 1]
)
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection of the dataset', fontsize=24)
# Out:
# Text(0.5, 1.0, 'UMAP projection of the dataset')

# %%
# Enrich source and download
xvalues = []
yvalues = []
for index, row in df.iterrows():
    coord = embedding[index]
    xvalues.append(coord[0])
    yvalues.append(coord[1])
df.insert(len(df.columns), 'X-UMAP', xvalues)
df.insert(len(df.columns), 'Y-UMAP', yvalues)

df.to_csv("07 Actors with topics + UMAP layout.csv", index = False, encoding='utf-8')
